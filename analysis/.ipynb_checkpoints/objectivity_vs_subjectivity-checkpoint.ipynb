# %% [markdown]
# # Objectivity vs. subjectivity in political communication

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from datetime import datetime,timedelta
from scipy import stats
tqdm.pandas(desc='Cleaning')

from scorers.cleaning import *
from scorers.objectivity_vs_subjectivity import *

# %%
# Manifestos
manifestos = pd.read_csv('../manifesto-forewords/manifestos.csv')
manifestos.year = pd.to_datetime(manifestos.year)
manifestos = manifestos[manifestos.year>='1945-01-01']
# PMQs answers
pmqs = pd.read_csv('../hansard-pmqs/hansard_pmqs.csv')
pmqs.date = pd.to_datetime(pmqs.date)
pmqs = pmqs[pmqs.date>='1945-01-01']
pmqs = pd.DataFrame({'date':pmqs.groupby(by='date').answer_text.aggregate(lambda x: ''.join(x)).index,
                     'answer_text':pmqs.groupby(by='date').answer_text.aggregate(lambda x: ''.join(x)),
                     'answerer_party':pmqs.groupby(by='date').answerer_party.aggregate(lambda x: x.mode()),
                     'answerer_name':pmqs.groupby(by='date').answerer_name.aggregate(lambda x: x.mode())})
# Conference speeches
conferences = pd.read_csv('../conference-speeches/conference.csv')
conferences = conferences.drop('Unnamed: 0', axis=1)
conferences.year = conferences.year.apply(lambda year: pd.to_datetime(str(year)+'-01-01'))
conferences = conferences[conferences.year>='1945-01-01']

# %%
# Manifestos
manifestos['clean'] = manifestos.foreword.progress_apply(lambda x: clean(x)) # ...clean them
manifestos_nans = [idx for idx,foreword in enumerate(manifestos['clean']) if len(foreword)==0] # ...save NAN indexes to a list
manifestos_scores = [measure_subjectivity(text_list=row.clean, sent_list=row.foreword) for idx,row in tqdm(manifestos.iterrows(),desc='Scoring manifesto forewords') if len(row.clean)>0] # ...score them
manifestos_vecs = [list(score_dict.values()) for score_dict in tqdm(manifestos_scores,desc='Saving manifesto scores')] # ...save scores as a list
# # PMQs answers
pmqs['clean'] = pmqs.answer_text.progress_apply(lambda x: clean(x))
pmqs_nans = [idx for idx,answer in enumerate(pmqs['clean']) if len(answer)==0]
pmqs_scores = [measure_subjectivity(text_list=row.clean, sent_list=row.answer_text) for idx,row in tqdm(pmqs.iterrows(),desc='Scoring PMQs answers') if len(row.clean)>0]
pmqs_vecs = [list(score_dict.values()) for score_dict in tqdm(pmqs_scores,desc='Saving PMQs answer scores')]
# # Conference speeches
conferences['clean'] = conferences.content.progress_apply(lambda x: clean(x))
conferences_nans = [idx for idx,speech in enumerate(conferences['clean']) if len(speech)==0]
conferences_scores = [measure_subjectivity(text_list=row.clean, sent_list=row.content) for idx,row in tqdm(conferences.iterrows(),desc='Scoring conference speeches') if len(row.clean)>0]
conferences_vecs = [list(score_dict.values()) for score_dict in tqdm(conferences_scores,desc='Saving conference speech scores')]
# Out:
# Cleaning: 100%|██████████| 76/76 [00:00<00:00, 5065.42it/s]
# Scoring manifesto forewords: 76it [06:19,  4.99s/it]
# Saving manifesto scores: 100%|██████████| 76/76 [00:00<00:00, 75824.72it/s]
# Cleaning: 100%|██████████| 1806/1806 [00:00<00:00, 2245.45it/s]
# Scoring PMQs answers: 1806it [7:02:00, 14.02s/it]
# Saving PMQs answer scores: 100%|██████████| 1806/1806 [00:00<00:00, 902635.01it/s]
# Cleaning: 100%|██████████| 183/183 [00:00<00:00, 740.89it/s]
# Scoring conference speeches: 0it [00:00, ?it/s]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-672cef217de6> in <module>
#      12 conferences['clean'] = conferences.content.progress_apply(lambda x: clean(x))
#      13 conferences_nans = [idx for idx,speech in enumerate(conferences['clean']) if len(speech)==0]
# ---> 14 conferences_scores = [measure_subjectivity(text_list=row.clean, sent_list=row.content) for idx,row in tqdm(conferences.iterrows(),desc='Scoring conference speeches') if len(speech)>0]
#      15 conferences_vecs = [list(score_dict.values()) for score_dict in tqdm(conferences_scores,desc='Saving conference speech scores')]
#
# <ipython-input-3-672cef217de6> in <listcomp>(.0)
#      12 conferences['clean'] = conferences.content.progress_apply(lambda x: clean(x))
#      13 conferences_nans = [idx for idx,speech in enumerate(conferences['clean']) if len(speech)==0]
# ---> 14 conferences_scores = [measure_subjectivity(text_list=row.clean, sent_list=row.content) for idx,row in tqdm(conferences.iterrows(),desc='Scoring conference speeches') if len(speech)>0]
#      15 conferences_vecs = [list(score_dict.values()) for score_dict in tqdm(conferences_scores,desc='Saving conference speech scores')]
#
# NameError: name 'speech' is not defined

# %%
conferences['clean'] = conferences.content.progress_apply(lambda x: clean(x))
conferences_nans = [idx for idx,speech in enumerate(conferences['clean']) if len(speech)==0]
conferences_scores = [measure_subjectivity(text_list=row.clean, sent_list=row.content) for idx,row in tqdm(conferences.iterrows(),desc='Scoring conference speeches') if len(row.clean)>0]
conferences_vecs = [list(score_dict.values()) for score_dict in tqdm(conferences_scores,desc='Saving conference speech scores')]
# Out:
# Cleaning:   0%|          | 0/183 [00:00<?, ?it/s]
# Cleaning: 100%|██████████| 183/183 [00:00<00:00, 797.90it/s][A
#
# Scoring conference speeches: 0it [00:00, ?it/s]
# Scoring conference speeches: 1it [00:19, 19.28s/it]
# Scoring conference speeches: 2it [01:01, 33.05s/it]
# Scoring conference speeches: 3it [01:38, 34.50s/it]
# Scoring conference speeches: 4it [02:27, 40.44s/it]
# Scoring conference speeches: 5it [03:20, 44.79s/it]
# Scoring conference speeches: 6it [03:56, 41.95s/it]
# Scoring conference speeches: 7it [04:40, 42.56s/it]
# Scoring conference speeches: 8it [05:39, 47.70s/it]
# Scoring conference speeches: 9it [06:22, 46.42s/it]
# Scoring conference speeches: 10it [07:09, 46.60s/it]
# Scoring conference speeches: 11it [08:00, 47.72s/it]
# Scoring conference speeches: 12it [08:20, 39.30s/it]
# Scoring conference speeches: 13it [09:10, 42.70s/it]
# Scoring conference speeches: 14it [10:07, 46.94s/it]
# Scoring conference speeches: 15it [10:54, 46.97s/it]
# Scoring conference speeches: 16it [11:45, 48.12s/it]
# Scoring conference speeches: 17it [11:59, 38.03s/it]
# Scoring conference speeches: 18it [12:38, 38.12s/it]
# Scoring conference speeches: 19it [12:56, 32.21s/it]
# Scoring conference speeches: 20it [13:40, 35.64s/it]
# Scoring conference speeches: 21it [14:19, 36.79s/it]
# Scoring conference speeches: 22it [14:53, 36.01s/it]
# Scoring conference speeches: 23it [15:46, 40.96s/it]
# Scoring conference speeches: 24it [16:03, 33.79s/it]
# Scoring conference speeches: 25it [16:35, 33.20s/it]
# Scoring conference speeches: 26it [16:55, 29.27s/it]
# Scoring conference speeches: 27it [17:22, 28.53s/it]
# Scoring conference speeches: 28it [17:50, 28.56s/it]
# Scoring conference speeches: 29it [18:20, 28.94s/it]
# Scoring conference speeches: 30it [18:54, 30.49s/it]
# Scoring conference speeches: 31it [19:21, 29.25s/it]
# Scoring conference speeches: 32it [19:49, 28.98s/it]
# Scoring conference speeches: 33it [20:27, 31.81s/it]
# Scoring conference speeches: 34it [21:01, 32.34s/it]
# Scoring conference speeches: 35it [21:42, 35.07s/it]
# Scoring conference speeches: 37it [21:43, 18.93s/it]
# Scoring conference speeches: 39it [21:43, 11.44s/it]
# Scoring conference speeches: 41it [21:43,  7.33s/it]
# Scoring conference speeches: 43it [21:43,  4.86s/it]
# Scoring conference speeches: 43it [21:56,  4.86s/it]
# Scoring conference speeches: 45it [22:26, 10.32s/it]
# Scoring conference speeches: 46it [23:15, 17.64s/it]
# Scoring conference speeches: 47it [24:10, 25.57s/it]
# Scoring conference speeches: 48it [24:46, 28.08s/it]
# Scoring conference speeches: 49it [25:46, 36.06s/it]
# Scoring conference speeches: 50it [26:29, 37.95s/it]
# Scoring conference speeches: 51it [27:11, 39.00s/it]
# Scoring conference speeches: 52it [27:48, 38.26s/it]
# Scoring conference speeches: 53it [28:30, 39.56s/it]
# Scoring conference speeches: 54it [29:06, 38.27s/it]
# Scoring conference speeches: 55it [29:46, 39.02s/it]
# Scoring conference speeches: 56it [30:42, 43.91s/it]
# Scoring conference speeches: 57it [31:16, 40.92s/it]
# Scoring conference speeches: 58it [31:58, 41.37s/it]
# Scoring conference speeches: 59it [32:28, 37.83s/it]
# Scoring conference speeches: 60it [33:29, 44.89s/it]
# Scoring conference speeches: 61it [33:59, 40.28s/it]
# Scoring conference speeches: 62it [34:37, 39.68s/it]
# Scoring conference speeches: 63it [35:17, 39.69s/it]
# Scoring conference speeches: 64it [35:56, 39.59s/it]
# Scoring conference speeches: 65it [36:39, 40.68s/it]
# Scoring conference speeches: 66it [37:12, 38.44s/it]
# Scoring conference speeches: 67it [37:49, 37.96s/it]
# Scoring conference speeches: 68it [38:30, 38.79s/it]
# Scoring conference speeches: 69it [39:11, 39.42s/it]
# Scoring conference speeches: 70it [39:52, 39.85s/it]
# Scoring conference speeches: 71it [40:28, 38.79s/it]
# Scoring conference speeches: 72it [40:57, 35.81s/it]
# Scoring conference speeches: 73it [41:35, 36.56s/it]
# Scoring conference speeches: 74it [42:13, 36.81s/it]
# Scoring conference speeches: 75it [42:49, 36.65s/it]
# Scoring conference speeches: 76it [43:29, 37.76s/it]
# Scoring conference speeches: 77it [44:12, 39.21s/it]
# Scoring conference speeches: 78it [44:57, 40.86s/it]
# Scoring conference speeches: 79it [45:50, 44.75s/it]
# Scoring conference speeches: 80it [46:47, 48.41s/it]
# Scoring conference speeches: 81it [47:31, 46.96s/it]
# Scoring conference speeches: 82it [48:04, 42.79s/it]
# Scoring conference speeches: 83it [48:12, 32.47s/it]
# Scoring conference speeches: 84it [49:08, 39.47s/it]
# Scoring conference speeches: 85it [49:59, 42.97s/it]
# Scoring conference speeches: 86it [50:50, 45.25s/it]
# Scoring conference speeches: 87it [51:19, 40.52s/it]
# Scoring conference speeches: 88it [51:48, 36.86s/it]
# Scoring conference speeches: 89it [52:15, 34.02s/it]
# Scoring conference speeches: 90it [52:49, 34.07s/it]
# Scoring conference speeches: 91it [53:31, 36.43s/it]
# Scoring conference speeches: 92it [54:38, 45.47s/it]
# Scoring conference speeches: 93it [55:35, 49.00s/it]
# Scoring conference speeches: 94it [56:25, 49.41s/it]
# Scoring conference speeches: 95it [56:56, 43.85s/it]
# Scoring conference speeches: 96it [57:14, 35.94s/it]
# Scoring conference speeches: 97it [57:30, 30.06s/it]
# Scoring conference speeches: 98it [57:55, 28.59s/it]
# Scoring conference speeches: 99it [58:12, 25.14s/it]
# Scoring conference speeches: 100it [58:37, 24.94s/it]
# Scoring conference speeches: 101it [59:37, 35.63s/it]
# Scoring conference speeches: 102it [1:00:51, 47.04s/it]
# Scoring conference speeches: 103it [1:01:49, 50.49s/it]
# Scoring conference speeches: 104it [1:03:00, 56.51s/it]
# Scoring conference speeches: 105it [1:03:57, 56.61s/it]
# Scoring conference speeches: 106it [1:04:48, 54.81s/it]
# Scoring conference speeches: 107it [1:07:08, 80.40s/it]
# Scoring conference speeches: 108it [1:08:24, 79.27s/it]
# Scoring conference speeches: 109it [1:09:29, 74.81s/it]
# Scoring conference speeches: 110it [1:10:18, 67.19s/it]
# Scoring conference speeches: 111it [1:11:12, 63.19s/it]
# Scoring conference speeches: 112it [1:12:23, 65.67s/it]
# Scoring conference speeches: 113it [1:13:26, 64.84s/it]
# Scoring conference speeches: 114it [1:14:19, 61.31s/it]
# Scoring conference speeches: 115it [1:15:23, 61.99s/it]
# Scoring conference speeches: 116it [1:16:24, 61.58s/it]
# Scoring conference speeches: 117it [1:17:13, 57.88s/it]
# Scoring conference speeches: 118it [1:18:11, 57.93s/it]
# Scoring conference speeches: 119it [1:19:03, 56.23s/it]
# Scoring conference speeches: 120it [1:19:55, 54.79s/it]
# Scoring conference speeches: 121it [1:20:38, 51.33s/it]
# Scoring conference speeches: 122it [1:21:24, 49.86s/it]
# Scoring conference speeches: 123it [1:22:09, 48.37s/it]
# Scoring conference speeches: 124it [1:22:54, 47.27s/it]
# Scoring conference speeches: 125it [1:23:41, 47.18s/it]
# Scoring conference speeches: 126it [1:24:31, 48.07s/it]
# Scoring conference speeches: 127it [1:25:17, 47.60s/it]
# Scoring conference speeches: 128it [1:26:10, 49.03s/it]
# Scoring conference speeches: 129it [1:26:50, 46.36s/it]
# Scoring conference speeches: 130it [1:27:55, 52.13s/it]
# Scoring conference speeches: 131it [1:28:53, 53.64s/it]
# Scoring conference speeches: 132it [1:29:48, 54.18s/it]
# Scoring conference speeches: 133it [1:30:39, 53.18s/it]
# Scoring conference speeches: 134it [1:31:42, 56.25s/it]
# Scoring conference speeches: 135it [1:32:40, 56.80s/it]
# Scoring conference speeches: 136it [1:33:35, 56.27s/it]
# Scoring conference speeches: 137it [1:34:19, 52.49s/it]
# Scoring conference speeches: 138it [1:35:05, 50.35s/it]
# Scoring conference speeches: 139it [1:36:03, 52.73s/it]
# Scoring conference speeches: 140it [1:36:57, 53.04s/it]
# Scoring conference speeches: 141it [1:37:51, 53.35s/it]
# Scoring conference speeches: 142it [1:38:35, 50.61s/it]
# Scoring conference speeches: 143it [1:39:20, 48.91s/it]
# Scoring conference speeches: 144it [1:40:04, 47.56s/it]
# Scoring conference speeches: 145it [1:40:49, 46.85s/it]
# Scoring conference speeches: 146it [1:41:28, 44.32s/it]
# Scoring conference speeches: 147it [1:42:15, 45.09s/it]
# Scoring conference speeches: 148it [1:42:57, 44.21s/it]
# Scoring conference speeches: 149it [1:43:47, 46.03s/it]
# Scoring conference speeches: 150it [1:44:37, 47.31s/it]
# Scoring conference speeches: 151it [1:45:06, 41.56s/it]
# Scoring conference speeches: 152it [1:45:48, 41.76s/it]
# Scoring conference speeches: 153it [1:46:30, 41.75s/it]
# Scoring conference speeches: 154it [1:46:53, 36.37s/it]
# Scoring conference speeches: 155it [1:47:31, 36.71s/it]
# Scoring conference speeches: 156it [1:47:57, 33.55s/it]
# Scoring conference speeches: 157it [1:48:42, 37.04s/it]
# Scoring conference speeches: 158it [1:49:08, 33.70s/it]
# Scoring conference speeches: 159it [1:49:43, 33.97s/it]
# Scoring conference speeches: 160it [1:50:30, 37.82s/it]
# Scoring conference speeches: 161it [1:51:20, 41.51s/it]
# Scoring conference speeches: 162it [1:51:52, 38.76s/it]
# Scoring conference speeches: 163it [1:52:26, 37.42s/it]
# Scoring conference speeches: 164it [1:53:22, 42.80s/it]
# Scoring conference speeches: 165it [1:54:08, 43.94s/it]
# Scoring conference speeches: 166it [1:54:55, 44.73s/it]
# Scoring conference speeches: 167it [1:55:53, 48.91s/it]
# Scoring conference speeches: 168it [1:56:40, 48.23s/it]
# Scoring conference speeches: 169it [1:57:24, 46.89s/it]
# Scoring conference speeches: 170it [1:58:10, 46.65s/it]
# Scoring conference speeches: 171it [1:59:00, 47.65s/it]
# Scoring conference speeches: 172it [1:59:57, 50.41s/it]
# Scoring conference speeches: 173it [2:00:50, 51.26s/it]
# Scoring conference speeches: 174it [2:01:35, 49.43s/it]
# Scoring conference speeches: 175it [2:02:25, 49.50s/it]
# Scoring conference speeches: 176it [2:03:12, 48.88s/it]
# Scoring conference speeches: 177it [2:04:10, 51.63s/it]
# Scoring conference speeches: 178it [2:04:53, 48.87s/it]
# Scoring conference speeches: 179it [2:05:42, 49.05s/it]
# Scoring conference speeches: 180it [2:06:39, 51.43s/it]
# Scoring conference speeches: 181it [2:07:17, 47.24s/it]
# Scoring conference speeches: 182it [2:08:03, 46.96s/it]
# Scoring conference speeches: 183it [2:09:00, 42.30s/it]
#
# Saving conference speech scores: 100%|██████████| 183/183 [00:00<00:00, 183319.23it/s]

# %%
source_dict = {0:'Manifestos',
               1:'PMQs',
               2:'Conferences'}
cohort_dict = {'1945-1964':(pd.to_datetime('1945-01-01'),pd.to_datetime('1964-10-17')),
               '1964-1979':(pd.to_datetime('1964-10-17'),pd.to_datetime('1979-05-05')),
               '1979-1997':(pd.to_datetime('1979-05-05'),pd.to_datetime('1997-05-03')),
               '1997-now':(pd.to_datetime('1997-05-03'),pd.to_datetime('2022-06-14'))}
cohort_checker = lambda date: [cohort for cohort,date_range in cohort_dict.items() if date>=date_range[0] and date<date_range[1]][0]

sign = lambda num: '-' if num>0 else '+' # Flipped because a neg. t-score indicates mean(sample_2)>mean(sample_1)
stars = lambda num: '***' if num<0.001 else '**' if num<0.01 else '*' if num<0.05 else ''

for score in list(manifestos_scores[0].keys()):
    manifestos_with_scores = manifestos.copy()
    manifestos_with_scores[score] = [score_dict[score] for score_dict in manifestos_scores]
    manifestos_with_scores['cohort'] = manifestos_with_scores['year'].apply(cohort_checker)
    
    pmqs_with_scores = pmqs.copy()
    pmqs_with_scores[score] = [score_dict[score] for score_dict in pmqs_scores]
    pmqs_with_scores['cohort'] = pmqs_with_scores['date'].apply(cohort_checker)
    
    conferences_with_scores = conferences.copy()
    conferences_with_scores[score] = [score_dict[score] for score_dict in conferences_scores]
    conferences_with_scores['cohort'] = conferences_with_scores['year'].apply(cohort_checker)

    cohort_diffs = {0:dict(),1:dict(),2:dict()}
    for idx,df in enumerate([manifestos_with_scores,pmqs_with_scores,conferences_with_scores]):
        cohort_diffs[idx]['1945-64 vs. 1964-79'] = stats.ttest_ind(df[df['cohort']=='1945-1964'][score].to_numpy(),
                                                                   df[df['cohort']=='1964-1979'][score].to_numpy())
        cohort_diffs[idx]['1964-79 vs. 1979-97'] = stats.ttest_ind(df[df['cohort']=='1964-1979'][score].to_numpy(),
                                                                   df[df['cohort']=='1979-1997'][score].to_numpy())
        cohort_diffs[idx]['1979-97 vs. 1997-now'] = stats.ttest_ind(df[df['cohort']=='1979-1997'][score].to_numpy(),
                                                                    df[df['cohort']=='1997-now'][score].to_numpy())
    
    print("\n",score.title())
    for source,cohort_diff in cohort_diffs.items():
        print("\t",source_dict[source])
        for name,diff in cohort_diff.items():
            print("{}:\tChange: {} ; T-stat: {:.2f}{}; P-value: {:.4f}".format(name, sign(diff.statistic), diff.statistic, stars(diff.pvalue), diff.pvalue))
        
    fig,axs = plt.subplots(1,3, figsize=(14,6))
    manifestos_with_scores.boxplot(by='cohort', ax=axs[0])
    axs[0].set_title(score+' - manifestos')
    pmqs_with_scores.boxplot(by='cohort', ax=axs[1])
    axs[1].set_title(score+' - PMQs')
    conferences_with_scores.boxplot(by='cohort', ax=axs[2])
    axs[2].set_title(score+' - conferences')
    plt.show()
# Out:
#  Subjective_Sentence_Freq
# 	 Manifestos
# 1945-64 vs. 1964-79:	Change: - ; T-stat: 0.40; P-value: 0.6889
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -1.03; P-value: 0.3110
# 1979-97 vs. 1997-now:	Change: - ; T-stat: 0.58; P-value: 0.5639
# 	 PMQs
# 1945-64 vs. 1964-79:	Change: - ; T-stat: 0.47; P-value: 0.6360
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -9.08***; P-value: 0.0000
# 1979-97 vs. 1997-now:	Change: + ; T-stat: -4.00***; P-value: 0.0001
# 	 Conferences
# 1945-64 vs. 1964-79:	Change: + ; T-stat: -3.18**; P-value: 0.0024
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -1.50; P-value: 0.1379
# 1979-97 vs. 1997-now:	Change: - ; T-stat: 0.45; P-value: 0.6544
#  Avg_Subjective_Sentence_Score
# 	 Manifestos
# 1945-64 vs. 1964-79:	Change: - ; T-stat: 0.62; P-value: 0.5370
# 1964-79 vs. 1979-97:	Change: - ; T-stat: 0.08; P-value: 0.9352
# 1979-97 vs. 1997-now:	Change: - ; T-stat: 0.53; P-value: 0.6004
# 	 PMQs
# 1945-64 vs. 1964-79:	Change: - ; T-stat: 0.24; P-value: 0.8082
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -6.04***; P-value: 0.0000
# 1979-97 vs. 1997-now:	Change: + ; T-stat: -0.75; P-value: 0.4557
# 	 Conferences
# 1945-64 vs. 1964-79:	Change: + ; T-stat: -1.88; P-value: 0.0657
# 1964-79 vs. 1979-97:	Change: - ; T-stat: 0.34; P-value: 0.7336
# 1979-97 vs. 1997-now:	Change: - ; T-stat: 1.84; P-value: 0.0682
#  Speculative_Sentence_Freq
# 	 Manifestos
# 1945-64 vs. 1964-79:	Change: + ; T-stat: nan; P-value: nan
# 1964-79 vs. 1979-97:	Change: + ; T-stat: nan; P-value: nan
# 1979-97 vs. 1997-now:	Change: + ; T-stat: nan; P-value: nan
# 	 PMQs
# 1945-64 vs. 1964-79:	Change: + ; T-stat: nan; P-value: nan
# 1964-79 vs. 1979-97:	Change: + ; T-stat: nan; P-value: nan
# 1979-97 vs. 1997-now:	Change: + ; T-stat: nan; P-value: nan
# 	 Conferences
# 1945-64 vs. 1964-79:	Change: + ; T-stat: nan; P-value: nan
# 1964-79 vs. 1979-97:	Change: + ; T-stat: nan; P-value: nan
# 1979-97 vs. 1997-now:	Change: + ; T-stat: nan; P-value: nan
#  Modal_Verb_Freq
# 	 Manifestos
# 1945-64 vs. 1964-79:	Change: - ; T-stat: 0.58; P-value: 0.5647
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -0.68; P-value: 0.4994
# 1979-97 vs. 1997-now:	Change: + ; T-stat: -0.69; P-value: 0.4941
# 	 PMQs
# 1945-64 vs. 1964-79:	Change: - ; T-stat: 2.74**; P-value: 0.0066
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -1.62; P-value: 0.1047
# 1979-97 vs. 1997-now:	Change: + ; T-stat: -2.48*; P-value: 0.0131
# 	 Conferences
# 1945-64 vs. 1964-79:	Change: + ; T-stat: -3.11**; P-value: 0.0029
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -2.40*; P-value: 0.0184
# 1979-97 vs. 1997-now:	Change: - ; T-stat: 2.70**; P-value: 0.0080
#  Subjective_Adjective_Freq
# 	 Manifestos
# 1945-64 vs. 1964-79:	Change: - ; T-stat: 0.78; P-value: 0.4416
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -0.54; P-value: 0.5905
# 1979-97 vs. 1997-now:	Change: - ; T-stat: 0.59; P-value: 0.5579
# 	 PMQs
# 1945-64 vs. 1964-79:	Change: - ; T-stat: 0.50; P-value: 0.6176
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -2.67**; P-value: 0.0076
# 1979-97 vs. 1997-now:	Change: + ; T-stat: -11.16***; P-value: 0.0000
# 	 Conferences
# 1945-64 vs. 1964-79:	Change: + ; T-stat: -2.64*; P-value: 0.0106
# 1964-79 vs. 1979-97:	Change: + ; T-stat: -3.18**; P-value: 0.0021
# 1979-97 vs. 1997-now:	Change: - ; T-stat: 0.79; P-value: 0.4282

# %%
party_dict = {'Labour':'LAB',
              'Conservative':'CON',
              'Liberal':'LIB',
              'SDP-Liberal Alliance':'LIB',
              'Liberal Democrat':'LIB',
              np.nan:'NAN'}

for s_idx,scoring_var in enumerate(manifestos_scores[0].keys()):
    plt.clf()
    manifestos_df = pd.DataFrame({'score':[x[s_idx] for x in manifestos_vecs],
                                  'type':['manifesto']*len(manifestos_vecs),
                                  'year':manifestos.drop(manifestos_nans, axis=0).year,
                                  'party':manifestos.drop(manifestos_nans, axis=0).party})
    pmqs_df = pd.DataFrame({'score':[x[s_idx] for x in pmqs_vecs],
                           'type':['PMQs']*len(pmqs_vecs),
                           'year':pmqs.drop(pmqs_nans, axis=0).date,
                           'party':pmqs.drop(pmqs_nans, axis=0).answerer_party.apply(lambda party: party_dict[str(party)] if str(party) in party_dict.keys() else 'NAN')})
    conferences_df = pd.DataFrame({'score':[x[s_idx] for x in conferences_vecs],
                                   'type':['conference']*len(conferences_vecs),
                                   'year':conferences.drop(conferences_nans, axis=0).year,
                                   'party':conferences.drop(conferences_nans, axis=0).party.apply(lambda party: party_dict[party])})
    var_df = pd.DataFrame({'score':[],'type':[],'year':[],'party':[]})
    var_df = var_df.append(manifestos_df)
    var_df = var_df.append(pmqs_df)
    var_df = var_df.append(conferences_df)

    col_dict = {'LAB':'red','CON':'blue','LIB':'gold','SNP':'yellow','UKIP':'purple','BRX':'purple','NAN':'grey'}
    marker_dict = {'manifesto':'s','PMQs':'.','conference':'P'}
    alpha_dict = {'manifesto':0.8,'PMQs':0.2,'conference':0.8}

    plt.style.use('seaborn-whitegrid')
    fig,ax = plt.subplots(1, figsize=(12,8))
    var_df.progress_apply(lambda row: ax.scatter(row.year, row.score,
                                                              color=col_dict[row.party],
                                                              marker=marker_dict[row.type],
                                                              alpha=alpha_dict[row.type]),
                                       axis=1)

    # Plot line of best fit for manifestos
    deg = 2
    x = np.array([date for date in manifestos.drop(manifestos_nans, axis=0).year])
    native_x = [int(xi.timestamp() * 10**9) for xi in x] # convert x to native timestamp
    y = np.array([score_dict[scoring_var] for score_dict in manifestos_scores])
    coefs = np.polyfit(native_x, y, deg=deg)
    xseq = np.linspace(min(native_x)-1, max(native_x)+1, num=500)
    XX = np.vstack([xseq**(deg-i) for i in range(deg+1)]).T # rows 1, x, x**2, ...
    yseq = np.dot(XX, coefs)  # matrix multiplication by coefs calculates the polynomial values
    ax.plot(pd.to_datetime(xseq), yseq, ':', color='black')
    # ...PMQs
    x = np.array([date for date in pmqs.drop(pmqs_nans, axis=0).date])
    native_x = [int(xi.timestamp() * 10**9) for xi in x] # convert x to native timestamp
    y = np.array([score_dict[scoring_var] for score_dict in pmqs_scores])
    coefs = np.polyfit(native_x, y, deg=deg)
    xseq = np.linspace(min(native_x)-1, max(native_x)+1, num=500)
    XX = np.vstack([xseq**(deg-i) for i in range(deg+1)]).T # rows 1, x, x**2, ...
    yseq = np.dot(XX, coefs)  # matrix multiplication by coefs calculates the polynomial values
    ax.plot(pd.to_datetime(xseq), yseq, '--', color='black')
    # ...and conference speeches
    x = np.array([date for date in conferences.drop(conferences_nans, axis=0).year])
    native_x = [int(xi.timestamp() * 10**9) for xi in x] # convert x to native timestamp
    y = np.array([score_dict[scoring_var] for score_dict in conferences_scores])
    coefs = np.polyfit(native_x, y, deg=deg)
    xseq = np.linspace(min(native_x)-1, max(native_x)+1, num=500)
    XX = np.vstack([xseq**(deg-i) for i in range(deg+1)]).T # rows 1, x, x**2, ...
    yseq = np.dot(XX, coefs)  # matrix multiplication by coefs calculates the polynomial values
    ax.plot(pd.to_datetime(xseq), yseq, '-.', color='black')
    ax.set_xlabel("Year")
    ax.set_ylabel(scoring_var)
    ax.set_title(scoring_var+" from 1900 onwards")
    plt.show()
# Out:
# Cleaning:   0%|          | 0/2065 [00:00<?, ?it/s]
# Cleaning:   3%|▎         | 71/2065 [00:00<00:02, 709.65it/s]
# Cleaning:   7%|▋         | 142/2065 [00:00<00:02, 688.98it/s]
# Cleaning:  10%|█         | 211/2065 [00:00<00:02, 677.42it/s]
# Cleaning:  14%|█▎        | 279/2065 [00:00<00:02, 653.05it/s]
# Cleaning:  17%|█▋        | 345/2065 [00:00<00:02, 616.91it/s]
# Cleaning:  20%|█▉        | 407/2065 [00:00<00:02, 580.93it/s]
# Cleaning:  23%|██▎       | 466/2065 [00:00<00:02, 558.52it/s]
# Cleaning:  25%|██▌       | 523/2065 [00:00<00:02, 536.93it/s]
# Cleaning:  28%|██▊       | 577/2065 [00:01<00:02, 504.90it/s]
# Cleaning:  30%|███       | 628/2065 [00:01<00:02, 484.78it/s]
# Cleaning:  33%|███▎      | 677/2065 [00:01<00:02, 470.42it/s]
# Cleaning:  35%|███▌      | 725/2065 [00:01<00:04, 309.26it/s]
# Cleaning:  37%|███▋      | 763/2065 [00:01<00:04, 321.06it/s]
# Cleaning:  39%|███▉      | 803/2065 [00:01<00:03, 337.89it/s]
# Cleaning:  41%|████      | 842/2065 [00:01<00:03, 350.47it/s]
# Cleaning:  43%|████▎     | 881/2065 [00:01<00:03, 356.96it/s]
# Cleaning:  92%|█████████▏| 1903/2065 [00:06<00:00, 195.81it/s]
# Cleaning:  93%|█████████▎| 1924/2065 [00:06<00:00, 199.80it/s]
# Cleaning:  94%|█████████▍| 1945/2065 [00:06<00:00, 191.89it/s]
# Cleaning:  95%|█████████▌| 1965/2065 [00:06<00:00, 184.37it/s]
# Cleaning:  96%|█████████▌| 1986/2065 [00:06<00:00, 191.26it/s]
# Cleaning:  97%|█████████▋| 2007/2065 [00:06<00:00, 196.13it/s]
# Cleaning:  98%|█████████▊| 2027/2065 [00:06<00:00, 196.72it/s]
# Cleaning: 100%|██████████| 2065/2065 [00:06<00:00, 297.16it/s]
# Cleaning:   0%|          | 0/2065 [00:00<?, ?it/s]
# Cleaning:   3%|▎         | 71/2065 [00:00<00:02, 702.93it/s]
# Cleaning:   7%|▋         | 146/2065 [00:00<00:02, 730.33it/s]
# Cleaning:  11%|█         | 220/2065 [00:00<00:02, 687.42it/s]
# Cleaning:  14%|█▍        | 290/2065 [00:00<00:02, 650.23it/s]
# Cleaning:  17%|█▋        | 356/2065 [00:00<00:02, 622.19it/s]
# Cleaning:  20%|██        | 419/2065 [00:00<00:02, 589.45it/s]
# Cleaning:  23%|██▎       | 479/2065 [00:00<00:02, 562.41it/s]
# Cleaning:  26%|██▌       | 536/2065 [00:00<00:02, 532.44it/s]
# Cleaning:  29%|██▊       | 590/2065 [00:01<00:02, 502.99it/s]
# Cleaning:  31%|███       | 641/2065 [00:01<00:02, 498.12it/s]
# Cleaning:  33%|███▎      | 691/2065 [00:01<00:02, 477.42it/s]
# Cleaning:  36%|███▌      | 739/2065 [00:01<00:02, 446.19it/s]
# Cleaning:  38%|███▊      | 784/2065 [00:01<00:02, 431.01it/s]
# Cleaning:  40%|████      | 828/2065 [00:01<00:02, 415.50it/s]
# Cleaning:  42%|████▏     | 870/2065 [00:01<00:04, 251.54it/s]
# Cleaning:  44%|████▍     | 907/2065 [00:02<00:04, 273.42it/s]
# Cleaning:  46%|████▌     | 943/2065 [00:02<00:03, 291.68it/s]
# Cleaning:  47%|████▋     | 978/2065 [00:02<00:03, 304.56it/s]
# Cleaning:  49%|████▉     | 1013/2065 [00:02<00:03, 313.05it/s]
# Cleaning:  51%|█████     | 1048/2065 [00:02<00:03, 318.49it/s]
# Cleaning:  52%|█████▏    | 1083/2065 [00:02<00:03, 315.96it/s]
# Cleaning:  54%|█████▍    | 1117/2065 [00:02<00:03, 314.78it/s]
# Cleaning:  56%|█████▌    | 1150/2065 [00:02<00:03, 292.79it/s]
# Cleaning:  57%|█████▋    | 1181/2065 [00:02<00:03, 271.50it/s]
# Cleaning:  59%|█████▊    | 1210/2065 [00:03<00:03, 251.72it/s]
# Cleaning:  60%|█████▉    | 1236/2065 [00:03<00:03, 245.80it/s]
# Cleaning:  61%|██████    | 1262/2065 [00:03<00:03, 235.59it/s]
# Cleaning:  63%|██████▎   | 1292/2065 [00:03<00:03, 251.52it/s]
# Cleaning:  64%|██████▍   | 1321/2065 [00:03<00:02, 259.11it/s]
# Cleaning:  65%|██████▌   | 1348/2065 [00:03<00:02, 251.72it/s]
# Cleaning:  67%|██████▋   | 1376/2065 [00:03<00:02, 257.63it/s]
# Cleaning:  68%|██████▊   | 1404/2065 [00:03<00:02, 262.77it/s]
# Cleaning:  69%|██████▉   | 1431/2065 [00:03<00:02, 259.65it/s]
# Cleaning:  71%|███████   | 1458/2065 [00:04<00:02, 249.11it/s]
# Cleaning:  72%|███████▏  | 1484/2065 [00:04<00:02, 248.00it/s]
# Cleaning:  73%|███████▎  | 1509/2065 [00:04<00:02, 248.23it/s]
# Cleaning:  74%|███████▍  | 1535/2065 [00:04<00:02, 248.79it/s]
# Cleaning:  76%|███████▌  | 1561/2065 [00:04<00:02, 249.86it/s]
# Cleaning:  77%|███████▋  | 1587/2065 [00:04<00:01, 249.07it/s]
# Cleaning:  78%|███████▊  | 1612/2065 [00:04<00:01, 247.77it/s]
# Cleaning:  79%|███████▉  | 1638/2065 [00:04<00:01, 249.83it/s]
# Cleaning:  81%|████████  | 1663/2065 [00:04<00:01, 246.29it/s]
# Cleaning:  82%|████████▏ | 1688/2065 [00:05<00:01, 239.79it/s]
# Cleaning:  83%|████████▎ | 1713/2065 [00:05<00:01, 241.02it/s]
# Cleaning:  84%|████████▍ | 1738/2065 [00:05<00:01, 231.54it/s]
# Cleaning:  85%|████████▌ | 1762/2065 [00:05<00:01, 226.88it/s]
# Cleaning:  86%|████████▋ | 1785/2065 [00:05<00:01, 224.60it/s]
# Cleaning:  88%|████████▊ | 1808/2065 [00:05<00:01, 222.97it/s]
# Cleaning:  89%|████████▊ | 1831/2065 [00:05<00:01, 223.33it/s]
# Cleaning:  90%|████████▉ | 1855/2065 [00:05<00:00, 224.28it/s]
# Cleaning:  91%|█████████ | 1878/2065 [00:05<00:00, 220.33it/s]
# Cleaning:  92%|█████████▏| 1901/2065 [00:05<00:00, 219.25it/s]
# Cleaning:  93%|█████████▎| 1923/2065 [00:06<00:00, 218.21it/s]
# Cleaning:  94%|█████████▍| 1945/2065 [00:06<00:00, 216.22it/s]
# Cleaning:  95%|█████████▌| 1967/2065 [00:06<00:00, 216.04it/s]
# Cleaning:  96%|█████████▋| 1989/2065 [00:06<00:00, 213.49it/s]
# Cleaning:  97%|█████████▋| 2011/2065 [00:06<00:00, 209.30it/s]
# Cleaning:  98%|█████████▊| 2033/2065 [00:06<00:00, 211.37it/s]
# Cleaning: 100%|██████████| 2065/2065 [00:06<00:00, 304.50it/s]
# Cleaning:   0%|          | 0/2065 [00:00<?, ?it/s]
# Cleaning:   4%|▎         | 76/2065 [00:00<00:02, 759.29it/s]
# Cleaning:   7%|▋         | 152/2065 [00:00<00:02, 729.86it/s]
# Cleaning:  11%|█         | 226/2065 [00:00<00:02, 705.83it/s]
# Cleaning:  14%|█▍        | 297/2065 [00:00<00:02, 672.34it/s]
# Cleaning:  82%|████████▏ | 1693/2065 [00:04<00:01, 228.97it/s]
# Cleaning:  83%|████████▎ | 1717/2065 [00:05<00:01, 227.57it/s]
# Cleaning:  84%|████████▍ | 1740/2065 [00:05<00:01, 226.32it/s]
# Cleaning:  85%|████████▌ | 1763/2065 [00:05<00:01, 213.85it/s]
# Cleaning:  87%|████████▋ | 1787/2065 [00:05<00:01, 218.81it/s]
# Cleaning:  88%|████████▊ | 1810/2065 [00:05<00:01, 220.54it/s]
# Cleaning:  89%|████████▉ | 1833/2065 [00:05<00:01, 215.83it/s]
# Cleaning:  90%|████████▉ | 1856/2065 [00:05<00:00, 217.39it/s]
# Cleaning:  91%|█████████ | 1878/2065 [00:05<00:00, 218.13it/s]
# Cleaning:  92%|█████████▏| 1900/2065 [00:05<00:00, 218.04it/s]
# Cleaning:  93%|█████████▎| 1922/2065 [00:06<00:00, 217.98it/s]
# Cleaning:  94%|█████████▍| 1944/2065 [00:06<00:00, 215.43it/s]
# Cleaning:  95%|█████████▌| 1966/2065 [00:06<00:00, 212.00it/s]
# Cleaning:  96%|█████████▋| 1988/2065 [00:06<00:00, 211.87it/s]
# Cleaning:  97%|█████████▋| 2010/2065 [00:06<00:00, 208.18it/s]
# Cleaning:  98%|█████████▊| 2031/2065 [00:06<00:00, 205.16it/s]
# Cleaning: 100%|██████████| 2065/2065 [00:06<00:00, 307.43it/s]
# Cleaning:   0%|          | 0/2065 [00:00<?, ?it/s]
# Cleaning:   4%|▎         | 77/2065 [00:00<00:02, 754.93it/s]
# Cleaning:   7%|▋         | 154/2065 [00:00<00:02, 759.10it/s]
# Cleaning:  11%|█         | 230/2065 [00:00<00:02, 703.48it/s]
# Cleaning:  15%|█▍        | 301/2065 [00:00<00:02, 670.74it/s]
# Cleaning:  18%|█▊        | 369/2065 [00:00<00:02, 627.41it/s]
# Cleaning:  21%|██        | 433/2065 [00:00<00:02, 593.52it/s]
# Cleaning:  24%|██▍       | 493/2065 [00:00<00:02, 576.76it/s]
# Cleaning:  27%|██▋       | 551/2065 [00:00<00:02, 550.65it/s]
# Cleaning:  29%|██▉       | 607/2065 [00:01<00:02, 514.12it/s]
# Cleaning:  32%|███▏      | 659/2065 [00:01<00:02, 495.44it/s]
# Cleaning:  34%|███▍      | 709/2065 [00:01<00:02, 473.49it/s]
# Cleaning:  37%|███▋      | 757/2065 [00:01<00:02, 455.58it/s]
# Cleaning:  39%|███▉      | 803/2065 [00:01<00:02, 433.30it/s]
# Cleaning:  41%|████      | 847/2065 [00:01<00:02, 409.59it/s]
# Cleaning:  43%|████▎     | 889/2065 [00:01<00:02, 398.56it/s]
# Cleaning:  45%|████▍     | 929/2065 [00:01<00:02, 388.53it/s]
# Cleaning:  47%|████▋     | 968/2065 [00:01<00:02, 379.66it/s]
# Cleaning:  49%|████▊     | 1006/2065 [00:02<00:02, 370.59it/s]
# Cleaning:  51%|█████     | 1043/2065 [00:02<00:02, 360.45it/s]
# Cleaning:  73%|███████▎  | 1502/2065 [00:03<00:02, 260.72it/s]
# Cleaning:  74%|███████▍  | 1529/2065 [00:03<00:02, 254.82it/s]
# Cleaning:  75%|███████▌  | 1556/2065 [00:04<00:01, 257.41it/s]
# Cleaning:  77%|███████▋  | 1582/2065 [00:04<00:03, 152.04it/s]
# Cleaning:  78%|███████▊  | 1608/2065 [00:04<00:02, 172.23it/s]
# Cleaning:  79%|███████▉  | 1631/2065 [00:04<00:02, 184.19it/s]
# Cleaning:  80%|████████  | 1655/2065 [00:04<00:02, 196.38it/s]
# Cleaning:  81%|████████▏ | 1680/2065 [00:04<00:01, 208.22it/s]
# Cleaning:  83%|████████▎ | 1704/2065 [00:04<00:01, 215.42it/s]
# Cleaning:  84%|████████▎ | 1728/2065 [00:04<00:01, 220.26it/s]
# Cleaning:  85%|████████▍ | 1752/2065 [00:05<00:01, 223.59it/s]
# Cleaning:  86%|████████▌ | 1776/2065 [00:05<00:01, 214.47it/s]
# Cleaning:  87%|████████▋ | 1799/2065 [00:05<00:01, 198.07it/s]
# Cleaning:  88%|████████▊ | 1820/2065 [00:05<00:01, 184.21it/s]
# Cleaning:  89%|████████▉ | 1839/2065 [00:05<00:01, 176.99it/s]
# Cleaning:  90%|████████▉ | 1858/2065 [00:05<00:01, 173.20it/s]
# Cleaning:  91%|█████████ | 1876/2065 [00:05<00:01, 169.22it/s]
# Cleaning:  92%|█████████▏| 1894/2065 [00:05<00:01, 167.23it/s]
# Cleaning:  93%|█████████▎| 1915/2065 [00:06<00:00, 177.29it/s]
# Cleaning:  94%|█████████▎| 1935/2065 [00:06<00:00, 183.05it/s]
# Cleaning:  95%|█████████▍| 1957/2065 [00:06<00:00, 192.40it/s]
# Cleaning:  96%|█████████▌| 1978/2065 [00:06<00:00, 196.87it/s]
# Cleaning:  97%|█████████▋| 1998/2065 [00:06<00:00, 197.23it/s]
# Cleaning:  98%|█████████▊| 2018/2065 [00:06<00:00, 197.59it/s]
# Cleaning:  99%|█████████▊| 2039/2065 [00:06<00:00, 199.39it/s]
# Cleaning: 100%|██████████| 2065/2065 [00:06<00:00, 303.44it/s]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
from tqdm import tqdm

current_day = datetime.strftime(datetime.now(), format="%Y-%m-%d")
pm_list = [['Neville Chamberlain',('1937-05-29','1940-05-09')],
               ['Winston Churchill (1)',('1940-05-10','1945-07-26')],
               ['Clement Attlee',('1945-07-27','1951-10-26')],
               ['Winston Churchill (2)',('1951-10-27','1955-04-05')],
               ['Anthony Eden',('1955-04-06','1957-01-09')],
               ['Harold Macmillan',('1957-01-10','1963-10-18')],
               ['Alec Douglas-Home',('1963-10-19','1964-10-16')],
               ['Harold Wilson (1)',('1964-10-17','1970-06-19')],
               ['Edward Heath',('1970-06-20','1974-03-04')],
               ['Harold Wilson (2)',('1974-03-05','1976-04-05')],
               ['James Callaghan',('1976-04-06','1979-05-04')],               
               ['Margaret Thatcher',('1979-05-05','1990-11-28')],
               ['John Major',('1990-11-29','1997-05-02')],
               ['Tony Blair',('1997-05-03','2007-06-27')],
               ['Gordon Brown',('2007-06-28','2010-05-11')],
               ['David Cameron',('2010-05-12','2016-07-13')],
               ['Theresa May',('2016-07-14','2019-07-24')],
               ['Boris Johnson',('2019-07-25',current_day)]]
pmqs_for_boxplot = pd.read_csv('../hansard-pmqs/hansard_pmqs.csv')
pmqs_for_boxplot.date = pd.to_datetime(pmqs_for_boxplot.date)
pmqs_for_boxplot = pmqs_for_boxplot[pmqs_for_boxplot.date>='1937-05-29']
pmqs_for_boxplot = pd.DataFrame({'date':pmqs_for_boxplot.groupby(by='date').answer_text.aggregate(lambda x: ''.join(x)).index,
                     'answer_text':pmqs_for_boxplot.groupby(by='date').answer_text.aggregate(lambda x: ''.join(x)),
                     'answerer_party':pmqs_for_boxplot.groupby(by='date').answerer_party.aggregate(lambda x: x.mode()),
                     'answerer_name':pmqs_for_boxplot.groupby(by='date').answerer_name.aggregate(lambda x: x.mode())})
pmqs_for_boxplot['answerer_name'] = pmqs_for_boxplot.date.apply(lambda date: [pm for pm,(start_date,end_date) in pm_list if date>=pd.to_datetime(start_date) and date<=pd.to_datetime(end_date)][0])
pmqs_for_boxplot['score'] = [x for x in pmqs_scores]
pmqs_for_boxplot = pmqs_for_boxplot[pmqs_for_boxplot.answerer_party.apply(lambda party: party in ['Conservative','Labour'])]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-8eff60c8c865> in <module>
#      31                      'answerer_name':pmqs_for_boxplot.groupby(by='date').answerer_name.aggregate(lambda x: x.mode())})
#      32 pmqs_for_boxplot['answerer_name'] = pmqs_for_boxplot.date.apply(lambda date: [pm for pm,(start_date,end_date) in pm_list if date>=pd.to_datetime(start_date) and date<=pd.to_datetime(end_date)][0])
# ---> 33 pmqs_for_boxplot['score'] = [x for x in pmqs_scores]
#      34 pmqs_for_boxplot = pmqs_for_boxplot[pmqs_for_boxplot.answerer_party.apply(lambda party: party in ['Conservative','Labour'])]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# ~\anaconda3\lib\site-packages\pandas\core\common.py in require_length_match(data, index)
#     529     """
#     530     if len(data) != len(index):
# --> 531         raise ValueError(
#     532             "Length of values "
#     533             f"({len(data)}) "
#
# ValueError: Length of values (1806) does not match length of index (1813)

# %%
for scoring_var in list(pmqs_for_boxplot.score[1].keys()):
    fig,ax = plt.subplots(1, figsize=(26,14))
    ax.boxplot([pmqs_for_boxplot[pmqs_for_boxplot.answerer_name==pm[0]].score.apply(lambda entry: entry[scoring_var]).to_numpy() for pm in pm_list],
               labels=[pm[0] for pm in pm_list])
    ax.set_title(scoring_var+" for Prime Ministers since 1900")
    plt.show()

# %%
import pwlf

party_dict = {'Labour':'LAB',
              'Conservative':'CON',
              'Liberal':'LIB',
              'SDP-Liberal Alliance':'LIB',
              'Liberal Democrat':'LIB',
              np.nan:'NAN'}



for s_idx,scoring_var in enumerate(manifestos_scores[0].keys()):

    plt.clf()
    manifestos_df = pd.DataFrame({'score':[x[s_idx] for x in manifestos_vecs],
                                  'type':['manifesto']*len(manifestos_vecs),
                                  'year':manifestos.drop(manifestos_nans, axis=0).year,
                                  'party':manifestos.drop(manifestos_nans, axis=0).party})
    pmqs_df = pd.DataFrame({'score':[x[s_idx] for x in pmqs_vecs],
                           'type':['PMQs']*len(pmqs_vecs),
                           'year':pmqs.drop(pmqs_nans, axis=0).date,
                           'party':pmqs.drop(pmqs_nans, axis=0).answerer_party.apply(lambda party: party_dict[str(party)] if str(party) in party_dict.keys() else 'NAN')})
    conferences_df = pd.DataFrame({'score':[x[s_idx] for x in conferences_vecs],
                                   'type':['conference']*len(conferences_vecs),
                                   'year':conferences.drop(conferences_nans, axis=0).year,
                                   'party':conferences.drop(conferences_nans, axis=0).party.apply(lambda party: party_dict[party])})
    var_df = pd.DataFrame({'score':[],'type':[],'year':[],'party':[]})
    var_df = var_df.append(manifestos_df)
    var_df = var_df.append(pmqs_df)
    var_df = var_df.append(conferences_df)

    col_dict = {'LAB':'red','CON':'blue','LIB':'gold','SNP':'yellow','UKIP':'purple','BRX':'purple','NAN':'grey'}
    marker_dict = {'manifesto':'s','PMQs':'.','conference':'P'}
    alpha_dict = {'manifesto':0.8,'PMQs':0.2,'conference':0.8}

    plt.style.use('seaborn-whitegrid')
    fig,ax = plt.subplots(1, figsize=(12,8))
    var_df.progress_apply(lambda row: ax.scatter(row.year, row.score,
                                                              color=col_dict[row.party],
                                                              marker=marker_dict[row.type],
                                                              alpha=alpha_dict[row.type]),
                                       axis=1)

    # Plot line of best fit for manifestos
    segments = 4
    x = np.array([date for date in manifestos.drop(manifestos_nans, axis=0).year])
    native_x = [int(xi.timestamp() * 10**9) for xi in x] # convert x to native timestamp
    y = np.array([score_dict[scoring_var] for score_dict in manifestos_scores])
    mani_pwlf = pwlf.PiecewiseLinFit(native_x, y, degree=0)
    mani_pwlf.fit(segments)
    xseq = np.linspace(min(native_x)-1, max(native_x)+1, num=500)
    yseq = mani_pwlf.predict(xseq)
    ax.plot(pd.to_datetime(xseq), yseq, ':', color='black')
    # ...PMQs
    x = np.array([date for date in pmqs.drop(pmqs_nans, axis=0).date])
    native_x = [int(xi.timestamp() * 10**9) for xi in x] # convert x to native timestamp
    y = np.array([score_dict[scoring_var] for score_dict in pmqs_scores])
    pmqs_pwlf = pwlf.PiecewiseLinFit(native_x, y, degree=0)
    pmqs_pwlf.fit(segments)
    xseq = np.linspace(min(native_x)-1, max(native_x)+1, num=500)
    yseq = pmqs_pwlf.predict(xseq)
    ax.plot(pd.to_datetime(xseq), yseq, '--', color='black')
    # ...and conference speeches
    x = np.array([date for date in conferences.drop(conferences_nans, axis=0).year])
    native_x = [int(xi.timestamp() * 10**9) for xi in x] # convert x to native timestamp
    y = np.array([score_dict[scoring_var] for score_dict in conferences_scores])
    conf_pwlf = pwlf.PiecewiseLinFit(native_x, y, degree=0)
    conf_pwlf.fit(segments)
    xseq = np.linspace(min(native_x)-1, max(native_x)+1, num=500)
    yseq = conf_pwlf.predict(xseq)
    ax.plot(pd.to_datetime(xseq), yseq, '-.', color='black')
    ax.set_xlabel("Year")
    ax.set_ylabel(scoring_var)
    ax.set_title(scoring_var+" from 1900 onwards")
    plt.show()
