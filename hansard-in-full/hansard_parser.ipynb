# %%
import pandas as pd
from tqdm import tqdm
tqdm.pandas()

# %% [markdown]
# # Hansard parser from XML files saved to disk

# %%
def read_xml_from_path(path):
    # Read from path - decode bytes to strings
    with open(path, 'rb') as file:
        xml = file.read().decode(errors='replace') # Replace unrecognised utf-8 tokens with '?'
        
    return xml

# %%
def parse_hansard_xml(xml, memberid2personid_lookup, filter_no_speaker=True):
    # Use BeautifulSoup to tidy the XML
    import pandas as pd
    from bs4 import BeautifulSoup
    bs = BeautifulSoup(xml)
    
    # Define a function to parse a chunk of XML for an individual speech
    def parse_speech_xml(speech_xml):
        name = speech_xml.get('speakername')
        speech_id = speech_xml.get('id')
        person_id = speech_xml.get('person_id')
        if pd.isna(person_id):
            member_id = speech_xml.get('speakerid')
            if member_id in memberid2personid_lookup.keys():
                person_id = memberid2personid_lookup[member_id]
        text = speech_xml.find('p')
        if text is not None:
            text = text.get_text()
        return name,speech_id,person_id,text
    
    # Get an XML object for each speech in the debate
    speeches = bs.find_all('speech') 
    
    # Create dictionary to store debate features
    debate_dict = {'name':[],
                   'speech_id':[],
                   'person_id':[],
                   'text':[]}
    
    for speech_xml in speeches:
        name,speech_id,person_id,text = parse_speech_xml(speech_xml)
        if filter_no_speaker: # If we're filtering 'no speaker' lines, then drop speeches with no name
            if name is not None:
                for variable in debate_dict.keys():
                    debate_dict[variable].append(eval(variable))
        else:
            for variable in debate_dict.keys():
                debate_dict[variable].append(eval(variable))
    
    return pd.DataFrame(debate_dict)

# %%
people_df = pd.read_csv('people.csv').drop('Unnamed: 0',axis=1)

lookup = lambda row: {member_id:row.person_id for member_id in eval(row.memberships)}
lookup_list = people_df.progress_apply(lookup, axis=1).to_list()

memberid2personid_lookup = {member_id:person_id for lookup_dict in lookup_list for member_id,person_id in lookup_dict.items()}

target_urls = pd.read_csv('debate_urls.csv').url.to_list()

df = parse_hansard_xml('', memberid2personid_lookup)

for url in tqdm(target_urls):
    filename = 'debates_xml/'+url.split('/')[-1]
    
    speech_xml = read_xml_from_path(filename)
    debate_df = parse_hansard_xml(speech_xml, memberid2personid_lookup)
    
    df = df.append(debate_df)
    
display(df.head())
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 14004/14004 [00:00<00:00, 22370.32it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 18280/18280 [1:50:43<00:00,  2.75it/s]
#                                                 name  \
# 0  Colonel F. B. MILDMAY (addressing himself to t...
# 1                                  Sir HENRY DALZIEL
# 2  Mr. LOWTHER (who was received with general che...
# 3  Mr. SPEAKER-ELECT (standing on the upper step ...
# 4                Mr. BONAR LAW (Leader of the House)
#
#                                    speech_id                       person_id  \
# 0   uk.org.publicwhip/debate/1919-02-04a.3.1  uk.org.publicwhip/person/15282
# 1   uk.org.publicwhip/debate/1919-02-04a.5.0                         unknown
# 2   uk.org.publicwhip/debate/1919-02-04a.8.0                         unknown
# 3  uk.org.publicwhip/debate/1919-02-04a.11.0                         unknown
# 4  uk.org.publicwhip/debate/1919-02-04a.11.3  uk.org.publicwhip/person/20693
#
#                                                 text
# 0  Sir Courtenay Ilbert, in accordance with the G...
# 1  Sir Courtenay Ilbert, I am fully conscious tha...
# 2  Sir Courtenay Ilbert,—In accordance with the a...
# 3  Before taking the Chair, once more as Speaker ...
# 4  Mr. Speaker-Elect,—In the unavoidable absence ...

# %%
date_from_speech_id = lambda x: pd.to_datetime(x.split('/')[-1][:10])

df['speech_date'] = df.speech_id.progress_apply(lambda x: date_from_speech_id(x))
# Out:
# 100%|█████████████████████████████████████████████████████████████████████| 5757506/5757506 [05:37<00:00, 17037.66it/s]

# %%
display(df)
# Out:
#                                                   name  \
# 0    Colonel F. B. MILDMAY (addressing himself to t...
# 1                                    Sir HENRY DALZIEL
# 2    Mr. LOWTHER (who was received with general che...
# 3    Mr. SPEAKER-ELECT (standing on the upper step ...
# 4                  Mr. BONAR LAW (Leader of the House)
# ..                                                 ...
# 170                                     George Freeman
# 171                                        Jim Shannon
# 172                                     George Freeman
# 173                                    Rachael Maskell
# 174                                     George Freeman
#
#                                       speech_id  \
# 0      uk.org.publicwhip/debate/1919-02-04a.3.1
# 1      uk.org.publicwhip/debate/1919-02-04a.5.0
# 2      uk.org.publicwhip/debate/1919-02-04a.8.0
# 3     uk.org.publicwhip/debate/1919-02-04a.11.0
# 4     uk.org.publicwhip/debate/1919-02-04a.11.3
# ..                                          ...
# 170  uk.org.publicwhip/debate/2022-05-10a.125.3
# 171  uk.org.publicwhip/debate/2022-05-10a.128.0
# 172  uk.org.publicwhip/debate/2022-05-10a.128.1
# 173  uk.org.publicwhip/debate/2022-05-10a.128.2
# 174  uk.org.publicwhip/debate/2022-05-10a.128.3
#
#                           person_id  \
# 0    uk.org.publicwhip/person/15282
# 1                           unknown
# 2                           unknown
# 3                           unknown
# 4    uk.org.publicwhip/person/20693
# ..                              ...
# 170  uk.org.publicwhip/person/24817
# 171  uk.org.publicwhip/person/13864
# 172  uk.org.publicwhip/person/24817
# 173  uk.org.publicwhip/person/25433
# 174  uk.org.publicwhip/person/24817
#
#                                                   text speech_date
# 0    Sir Courtenay Ilbert, in accordance with the G...  1919-02-04
# 1    Sir Courtenay Ilbert, I am fully conscious tha...  1919-02-04
# 2    Sir Courtenay Ilbert,—In accordance with the a...  1919-02-04
# 3    Before taking the Chair, once more as Speaker ...  1919-02-04
# 4    Mr. Speaker-Elect,—In the unavoidable absence ...  1919-02-04
# ..                                                 ...         ...
# 170  The hon. Gentleman makes an important point. S...  2022-05-10
# 171  The Minister referred to Queen’s University Be...  2022-05-10
# 172  The hon. Gentleman makes an important point an...  2022-05-10
# 173  This evening’s debate has been excellent. In Y...  2022-05-10
# 174  The hon. Lady, not for the first time, makes a...  2022-05-10
#
# [5757506 rows x 5 columns]

# %%
df.to_csv('hansard_in_full.csv')
