# %%
import time
import pandas as pd
from datetime import datetime

def find_pmqs(start_date, end_date, term, print_url=True):
    
    # Load Selenium, module for browsing
    import undetected_chromedriver as uc
    from selenium import webdriver
    from selenium.common.exceptions import NoSuchElementException
    from selenium.webdriver.common.by import By
    
    # Check what the installed main version of Chrome is - this is needed to launch the chromedriver correctly
    from win32api import HIWORD, LOWORD, GetFileVersionInfo
    def get_chrome_main_version():
        filename = uc.find_chrome_executable()
        info = GetFileVersionInfo(filename, "\\")
        version = (
            HIWORD(info["FileVersionMS"]),
            LOWORD(info["FileVersionMS"]),
            HIWORD(info["FileVersionLS"]),
            LOWORD(info["FileVersionLS"]),
        )
        print(f"Chrome version={'.'.join(map(str, version))}")
        return version[0]
    version_main = get_chrome_main_version()
    
    # Prepare url with search term, start and end dates
    root_url = "https://hansard.parliament.uk/search/Debates?startDate=%s&endDate=%s&searchTerm=%s&house=Commons&partial=False"
    search_term = term.replace(" ","%20")
    url = root_url % (start_date, end_date, search_term)
    if print_url:
        print(url)
        
    # Make request to Hansard url with Selenium
    options = webdriver.ChromeOptions()
    browser = uc.Chrome(version_main=version_main, options=options)
    #browser = webdriver.Firefox()
    browser.get(url)
    
    # Wait for page to load
    time.sleep(5)
    
    # Save search results to a list
    try:
        dates_res = browser.find_element(By.CLASS_NAME, "card-list").text.split("\n")
        #search_res = browser.find_element_by_class_name("card-list").text.split("\n")
    except NoSuchElementException:
        dates_res = None
        temp_pmqs_dates = None
    
    try:
        urls_res = [x.get_property("href") for x in browser.find_element(By.CLASS_NAME, "card-list").find_elements(By.CLASS_NAME, "card-calendar")]
        #search_res = [x.get_property("href") for x in browser.find_element_by_class_name("card-list").find_elements_by_class_name("card-calendar")]
        if len(urls_res)==1:
            print(f"{len(urls_res)} search result for selected time period")
        else: print(f"{len(urls_res)} search results for selected time period")
    except NoSuchElementException:
        print("No search results for selected time period")
        urls_res = None
        
    browser.quit()
    
    if dates_res: 
        temp_pmqs_dates = []
        for i in range(0,len(dates_res),8):
            temp_pmqs_dates.append(dates_res[i+5])
        temp_pmqs_dates = [datetime.strftime(datetime.strptime(x,"%d %B %Y"),"%Y-%m-%d") for x in temp_pmqs_dates]
    
    return temp_pmqs_dates,urls_res

# %%
from dateutil.relativedelta import *
from datetime import timedelta

date_ceiling = datetime.now()

startdate = datetime.strptime("1900-01-01","%Y-%m-%d")
enddate = startdate + relativedelta(days=+29)

pmqs_dates = list()
pmqs_urls = list()

tot_run_time = timedelta()
n = 0

while startdate <= date_ceiling:
    
    go_time = datetime.now()
    
    print(f"Start: {datetime.strftime(startdate,'%d-%m-%Y')}; End: {datetime.strftime(enddate,'%d-%m-%Y')}")
    
    date_res,url_res = find_pmqs(startdate, enddate, "Prime Minister", print_url = False)
    if date_res:
        pmqs_dates.extend(date_res)
    if url_res:
        pmqs_urls.extend(url_res)
        
    startdate = startdate + relativedelta(days=+30)
    enddate = enddate + relativedelta(days=+30)
    
    run_time = datetime.now()-go_time
    tot_run_time += run_time
    n += 1
    avg_run_time = tot_run_time/n
    
    months_left_to_run = ((date_ceiling-startdate)/30).days
    estimated_runtime = avg_run_time*months_left_to_run
    print(f"{months_left_to_run} months left to run, estimated runtime remaining: {estimated_runtime}")
# Out:
# Start: 01-01-1900; End: 30-01-1900
# Chrome version=101.0.4951.67
# No search results for selected time period
# 
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1459 months left to run, estimated runtime remaining: 5:59:39.688201
# Start: 20-07-1902; End: 18-08-1902
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1458 months left to run, estimated runtime remaining: 5:56:06.312030
# Start: 19-08-1902; End: 17-09-1902
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1457 months left to run, estimated runtime remaining: 5:52:24.891711
# Start: 18-09-1902; End: 17-10-1902
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1456 months left to run, estimated runtime remaining: 5:48:59.188816
# Start: 18-10-1902; End: 16-11-1902
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1455 months left to run, estimated runtime remaining: 5:45:53.060760
# Start: 17-11-1902; End: 16-12-1902
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1454 months left to run, estimated runtime remaining: 5:42:46.590090
# Start: 17-12-1902; End: 15-01-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1453 months left to run, estimated runtime remaining: 5:39:51.797216
# Start: 16-01-1903; End: 14-02-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1452 months left to run, estimated runtime remaining: 5:57:32.730816
# Start: 15-02-1903; End: 16-03-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1451 months left to run, estimated runtime remaining: 5:54:16.344695
# Start: 17-03-1903; End: 15-04-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1450 months left to run, estimated runtime remaining: 5:51:17.053550
# Start: 16-04-1903; End: 15-05-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1449 months left to run, estimated runtime remaining: 5:48:25.885098
# Start: 16-05-1903; End: 14-06-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1448 months left to run, estimated runtime remaining: 5:45:52.075712
# Start: 15-06-1903; End: 14-07-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1447 months left to run, estimated runtime remaining: 5:43:17.531315
# Start: 15-07-1903; End: 13-08-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1446 months left to run, estimated runtime remaining: 5:41:09.792900
# Start: 14-08-1903; End: 12-09-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1445 months left to run, estimated runtime remaining: 5:38:57.310035
# Start: 13-09-1903; End: 12-10-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1444 months left to run, estimated runtime remaining: 5:36:45.450136
# Start: 13-10-1903; End: 11-11-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1443 months left to run, estimated runtime remaining: 5:53:26.603613
# Start: 12-11-1903; End: 11-12-1903
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1442 months left to run, estimated runtime remaining: 5:50:58.219602
# Start: 12-12-1903; End: 10-01-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1441 months left to run, estimated runtime remaining: 5:48:36.626555
# Start: 11-01-1904; End: 09-02-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1440 months left to run, estimated runtime remaining: 5:46:26.984640
# Start: 10-02-1904; End: 10-03-1904
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1439 months left to run, estimated runtime remaining: 5:44:22.341980
# Start: 11-03-1904; End: 09-04-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1438 months left to run, estimated runtime remaining: 5:42:20.977266
# Start: 10-04-1904; End: 09-05-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1437 months left to run, estimated runtime remaining: 5:40:18.276957
# Start: 10-05-1904; End: 08-06-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1436 months left to run, estimated runtime remaining: 5:38:19.774188
# Start: 09-06-1904; End: 08-07-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1435 months left to run, estimated runtime remaining: 5:36:32.675685
# Start: 09-07-1904; End: 07-08-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1434 months left to run, estimated runtime remaining: 5:50:59.817210
# Start: 08-08-1904; End: 06-09-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1433 months left to run, estimated runtime remaining: 5:49:01.168428
# Start: 07-09-1904; End: 06-10-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1432 months left to run, estimated runtime remaining: 5:47:08.008968
# Start: 07-10-1904; End: 05-11-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1431 months left to run, estimated runtime remaining: 5:45:18.647640
# Start: 06-11-1904; End: 05-12-1904
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1430 months left to run, estimated runtime remaining: 5:43:26.648920
# Start: 06-12-1904; End: 04-01-1905
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1429 months left to run, estimated runtime remaining: 5:41:42.750409
# Start: 05-01-1905; End: 03-02-1905
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1428 months left to run, estimated runtime remaining: 5:40:02.864160
# Start: 04-02-1905; End: 05-03-1905
# Chrome version=101.0.4951.67
# No search results for selected time period
# 
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1271 months left to run, estimated runtime remaining: 5:13:08.708749
# Start: 28-12-1917; End: 26-01-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1270 months left to run, estimated runtime remaining: 5:12:27.451710
# Start: 27-01-1918; End: 25-02-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1269 months left to run, estimated runtime remaining: 5:11:47.020605
# Start: 26-02-1918; End: 27-03-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1268 months left to run, estimated runtime remaining: 5:11:07.265224
# Start: 28-03-1918; End: 26-04-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1267 months left to run, estimated runtime remaining: 5:10:29.067163
# Start: 27-04-1918; End: 26-05-1918
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1266 months left to run, estimated runtime remaining: 5:12:52.887330
# Start: 27-05-1918; End: 25-06-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1265 months left to run, estimated runtime remaining: 5:12:14.402060
# Start: 26-06-1918; End: 25-07-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1264 months left to run, estimated runtime remaining: 5:11:34.367872
# Start: 26-07-1918; End: 24-08-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1263 months left to run, estimated runtime remaining: 5:10:56.670993
# Start: 25-08-1918; End: 23-09-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1262 months left to run, estimated runtime remaining: 5:10:16.928088
# Start: 24-09-1918; End: 23-10-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1261 months left to run, estimated runtime remaining: 5:09:36.738011
# Start: 24-10-1918; End: 22-11-1918
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1260 months left to run, estimated runtime remaining: 5:09:00.592560
# Start: 23-11-1918; End: 22-12-1918
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1259 months left to run, estimated runtime remaining: 5:08:21.927847
# Start: 23-12-1918; End: 21-01-1919
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1258 months left to run, estimated runtime remaining: 5:07:43.479816
# Start: 22-01-1919; End: 20-02-1919
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1257 months left to run, estimated runtime remaining: 5:14:59.419866
# Start: 21-02-1919; End: 22-03-1919
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1256 months left to run, estimated runtime remaining: 5:14:24.422920
# Start: 23-03-1919; End: 21-04-1919
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1255 months left to run, estimated runtime remaining: 5:13:43.900620
# Start: 22-04-1919; End: 21-05-1919
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1254 months left to run, estimated runtime remaining: 5:13:12.899202
# Start: 22-05-1919; End: 20-06-1919
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1253 months left to run, estimated runtime remaining: 5:12:32.609757
# Start: 21-06-1919; End: 20-07-1919
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1252 months left to run, estimated runtime remaining: 5:11:53.341016
# Start: 21-07-1919; End: 19-08-1919
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 1251 months left to run, estimated runtime remaining: 5:11:14.243703
# Start: 20-08-1919; End: 18-09-1919
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1250 months left to run, estimated runtime remaining: 5:10:35.612500
# Start: 19-09-1919; End: 18-10-1919
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1249 months left to run, estimated runtime remaining: 5:09:57.492594
# Start: 19-10-1919; End: 17-11-1919
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 1248 months left to run, estimated runtime remaining: 5:12:29.134560
# Start: 18-11-1919; End: 17-12-1919
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 1247 months left to run, estimated runtime remaining: 5:11:51.657733
# Start: 18-12-1919; End: 16-01-1920
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1246 months left to run, estimated runtime remaining: 5:11:12.522358
# Start: 17-01-1920; End: 15-02-1920
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1245 months left to run, estimated runtime remaining: 5:10:34.813890
# Start: 16-02-1920; End: 16-03-1920
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 1244 months left to run, estimated runtime remaining: 5:09:57.722872
# Start: 17-03-1920; End: 15-04-1920
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 1243 months left to run, estimated runtime remaining: 5:09:21.329941
# Start: 16-04-1920; End: 15-05-1920
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1242 months left to run, estimated runtime remaining: 5:08:43.607796
# Start: 16-05-1920; End: 14-06-1920
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1241 months left to run, estimated runtime remaining: 5:08:06.348012
# Start: 15-06-1920; End: 14-07-1920
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1240 months left to run, estimated runtime remaining: 5:07:29.349920
# Start: 15-07-1920; End: 13-08-1920
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1239 months left to run, estimated runtime remaining: 5:09:55.423707
# Start: 14-08-1920; End: 12-09-1920
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1238 months left to run, estimated runtime remaining: 5:09:17.023284
# Start: 13-09-1920; End: 12-10-1920
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1237 months left to run, estimated runtime remaining: 5:08:40.058461
# Start: 13-10-1920; End: 11-11-1920
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1236 months left to run, estimated runtime remaining: 5:08:04.303368
# Start: 12-11-1920; End: 11-12-1920
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1235 months left to run, estimated runtime remaining: 5:07:26.015575
# Start: 12-12-1920; End: 10-01-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1234 months left to run, estimated runtime remaining: 5:06:48.213510
# Start: 11-01-1921; End: 09-02-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1233 months left to run, estimated runtime remaining: 5:06:10.766619
# Start: 10-02-1921; End: 11-03-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1232 months left to run, estimated runtime remaining: 5:05:34.150912
# Start: 12-03-1921; End: 10-04-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1231 months left to run, estimated runtime remaining: 5:04:58.216734
# Start: 11-04-1921; End: 10-05-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1230 months left to run, estimated runtime remaining: 5:07:15.987840
# Start: 11-05-1921; End: 09-06-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1229 months left to run, estimated runtime remaining: 5:06:39.311069
# Start: 10-06-1921; End: 09-07-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1228 months left to run, estimated runtime remaining: 5:06:01.591408
# Start: 10-07-1921; End: 08-08-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1227 months left to run, estimated runtime remaining: 5:05:25.706352
# Start: 09-08-1921; End: 07-09-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1226 months left to run, estimated runtime remaining: 5:04:50.072418
# Start: 08-09-1921; End: 07-10-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1225 months left to run, estimated runtime remaining: 5:04:13.794825
# Start: 08-10-1921; End: 06-11-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1224 months left to run, estimated runtime remaining: 5:03:39.652488
# Start: 07-11-1921; End: 06-12-1921
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1223 months left to run, estimated runtime remaining: 5:03:05.141670
# Start: 07-12-1921; End: 05-01-1922
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1222 months left to run, estimated runtime remaining: 5:02:29.525264
# Start: 06-01-1922; End: 04-02-1922
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1221 months left to run, estimated runtime remaining: 5:04:41.779032
# Start: 05-02-1922; End: 06-03-1922
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1220 months left to run, estimated runtime remaining: 5:04:08.929580
# Start: 07-03-1922; End: 05-04-1922
# Chrome version=101.0.4951.67
# No search results for selected time period
# 1219 months left to run, estimated runtime remaining: 5:03:35.349997
# Start: 06-04-1922; End: 05-05-1922
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1218 months left to run, estimated runtime remaining: 5:03:00.353982
# Start: 06-05-1922; End: 04-06-1922
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 1217 months left to run, estimated runtime remaining: 5:02:25.037965
# ...
# 91 months left to run, estimated runtime remaining: 0:22:32.637104
# Start: 29-11-2014; End: 28-12-2014
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 90 months left to run, estimated runtime remaining: 0:22:17.465250
# Start: 29-12-2014; End: 27-01-2015
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 89 months left to run, estimated runtime remaining: 0:22:02.304150
# Start: 28-01-2015; End: 26-02-2015
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 88 months left to run, estimated runtime remaining: 0:21:47.150504
# Start: 27-02-2015; End: 28-03-2015
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 87 months left to run, estimated runtime remaining: 0:21:32.011683
# Start: 29-03-2015; End: 27-04-2015
# Chrome version=101.0.4951.67
# No search results for selected time period
# 86 months left to run, estimated runtime remaining: 0:21:16.878120
# Start: 28-04-2015; End: 27-05-2015
# Chrome version=101.0.4951.67
# No search results for selected time period
# 85 months left to run, estimated runtime remaining: 0:21:03.987910
# Start: 28-05-2015; End: 26-06-2015
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 84 months left to run, estimated runtime remaining: 0:20:48.856644
# Start: 27-06-2015; End: 26-07-2015
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 83 months left to run, estimated runtime remaining: 0:20:33.707186
# Start: 27-07-2015; End: 25-08-2015
# Chrome version=101.0.4951.67
# No search results for selected time period
# 82 months left to run, estimated runtime remaining: 0:20:18.545666
# Start: 26-08-2015; End: 24-09-2015
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 81 months left to run, estimated runtime remaining: 0:20:03.394887
# Start: 25-09-2015; End: 24-10-2015
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 80 months left to run, estimated runtime remaining: 0:19:48.242960
# Start: 25-10-2015; End: 23-11-2015
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 79 months left to run, estimated runtime remaining: 0:19:33.108999
# Start: 24-11-2015; End: 23-12-2015
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 78 months left to run, estimated runtime remaining: 0:19:17.988156
# Start: 24-12-2015; End: 22-01-2016
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 77 months left to run, estimated runtime remaining: 0:19:02.880354
# Start: 23-01-2016; End: 21-02-2016
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 76 months left to run, estimated runtime remaining: 0:18:49.767968
# Start: 22-02-2016; End: 22-03-2016
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 75 months left to run, estimated runtime remaining: 0:18:34.636125
# Start: 23-03-2016; End: 21-04-2016
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 74 months left to run, estimated runtime remaining: 0:18:19.522710
# Start: 22-04-2016; End: 21-05-2016
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 73 months left to run, estimated runtime remaining: 0:18:04.400984
# Start: 22-05-2016; End: 20-06-2016
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 72 months left to run, estimated runtime remaining: 0:17:49.366824
# Start: 21-06-2016; End: 20-07-2016
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 71 months left to run, estimated runtime remaining: 0:17:34.266859
# Start: 21-07-2016; End: 19-08-2016
# Chrome version=101.0.4951.67
# No search results for selected time period
# 70 months left to run, estimated runtime remaining: 0:17:19.177720
# Start: 20-08-2016; End: 18-09-2016
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 69 months left to run, estimated runtime remaining: 0:17:04.087995
# Start: 19-09-2016; End: 18-10-2016
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 68 months left to run, estimated runtime remaining: 0:16:49.005760
# Start: 19-10-2016; End: 17-11-2016
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 67 months left to run, estimated runtime remaining: 0:16:35.674940
# Start: 18-11-2016; End: 17-12-2016
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 66 months left to run, estimated runtime remaining: 0:16:20.580216
# Start: 18-12-2016; End: 16-01-2017
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 65 months left to run, estimated runtime remaining: 0:16:05.493100
# Start: 17-01-2017; End: 15-02-2017
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 64 months left to run, estimated runtime remaining: 0:15:50.409984
# Start: 16-02-2017; End: 17-03-2017
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 63 months left to run, estimated runtime remaining: 0:15:35.336493
# Start: 18-03-2017; End: 16-04-2017
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 62 months left to run, estimated runtime remaining: 0:15:20.269162
# Start: 17-04-2017; End: 16-05-2017
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 61 months left to run, estimated runtime remaining: 0:15:05.212550
# Start: 17-05-2017; End: 15-06-2017
# Chrome version=101.0.4951.67
# No search results for selected time period
# 60 months left to run, estimated runtime remaining: 0:14:50.165160
# Start: 16-06-2017; End: 15-07-2017
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 59 months left to run, estimated runtime remaining: 0:14:35.128828
# Start: 16-07-2017; End: 14-08-2017
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 58 months left to run, estimated runtime remaining: 0:14:21.592378
# Start: 15-08-2017; End: 13-09-2017
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 57 months left to run, estimated runtime remaining: 0:14:06.532479
# Start: 14-09-2017; End: 13-10-2017
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 56 months left to run, estimated runtime remaining: 0:13:51.490576
# Start: 14-10-2017; End: 12-11-2017
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 55 months left to run, estimated runtime remaining: 0:13:36.455475
# Start: 13-11-2017; End: 12-12-2017
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 54 months left to run, estimated runtime remaining: 0:13:21.428688
# Start: 13-12-2017; End: 11-01-2018
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 53 months left to run, estimated runtime remaining: 0:13:06.403188
# Start: 12-01-2018; End: 10-02-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 52 months left to run, estimated runtime remaining: 0:12:51.383132
# Start: 11-02-2018; End: 12-03-2018
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 51 months left to run, estimated runtime remaining: 0:12:36.394056
# Start: 13-03-2018; End: 11-04-2018
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 50 months left to run, estimated runtime remaining: 0:12:22.514000
# Start: 12-04-2018; End: 11-05-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 49 months left to run, estimated runtime remaining: 0:12:07.503196
# Start: 12-05-2018; End: 10-06-2018
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 48 months left to run, estimated runtime remaining: 0:11:52.488288
# Start: 11-06-2018; End: 10-07-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 47 months left to run, estimated runtime remaining: 0:11:37.480047
# Start: 11-07-2018; End: 09-08-2018
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 46 months left to run, estimated runtime remaining: 0:11:22.480610
# Start: 10-08-2018; End: 08-09-2018
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 45 months left to run, estimated runtime remaining: 0:11:07.484865
# Start: 09-09-2018; End: 08-10-2018
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 44 months left to run, estimated runtime remaining: 0:10:52.502708
# Start: 09-10-2018; End: 07-11-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 43 months left to run, estimated runtime remaining: 0:10:37.528750
# Start: 08-11-2018; End: 07-12-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 42 months left to run, estimated runtime remaining: 0:10:23.496216
# Start: 08-12-2018; End: 06-01-2019
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 41 months left to run, estimated runtime remaining: 0:10:08.513103
# Start: 07-01-2019; End: 05-02-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 40 months left to run, estimated runtime remaining: 0:09:53.539160
# Start: 06-02-2019; End: 07-03-2019
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 39 months left to run, estimated runtime remaining: 0:09:38.575842
# Start: 08-03-2019; End: 06-04-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 38 months left to run, estimated runtime remaining: 0:09:23.613150
# Start: 07-04-2019; End: 06-05-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 37 months left to run, estimated runtime remaining: 0:09:08.653834
# Start: 07-05-2019; End: 05-06-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 36 months left to run, estimated runtime remaining: 0:08:53.702556
# Start: 06-06-2019; End: 05-07-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 35 months left to run, estimated runtime remaining: 0:08:38.764715
# Start: 06-07-2019; End: 04-08-2019
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 34 months left to run, estimated runtime remaining: 0:08:24.588152
# Start: 05-08-2019; End: 03-09-2019
# Chrome version=101.0.4951.67
# No search results for selected time period
# 33 months left to run, estimated runtime remaining: 0:08:09.636576
# Start: 04-09-2019; End: 03-10-2019
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 32 months left to run, estimated runtime remaining: 0:07:54.688672
# Start: 04-10-2019; End: 02-11-2019
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 31 months left to run, estimated runtime remaining: 0:07:39.749096
# Start: 03-11-2019; End: 02-12-2019
# Chrome version=101.0.4951.67
# No search results for selected time period
# 30 months left to run, estimated runtime remaining: 0:07:24.821250
# Start: 03-12-2019; End: 01-01-2020
# Chrome version=101.0.4951.67
# No search results for selected time period
# 29 months left to run, estimated runtime remaining: 0:07:09.893680
# Start: 02-01-2020; End: 31-01-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 28 months left to run, estimated runtime remaining: 0:06:54.975204
# Start: 01-02-2020; End: 01-03-2020
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 27 months left to run, estimated runtime remaining: 0:06:40.064508
# Start: 02-03-2020; End: 31-03-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 26 months left to run, estimated runtime remaining: 0:06:25.738340
# Start: 01-04-2020; End: 30-04-2020
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 25 months left to run, estimated runtime remaining: 0:06:10.818150
# Start: 01-05-2020; End: 30-05-2020
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 24 months left to run, estimated runtime remaining: 0:05:55.904184
# Start: 31-05-2020; End: 29-06-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 23 months left to run, estimated runtime remaining: 0:05:41.000714
# Start: 30-06-2020; End: 29-07-2020
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 22 months left to run, estimated runtime remaining: 0:05:26.101358
# Start: 30-07-2020; End: 28-08-2020
# Chrome version=101.0.4951.67
# No search results for selected time period
# 21 months left to run, estimated runtime remaining: 0:05:11.208093
# Start: 29-08-2020; End: 27-09-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 20 months left to run, estimated runtime remaining: 0:04:56.323500
# Start: 28-09-2020; End: 27-10-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 19 months left to run, estimated runtime remaining: 0:04:41.444739
# Start: 28-10-2020; End: 26-11-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 18 months left to run, estimated runtime remaining: 0:04:26.966118
# Start: 27-11-2020; End: 26-12-2020
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 17 months left to run, estimated runtime remaining: 0:04:12.077241
# Start: 27-12-2020; End: 25-01-2021
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 16 months left to run, estimated runtime remaining: 0:03:57.196352
# Start: 26-01-2021; End: 24-02-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 15 months left to run, estimated runtime remaining: 0:03:42.322740
# Start: 25-02-2021; End: 26-03-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 14 months left to run, estimated runtime remaining: 0:03:27.454870
# Start: 27-03-2021; End: 25-04-2021
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 13 months left to run, estimated runtime remaining: 0:03:12.593011
# Start: 26-04-2021; End: 25-05-2021
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 12 months left to run, estimated runtime remaining: 0:02:57.739584
# Start: 26-05-2021; End: 24-06-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 11 months left to run, estimated runtime remaining: 0:02:42.890552
# Start: 25-06-2021; End: 24-07-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 10 months left to run, estimated runtime remaining: 0:02:28.270160
# Start: 25-07-2021; End: 23-08-2021
# Chrome version=101.0.4951.67
# No search results for selected time period
# 9 months left to run, estimated runtime remaining: 0:02:13.413525
# Start: 24-08-2021; End: 22-09-2021
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 8 months left to run, estimated runtime remaining: 0:01:58.563632
# Start: 23-09-2021; End: 22-10-2021
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 7 months left to run, estimated runtime remaining: 0:01:43.720638
# Start: 23-10-2021; End: 21-11-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 6 months left to run, estimated runtime remaining: 0:01:28.883700
# Start: 22-11-2021; End: 21-12-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 5 months left to run, estimated runtime remaining: 0:01:14.053380
# Start: 22-12-2021; End: 20-01-2022
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 4 months left to run, estimated runtime remaining: 0:00:59.229828
# Start: 21-01-2022; End: 19-02-2022
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 3 months left to run, estimated runtime remaining: 0:00:44.413422
# Start: 20-02-2022; End: 21-03-2022
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 2 months left to run, estimated runtime remaining: 0:00:29.602468
# Start: 22-03-2022; End: 20-04-2022
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 1 months left to run, estimated runtime remaining: 0:00:14.822827
# Start: 21-04-2022; End: 20-05-2022
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 0 months left to run, estimated runtime remaining: 0:00:00
# Start: 21-05-2022; End: 19-06-2022
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# -1 months left to run, estimated runtime remaining: -1 day, 23:59:45.183825

# %%
pmqs_dates = pd.Series(pmqs_dates, name='date')
pmqs_dates = pmqs_dates.drop_duplicates()
pmqs_dates.to_csv('pmqs_dates.csv')
