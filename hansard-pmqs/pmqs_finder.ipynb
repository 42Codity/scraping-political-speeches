# %%
import time
import pandas as pd
from datetime import datetime

def find_pmqs(start_date, end_date, term, print_url=True):
    
    # Load Selenium, module for browsing
    import undetected_chromedriver as uc
    from selenium import webdriver
    from selenium.common.exceptions import NoSuchElementException
    from selenium.webdriver.common.by import By
    
    # Check what the installed main version of Chrome is - this is needed to launch the chromedriver correctly
    from win32api import HIWORD, LOWORD, GetFileVersionInfo
    def get_chrome_main_version():
        filename = uc.find_chrome_executable()
        info = GetFileVersionInfo(filename, "\\")
        version = (
            HIWORD(info["FileVersionMS"]),
            LOWORD(info["FileVersionMS"]),
            HIWORD(info["FileVersionLS"]),
            LOWORD(info["FileVersionLS"]),
        )
        print(f"Chrome version={'.'.join(map(str, version))}")
        return version[0]
    version_main = get_chrome_main_version()
    
    # Prepare url with search term, start and end dates
    root_url = "https://hansard.parliament.uk/search/Debates?startDate=%s&endDate=%s&searchTerm=%s&house=Commons&partial=False"
    search_term = term.replace(" ","%20")
    url = root_url % (start_date, end_date, search_term)
    if print_url:
        print(url)
        
    # Make request to Hansard url with Selenium
    options = webdriver.ChromeOptions()
    browser = uc.Chrome(version_main=version_main, options=options)
    #browser = webdriver.Firefox()
    browser.get(url)
    
    # Wait for page to load
    time.sleep(5)
    
    # Save search results to a list
    try:
        dates_res = browser.find_element(By.CLASS_NAME, "card-list").text.split("\n")
        #search_res = browser.find_element_by_class_name("card-list").text.split("\n")
    except NoSuchElementException:
        dates_res = None
        temp_pmqs_dates = None
    
    try:
        urls_res = [x.get_property("href") for x in browser.find_element(By.CLASS_NAME, "card-list").find_elements(By.CLASS_NAME, "card-calendar")]
        #search_res = [x.get_property("href") for x in browser.find_element_by_class_name("card-list").find_elements_by_class_name("card-calendar")]
        if len(urls_res)==1:
            print(f"{len(urls_res)} search result for selected time period")
        else: print(f"{len(urls_res)} search results for selected time period")
    except NoSuchElementException:
        print("No search results for selected time period")
        urls_res = None
        
    browser.quit()
    
    if dates_res: 
        temp_pmqs_dates = []
        for i in range(0,len(dates_res),8):
            temp_pmqs_dates.append(dates_res[i+5])
        temp_pmqs_dates = [datetime.strftime(datetime.strptime(x,"%d %B %Y"),"%Y-%m-%d") for x in temp_pmqs_dates]
    
    return temp_pmqs_dates,urls_res

# %%
from dateutil.relativedelta import *
from datetime import timedelta

date_ceiling = datetime.now()

startdate = datetime.strptime("1945-01-01","%Y-%m-%d")
enddate = startdate + relativedelta(days=+29)

pmqs_dates = list()
pmqs_urls = list()

tot_run_time = timedelta()
n = 0

while startdate <= date_ceiling:
    
    go_time = datetime.now()
    
    print(f"Start: {datetime.strftime(startdate,'%d-%m-%Y')}; End: {datetime.strftime(enddate,'%d-%m-%Y')}")
    
    date_res,url_res = find_pmqs(startdate, enddate, "Prime Minister", print_url = False)
    if date_res:
        pmqs_dates.extend(date_res)
    if url_res:
        pmqs_urls.extend(url_res)
        
    startdate = startdate + relativedelta(days=+30)
    enddate = enddate + relativedelta(days=+30)
    
    run_time = datetime.now()-go_time
    tot_run_time += run_time
    n += 1
    avg_run_time = tot_run_time/n
    
    months_left_to_run = ((date_ceiling-startdate)/30).days
    estimated_runtime = avg_run_time*months_left_to_run
    print(f"{months_left_to_run} months left to run, estimated runtime remaining: {estimated_runtime}")
# Out:
# Start: 01-01-1945; End: 30-01-1945
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 941 months left to run, estimated runtime remaining: 2:48:56.509401
# Start: 31-01-1945; End: 01-03-1945
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 940 months left to run, estimated runtime remaining: 2:44:49.574560
# Start: 02-03-1945; End: 31-03-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 939 months left to run, estimated runtime remaining: 3:08:39.669414
# Start: 01-04-1945; End: 30-04-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 938 months left to run, estimated runtime remaining: 3:02:14.258496
# Start: 01-05-1945; End: 30-05-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 937 months left to run, estimated runtime remaining: 2:57:30.465783
# Start: 31-05-1945; End: 29-06-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 936 months left to run, estimated runtime remaining: 2:54:44.629272
# Start: 30-06-1945; End: 29-07-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 935 months left to run, estimated runtime remaining: 2:53:02.632700
# Start: 30-07-1945; End: 28-08-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 934 months left to run, estimated runtime remaining: 2:51:45.018140
# Start: 29-08-1945; End: 27-09-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 933 months left to run, estimated runtime remaining: 2:50:39.214098
# Start: 28-09-1945; End: 27-10-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 932 months left to run, estimated runtime remaining: 2:49:45.809360
# Start: 28-10-1945; End: 26-11-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 931 months left to run, estimated runtime remaining: 3:34:14.709882
# Start: 27-11-1945; End: 26-12-1945
# Chrome version=101.0.4951.67
# No search results for selected time period
# 930 months left to run, estimated runtime remaining: 3:29:45.951330
# Start: 27-12-1945; End: 25-01-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 929 months left to run, estimated runtime remaining: 3:25:51.064290
# Start: 26-01-1946; End: 24-02-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 928 months left to run, estimated runtime remaining: 3:22:27.204480
# Start: 25-02-1946; End: 26-03-1946
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 927 months left to run, estimated runtime remaining: 3:19:25.916232
# Start: 27-03-1946; End: 25-04-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 926 months left to run, estimated runtime remaining: 3:16:40.499520
# Start: 26-04-1946; End: 25-05-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 925 months left to run, estimated runtime remaining: 3:14:34.867150
# Start: 26-05-1946; End: 24-06-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 924 months left to run, estimated runtime remaining: 3:12:11.376780
# Start: 25-06-1946; End: 24-07-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 923 months left to run, estimated runtime remaining: 3:10:08.617818
# Start: 25-07-1946; End: 23-08-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 922 months left to run, estimated runtime remaining: 3:47:10.989066
# Start: 24-08-1946; End: 22-09-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 921 months left to run, estimated runtime remaining: 3:43:17.642403
# Start: 23-09-1946; End: 22-10-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 920 months left to run, estimated runtime remaining: 3:39:38.617280
# Start: 23-10-1946; End: 21-11-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 919 months left to run, estimated runtime remaining: 3:36:23.732171
# Start: 22-11-1946; End: 21-12-1946
# Chrome version=101.0.4951.67
# No search results for selected time period
# 918 months left to run, estimated runtime remaining: 3:33:18.075762
# Start: 22-12-1946; End: 20-01-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 917 months left to run, estimated runtime remaining: 3:30:39.902324
# Start: 21-01-1947; End: 19-02-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 916 months left to run, estimated runtime remaining: 3:28:04.784132
# Start: 20-02-1947; End: 21-03-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 915 months left to run, estimated runtime remaining: 3:25:40.652580
# Start: 22-03-1947; End: 20-04-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 914 months left to run, estimated runtime remaining: 3:23:25.350350
# Start: 21-04-1947; End: 20-05-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 913 months left to run, estimated runtime remaining: 3:40:49.174796
# Start: 21-05-1947; End: 19-06-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 912 months left to run, estimated runtime remaining: 3:38:10.019904
# Start: 20-06-1947; End: 19-07-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 911 months left to run, estimated runtime remaining: 3:35:40.217510
# Start: 20-07-1947; End: 18-08-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 910 months left to run, estimated runtime remaining: 3:33:18.359210
# Start: 19-08-1947; End: 17-09-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 909 months left to run, estimated runtime remaining: 3:31:04.306170
# Start: 18-09-1947; End: 17-10-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 908 months left to run, estimated runtime remaining: 3:28:53.783208
# Start: 18-10-1947; End: 16-11-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 907 months left to run, estimated runtime remaining: 3:26:54.286772
# Start: 17-11-1947; End: 16-12-1947
# Chrome version=101.0.4951.67
# No search results for selected time period
# 906 months left to run, estimated runtime remaining: 3:25:04.505592
# Start: 17-12-1947; End: 15-01-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 905 months left to run, estimated runtime remaining: 3:23:23.654405
# Start: 16-01-1948; End: 14-02-1948
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 904 months left to run, estimated runtime remaining: 3:36:23.143136
# Start: 15-02-1948; End: 15-03-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 903 months left to run, estimated runtime remaining: 3:34:35.325267
# Start: 16-03-1948; End: 14-04-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 902 months left to run, estimated runtime remaining: 3:32:38.749410
# Start: 15-04-1948; End: 14-05-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 901 months left to run, estimated runtime remaining: 3:30:50.041802
# Start: 15-05-1948; End: 13-06-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 900 months left to run, estimated runtime remaining: 3:29:01.886100
# Start: 14-06-1948; End: 13-07-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 899 months left to run, estimated runtime remaining: 3:27:21.771632
# Start: 14-07-1948; End: 12-08-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 898 months left to run, estimated runtime remaining: 3:25:46.364030
# Start: 13-08-1948; End: 11-09-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 897 months left to run, estimated runtime remaining: 3:24:18.190308
# Start: 12-09-1948; End: 11-10-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 896 months left to run, estimated runtime remaining: 3:22:51.629568
# Start: 12-10-1948; End: 10-11-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 895 months left to run, estimated runtime remaining: 3:33:07.171090
# Start: 11-11-1948; End: 10-12-1948
# Chrome version=101.0.4951.67
# No search results for selected time period
# 894 months left to run, estimated runtime remaining: 3:31:51.276420
# Start: 11-12-1948; End: 09-01-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 893 months left to run, estimated runtime remaining: 3:30:16.087001
# Start: 10-01-1949; End: 08-02-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 892 months left to run, estimated runtime remaining: 3:28:44.395384
# Start: 09-02-1949; End: 10-03-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 891 months left to run, estimated runtime remaining: 3:27:15.072210
# Start: 11-03-1949; End: 09-04-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 890 months left to run, estimated runtime remaining: 3:25:49.227040
# Start: 10-04-1949; End: 09-05-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 889 months left to run, estimated runtime remaining: 3:24:25.549002
# Start: 10-05-1949; End: 08-06-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 888 months left to run, estimated runtime remaining: 3:23:06.205152
# Start: 09-06-1949; End: 08-07-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 887 months left to run, estimated runtime remaining: 3:21:51.454574
# Start: 09-07-1949; End: 07-08-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 886 months left to run, estimated runtime remaining: 3:30:23.354994
# Start: 08-08-1949; End: 06-09-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 885 months left to run, estimated runtime remaining: 3:28:58.520700
# Start: 07-09-1949; End: 06-10-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 884 months left to run, estimated runtime remaining: 3:27:38.608032
# Start: 07-10-1949; End: 05-11-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 883 months left to run, estimated runtime remaining: 3:26:20.115628
# Start: 06-11-1949; End: 05-12-1949
# Chrome version=101.0.4951.67
# No search results for selected time period
# 882 months left to run, estimated runtime remaining: 3:25:02.578764
# Start: 06-12-1949; End: 04-01-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 881 months left to run, estimated runtime remaining: 3:23:47.939934
# Start: 05-01-1950; End: 03-02-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 880 months left to run, estimated runtime remaining: 3:22:34.823120
# Start: 04-02-1950; End: 05-03-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 879 months left to run, estimated runtime remaining: 3:21:25.401765
# Start: 06-03-1950; End: 04-04-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 878 months left to run, estimated runtime remaining: 3:20:19.949066
# Start: 05-04-1950; End: 04-05-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 877 months left to run, estimated runtime remaining: 3:27:34.170883
# Start: 05-05-1950; End: 03-06-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 876 months left to run, estimated runtime remaining: 3:26:22.338840
# Start: 04-06-1950; End: 03-07-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 875 months left to run, estimated runtime remaining: 3:25:11.304250
# Start: 04-07-1950; End: 02-08-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 874 months left to run, estimated runtime remaining: 3:24:02.367964
# Start: 03-08-1950; End: 01-09-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 873 months left to run, estimated runtime remaining: 3:22:55.458624
# Start: 02-09-1950; End: 01-10-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 872 months left to run, estimated runtime remaining: 3:21:49.928776
# Start: 02-10-1950; End: 31-10-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 871 months left to run, estimated runtime remaining: 3:20:45.937839
# Start: 01-11-1950; End: 30-11-1950
# Chrome version=101.0.4951.67
# No search results for selected time period
# 870 months left to run, estimated runtime remaining: 3:19:43.216440
# Start: 01-12-1950; End: 30-12-1950
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 869 months left to run, estimated runtime remaining: 3:18:43.137963
# Start: 31-12-1950; End: 29-01-1951
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 868 months left to run, estimated runtime remaining: 3:24:55.305064
# Start: 30-01-1951; End: 28-02-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 867 months left to run, estimated runtime remaining: 3:23:59.223117
# Start: 01-03-1951; End: 30-03-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 866 months left to run, estimated runtime remaining: 3:22:59.547838
# Start: 31-03-1951; End: 29-04-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 865 months left to run, estimated runtime remaining: 3:21:55.999640
# Start: 30-04-1951; End: 29-05-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 864 months left to run, estimated runtime remaining: 3:20:57.447456
# Start: 30-05-1951; End: 28-06-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 863 months left to run, estimated runtime remaining: 3:19:56.863324
# Start: 29-06-1951; End: 28-07-1951
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 862 months left to run, estimated runtime remaining: 3:18:58.803440
# Start: 29-07-1951; End: 27-08-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 861 months left to run, estimated runtime remaining: 3:18:02.468997
# Start: 28-08-1951; End: 26-09-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 860 months left to run, estimated runtime remaining: 3:22:45.799940
# Start: 27-09-1951; End: 26-10-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 859 months left to run, estimated runtime remaining: 3:21:46.580213
# Start: 27-10-1951; End: 25-11-1951
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 858 months left to run, estimated runtime remaining: 3:20:50.442690
# Start: 26-11-1951; End: 25-12-1951
# Chrome version=101.0.4951.67
# No search results for selected time period
# 857 months left to run, estimated runtime remaining: 3:19:52.507487
# Start: 26-12-1951; End: 24-01-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 856 months left to run, estimated runtime remaining: 3:18:57.157112
# Start: 25-01-1952; End: 23-02-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 855 months left to run, estimated runtime remaining: 3:18:03.906630
# Start: 24-02-1952; End: 24-03-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 854 months left to run, estimated runtime remaining: 3:17:08.850502
# Start: 25-03-1952; End: 23-04-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 853 months left to run, estimated runtime remaining: 3:16:15.771625
# Start: 24-04-1952; End: 23-05-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 852 months left to run, estimated runtime remaining: 3:20:26.879712
# Start: 24-05-1952; End: 22-06-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 851 months left to run, estimated runtime remaining: 3:19:31.876510
# Start: 23-06-1952; End: 22-07-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 850 months left to run, estimated runtime remaining: 3:18:38.072700
# Start: 23-07-1952; End: 21-08-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 849 months left to run, estimated runtime remaining: 3:17:44.926122
# Start: 22-08-1952; End: 20-09-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 848 months left to run, estimated runtime remaining: 3:16:52.766352
# Start: 21-09-1952; End: 20-10-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 847 months left to run, estimated runtime remaining: 3:16:02.577827
# Start: 21-10-1952; End: 19-11-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 846 months left to run, estimated runtime remaining: 3:15:13.034124
# Start: 20-11-1952; End: 19-12-1952
# Chrome version=101.0.4951.67
# No search results for selected time period
# 845 months left to run, estimated runtime remaining: 3:14:25.884100
# Start: 20-12-1952; End: 18-01-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 844 months left to run, estimated runtime remaining: 3:13:38.806152
# Start: 19-01-1953; End: 17-02-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 843 months left to run, estimated runtime remaining: 3:18:05.918964
# Start: 18-02-1953; End: 19-03-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 842 months left to run, estimated runtime remaining: 3:17:15.999052
# Start: 20-03-1953; End: 18-04-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 841 months left to run, estimated runtime remaining: 3:16:29.198552
# Start: 19-04-1953; End: 18-05-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 840 months left to run, estimated runtime remaining: 3:15:39.305760
# Start: 19-05-1953; End: 17-06-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 839 months left to run, estimated runtime remaining: 3:14:50.678018
# Start: 18-06-1953; End: 17-07-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 838 months left to run, estimated runtime remaining: 3:14:03.172838
# Start: 18-07-1953; End: 16-08-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 837 months left to run, estimated runtime remaining: 3:13:15.493332
# Start: 17-08-1953; End: 15-09-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 836 months left to run, estimated runtime remaining: 3:12:29.000584
# Start: 16-09-1953; End: 15-10-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 835 months left to run, estimated runtime remaining: 3:11:43.669750
# Start: 16-10-1953; End: 14-11-1953
# Chrome version=101.0.4951.67
# No search results for selected time period
# 834 months left to run, estimated runtime remaining: 3:15:42.463962
# Start: 15-11-1953; End: 14-12-1953
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 833 months left to run, estimated runtime remaining: 3:14:54.562803
# Start: 15-12-1953; End: 13-01-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 832 months left to run, estimated runtime remaining: 3:14:08.894400
# Start: 14-01-1954; End: 12-02-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 831 months left to run, estimated runtime remaining: 3:13:23.262141
# Start: 13-02-1954; End: 14-03-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 830 months left to run, estimated runtime remaining: 3:12:38.897890
# Start: 15-03-1954; End: 13-04-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 829 months left to run, estimated runtime remaining: 3:12:02.012352
# Start: 14-04-1954; End: 13-05-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 828 months left to run, estimated runtime remaining: 3:11:17.849436
# Start: 14-05-1954; End: 12-06-1954
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 827 months left to run, estimated runtime remaining: 3:10:34.651128
# Start: 13-06-1954; End: 12-07-1954
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 826 months left to run, estimated runtime remaining: 3:09:51.917768
# Start: 13-07-1954; End: 11-08-1954
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 825 months left to run, estimated runtime remaining: 3:13:32.082075
# Start: 12-08-1954; End: 10-09-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 824 months left to run, estimated runtime remaining: 3:12:48.606504
# Start: 11-09-1954; End: 10-10-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 823 months left to run, estimated runtime remaining: 3:12:10.661252
# Start: 11-10-1954; End: 09-11-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 822 months left to run, estimated runtime remaining: 3:11:27.964572
# Start: 10-11-1954; End: 09-12-1954
# Chrome version=101.0.4951.67
# No search results for selected time period
# 821 months left to run, estimated runtime remaining: 3:10:44.969880
# Start: 10-12-1954; End: 08-01-1955
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 820 months left to run, estimated runtime remaining: 3:10:17.862040
# Start: 09-01-1955; End: 07-02-1955
# Chrome version=101.0.4951.67
# No search results for selected time period
# 819 months left to run, estimated runtime remaining: 3:09:37.227771
# Start: 08-02-1955; End: 09-03-1955
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 818 months left to run, estimated runtime remaining: 3:08:56.396968
# Start: 10-03-1955; End: 08-04-1955
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 817 months left to run, estimated runtime remaining: 3:08:16.736615
# Start: 09-04-1955; End: 08-05-1955
# Chrome version=101.0.4951.67
# No search results for selected time period
# 816 months left to run, estimated runtime remaining: 3:17:02.527056
# Start: 09-05-1955; End: 07-06-1955
# Chrome version=101.0.4951.67
# No search results for selected time period
# 815 months left to run, estimated runtime remaining: 3:16:19.638360
# Start: 08-06-1955; End: 07-07-1955
# Chrome version=101.0.4951.67
# No search results for selected time period
# 814 months left to run, estimated runtime remaining: 3:15:36.342354
# Start: 08-07-1955; End: 06-08-1955
# Chrome version=101.0.4951.67
# No search results for selected time period
# 813 months left to run, estimated runtime remaining: 3:14:58.309032
# Start: 07-08-1955; End: 05-09-1955
# Chrome version=101.0.4951.67
# No search results for selected time period
# 812 months left to run, estimated runtime remaining: 3:14:15.161364
# Start: 06-09-1955; End: 05-10-1955
# Chrome version=101.0.4951.67
# No search results for selected time period
# 811 months left to run, estimated runtime remaining: 3:13:33.011503
# Start: 06-10-1955; End: 04-11-1955
# Chrome version=101.0.4951.67
# No search results for selected time period
# 810 months left to run, estimated runtime remaining: 3:12:50.664510
# Start: 05-11-1955; End: 04-12-1955
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 809 months left to run, estimated runtime remaining: 3:12:10.549178
# Start: 05-12-1955; End: 03-01-1956
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 808 months left to run, estimated runtime remaining: 3:11:29.423064
# Start: 04-01-1956; End: 02-02-1956
# Chrome version=101.0.4951.67
# No search results for selected time period
# 807 months left to run, estimated runtime remaining: 3:14:28.670433
# Start: 03-02-1956; End: 03-03-1956
# Chrome version=101.0.4951.67
# No search results for selected time period
# 806 months left to run, estimated runtime remaining: 3:13:46.392024
# Start: 04-03-1956; End: 02-04-1956
# Chrome version=101.0.4951.67
# No search results for selected time period
# 805 months left to run, estimated runtime remaining: 3:13:04.642300
# Start: 03-04-1956; End: 02-05-1956
# Chrome version=101.0.4951.67
# No search results for selected time period
# 804 months left to run, estimated runtime remaining: 3:12:23.807076
# Start: 03-05-1956; End: 01-06-1956
# Chrome version=101.0.4951.67
# No search results for selected time period
# 803 months left to run, estimated runtime remaining: 3:11:42.452247
# Start: 02-06-1956; End: 01-07-1956
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 802 months left to run, estimated runtime remaining: 3:11:04.275616
# Start: 02-07-1956; End: 31-07-1956
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 801 months left to run, estimated runtime remaining: 3:10:24.246480
# Start: 01-08-1956; End: 30-08-1956
# Chrome version=101.0.4951.67
# No search results for selected time period
# 800 months left to run, estimated runtime remaining: 3:09:44.566400
# Start: 31-08-1956; End: 29-09-1956
# Chrome version=101.0.4951.67
# No search results for selected time period
# 799 months left to run, estimated runtime remaining: 3:12:06.183039
# Start: 30-09-1956; End: 29-10-1956
# Chrome version=101.0.4951.67
# No search results for selected time period
# 798 months left to run, estimated runtime remaining: 3:11:25.864572
# Start: 30-10-1956; End: 28-11-1956
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 797 months left to run, estimated runtime remaining: 3:10:48.120752
# Start: 29-11-1956; End: 28-12-1956
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 796 months left to run, estimated runtime remaining: 3:10:11.970216
# Start: 29-12-1956; End: 27-01-1957
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 795 months left to run, estimated runtime remaining: 3:09:34.976070
# Start: 28-01-1957; End: 26-02-1957
# Chrome version=101.0.4951.67
# 7 search results for selected time period
# 794 months left to run, estimated runtime remaining: 3:08:57.948408
# Start: 27-02-1957; End: 28-03-1957
# Chrome version=101.0.4951.67
# No search results for selected time period
# 793 months left to run, estimated runtime remaining: 3:08:22.567939
# Start: 29-03-1957; End: 27-04-1957
# Chrome version=101.0.4951.67
# No search results for selected time period
# 792 months left to run, estimated runtime remaining: 3:07:46.038432
# Start: 28-04-1957; End: 27-05-1957
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 791 months left to run, estimated runtime remaining: 3:09:59.074897
# Start: 28-05-1957; End: 26-06-1957
# Chrome version=101.0.4951.67
# No search results for selected time period
# 790 months left to run, estimated runtime remaining: 3:09:20.682690
# Start: 27-06-1957; End: 26-07-1957
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 789 months left to run, estimated runtime remaining: 3:08:47.033121
# Start: 27-07-1957; End: 25-08-1957
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 788 months left to run, estimated runtime remaining: 3:08:11.739772
# Start: 26-08-1957; End: 24-09-1957
# Chrome version=101.0.4951.67
# No search results for selected time period
# 787 months left to run, estimated runtime remaining: 3:07:35.843205
# Start: 25-09-1957; End: 24-10-1957
# Chrome version=101.0.4951.67
# No search results for selected time period
# 786 months left to run, estimated runtime remaining: 3:07:00.761508
# Start: 25-10-1957; End: 23-11-1957
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 785 months left to run, estimated runtime remaining: 3:06:24.896660
# Start: 24-11-1957; End: 23-12-1957
# Chrome version=101.0.4951.67
# No search results for selected time period
# 784 months left to run, estimated runtime remaining: 3:05:50.687744
# Start: 24-12-1957; End: 22-01-1958
# Chrome version=101.0.4951.67
# No search results for selected time period
# 783 months left to run, estimated runtime remaining: 3:07:56.073045
# Start: 23-01-1958; End: 21-02-1958
# Chrome version=101.0.4951.67
# No search results for selected time period
# 782 months left to run, estimated runtime remaining: 3:07:20.121574
# Start: 22-02-1958; End: 23-03-1958
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 781 months left to run, estimated runtime remaining: 3:06:44.827370
# Start: 24-03-1958; End: 22-04-1958
# Chrome version=101.0.4951.67
# No search results for selected time period
# 780 months left to run, estimated runtime remaining: 3:06:11.454840
# Start: 23-04-1958; End: 22-05-1958
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 779 months left to run, estimated runtime remaining: 3:05:36.699292
# Start: 23-05-1958; End: 21-06-1958
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 778 months left to run, estimated runtime remaining: 3:05:02.502682
# Start: 22-06-1958; End: 21-07-1958
# Chrome version=101.0.4951.67
# No search results for selected time period
# 777 months left to run, estimated runtime remaining: 3:04:26.724753
# Start: 22-07-1958; End: 20-08-1958
# Chrome version=101.0.4951.67
# No search results for selected time period
# 776 months left to run, estimated runtime remaining: 3:03:51.287752
# Start: 21-08-1958; End: 19-09-1958
# Chrome version=101.0.4951.67
# No search results for selected time period
# 775 months left to run, estimated runtime remaining: 3:03:16.096800
# Start: 20-09-1958; End: 19-10-1958
# Chrome version=101.0.4951.67
# No search results for selected time period
# 774 months left to run, estimated runtime remaining: 3:05:30.952824
# Start: 20-10-1958; End: 18-11-1958
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 773 months left to run, estimated runtime remaining: 3:04:54.634781
# Start: 19-11-1958; End: 18-12-1958
# Chrome version=101.0.4951.67
# No search results for selected time period
# 772 months left to run, estimated runtime remaining: 3:04:19.555428
# Start: 19-12-1958; End: 17-01-1959
# Chrome version=101.0.4951.67
# No search results for selected time period
# 771 months left to run, estimated runtime remaining: 3:03:44.805018
# Start: 18-01-1959; End: 16-02-1959
# Chrome version=101.0.4951.67
# 7 search results for selected time period
# 770 months left to run, estimated runtime remaining: 3:03:10.266210
# Start: 17-02-1959; End: 18-03-1959
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 769 months left to run, estimated runtime remaining: 3:02:35.510822
# Start: 19-03-1959; End: 17-04-1959
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 768 months left to run, estimated runtime remaining: 3:02:01.003776
# Start: 18-04-1959; End: 17-05-1959
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 767 months left to run, estimated runtime remaining: 3:01:26.949099
# Start: 18-05-1959; End: 16-06-1959
# Chrome version=101.0.4951.67
# No search results for selected time period
# 766 months left to run, estimated runtime remaining: 3:00:53.303864
# Start: 17-06-1959; End: 16-07-1959
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 765 months left to run, estimated runtime remaining: 3:02:58.580790
# Start: 17-07-1959; End: 15-08-1959
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 764 months left to run, estimated runtime remaining: 3:02:24.227420
# Start: 16-08-1959; End: 14-09-1959
# Chrome version=101.0.4951.67
# No search results for selected time period
# 763 months left to run, estimated runtime remaining: 3:01:49.679963
# Start: 15-09-1959; End: 14-10-1959
# Chrome version=101.0.4951.67
# No search results for selected time period
# 762 months left to run, estimated runtime remaining: 3:01:15.769968
# Start: 15-10-1959; End: 13-11-1959
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 761 months left to run, estimated runtime remaining: 3:00:42.231067
# Start: 14-11-1959; End: 13-12-1959
# Chrome version=101.0.4951.67
# No search results for selected time period
# 760 months left to run, estimated runtime remaining: 3:00:09.027040
# Start: 14-12-1959; End: 12-01-1960
# Chrome version=101.0.4951.67
# No search results for selected time period
# 759 months left to run, estimated runtime remaining: 2:59:35.771193
# Start: 13-01-1960; End: 11-02-1960
# Chrome version=101.0.4951.67
# No search results for selected time period
# 758 months left to run, estimated runtime remaining: 2:59:02.794416
# Start: 12-02-1960; End: 12-03-1960
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 757 months left to run, estimated runtime remaining: 2:58:32.593903
# Start: 13-03-1960; End: 11-04-1960
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 756 months left to run, estimated runtime remaining: 3:00:31.613436
# Start: 12-04-1960; End: 11-05-1960
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 755 months left to run, estimated runtime remaining: 2:59:58.967340
# Start: 12-05-1960; End: 10-06-1960
# Chrome version=101.0.4951.67
# No search results for selected time period
# 754 months left to run, estimated runtime remaining: 2:59:26.065154
# Start: 11-06-1960; End: 10-07-1960
# Chrome version=101.0.4951.67
# No search results for selected time period
# 753 months left to run, estimated runtime remaining: 2:58:53.576754
# Start: 11-07-1960; End: 09-08-1960
# Chrome version=101.0.4951.67
# No search results for selected time period
# 752 months left to run, estimated runtime remaining: 2:58:21.575888
# Start: 10-08-1960; End: 08-09-1960
# Chrome version=101.0.4951.67
# No search results for selected time period
# 751 months left to run, estimated runtime remaining: 2:57:49.687557
# Start: 09-09-1960; End: 08-10-1960
# Chrome version=101.0.4951.67
# No search results for selected time period
# 750 months left to run, estimated runtime remaining: 2:57:17.307000
# Start: 09-10-1960; End: 07-11-1960
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 749 months left to run, estimated runtime remaining: 2:56:47.218160
# Start: 08-11-1960; End: 07-12-1960
# Chrome version=101.0.4951.67
# No search results for selected time period
# 748 months left to run, estimated runtime remaining: 2:58:21.054056
# Start: 08-12-1960; End: 06-01-1961
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 747 months left to run, estimated runtime remaining: 2:57:48.754845
# Start: 07-01-1961; End: 05-02-1961
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 746 months left to run, estimated runtime remaining: 2:57:16.994676
# Start: 06-02-1961; End: 07-03-1961
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 745 months left to run, estimated runtime remaining: 2:56:45.526470
# Start: 08-03-1961; End: 06-04-1961
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 744 months left to run, estimated runtime remaining: 2:56:14.416200
# Start: 07-04-1961; End: 06-05-1961
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 743 months left to run, estimated runtime remaining: 2:55:43.312656
# Start: 07-05-1961; End: 05-06-1961
# Chrome version=101.0.4951.67
# No search results for selected time period
# 742 months left to run, estimated runtime remaining: 2:55:14.306950
# Start: 06-06-1961; End: 05-07-1961
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 741 months left to run, estimated runtime remaining: 2:54:43.547958
# Start: 06-07-1961; End: 04-08-1961
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 740 months left to run, estimated runtime remaining: 2:56:10.848940
# Start: 05-08-1961; End: 03-09-1961
# Chrome version=101.0.4951.67
# No search results for selected time period
# 739 months left to run, estimated runtime remaining: 2:55:40.321528
# Start: 04-09-1961; End: 03-10-1961
# Chrome version=101.0.4951.67
# No search results for selected time period
# 738 months left to run, estimated runtime remaining: 2:55:09.492690
# Start: 04-10-1961; End: 02-11-1961
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 737 months left to run, estimated runtime remaining: 2:54:39.305716
# Start: 03-11-1961; End: 02-12-1961
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 736 months left to run, estimated runtime remaining: 2:54:08.900736
# Start: 03-12-1961; End: 01-01-1962
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 735 months left to run, estimated runtime remaining: 2:53:38.804340
# Start: 02-01-1962; End: 31-01-1962
# Chrome version=101.0.4951.67
# No search results for selected time period
# 734 months left to run, estimated runtime remaining: 2:53:08.899476
# Start: 01-02-1962; End: 02-03-1962
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 733 months left to run, estimated runtime remaining: 2:52:39.156218
# Start: 03-03-1962; End: 01-04-1962
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 732 months left to run, estimated runtime remaining: 2:52:10.222632
# Start: 02-04-1962; End: 01-05-1962
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 731 months left to run, estimated runtime remaining: 2:53:49.218667
# Start: 02-05-1962; End: 31-05-1962
# Chrome version=101.0.4951.67
# 6 search results for selected time period
# 730 months left to run, estimated runtime remaining: 2:53:21.159720
# Start: 01-06-1962; End: 30-06-1962
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 729 months left to run, estimated runtime remaining: 2:52:52.228038
# Start: 01-07-1962; End: 30-07-1962
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 728 months left to run, estimated runtime remaining: 2:52:22.588984
# Start: 31-07-1962; End: 29-08-1962
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 727 months left to run, estimated runtime remaining: 2:51:53.510619
# Start: 30-08-1962; End: 28-09-1962
# Chrome version=101.0.4951.67
# No search results for selected time period
# 726 months left to run, estimated runtime remaining: 2:51:24.134124
# Start: 29-09-1962; End: 28-10-1962
# Chrome version=101.0.4951.67
# No search results for selected time period
# 725 months left to run, estimated runtime remaining: 2:50:55.533900
# Start: 29-10-1962; End: 27-11-1962
# Chrome version=101.0.4951.67
# No search results for selected time period
# 724 months left to run, estimated runtime remaining: 2:50:26.641180
# Start: 28-11-1962; End: 27-12-1962
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 723 months left to run, estimated runtime remaining: 2:49:58.081290
# Start: 28-12-1962; End: 26-01-1963
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 722 months left to run, estimated runtime remaining: 2:51:31.554060
# Start: 27-01-1963; End: 25-02-1963
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 721 months left to run, estimated runtime remaining: 2:51:04.613835
# Start: 26-02-1963; End: 27-03-1963
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 720 months left to run, estimated runtime remaining: 2:50:37.044240
# Start: 28-03-1963; End: 26-04-1963
# Chrome version=101.0.4951.67
# No search results for selected time period
# 719 months left to run, estimated runtime remaining: 2:50:08.198068
# Start: 27-04-1963; End: 26-05-1963
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 718 months left to run, estimated runtime remaining: 2:49:39.689120
# Start: 27-05-1963; End: 25-06-1963
# Chrome version=101.0.4951.67
# No search results for selected time period
# 717 months left to run, estimated runtime remaining: 2:49:15.194367
# Start: 26-06-1963; End: 25-07-1963
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 716 months left to run, estimated runtime remaining: 2:48:47.260088
# Start: 26-07-1963; End: 24-08-1963
# Chrome version=101.0.4951.67
# No search results for selected time period
# 715 months left to run, estimated runtime remaining: 2:48:19.178375
# Start: 25-08-1963; End: 23-09-1963
# Chrome version=101.0.4951.67
# No search results for selected time period
# 714 months left to run, estimated runtime remaining: 2:47:51.389832
# Start: 24-09-1963; End: 23-10-1963
# Chrome version=101.0.4951.67
# No search results for selected time period
# 713 months left to run, estimated runtime remaining: 2:52:01.704572
# Start: 24-10-1963; End: 22-11-1963
# Chrome version=101.0.4951.67
# No search results for selected time period
# 712 months left to run, estimated runtime remaining: 2:51:33.169688
# Start: 23-11-1963; End: 22-12-1963
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 711 months left to run, estimated runtime remaining: 2:51:04.373541
# Start: 23-12-1963; End: 21-01-1964
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 710 months left to run, estimated runtime remaining: 2:50:36.613860
# Start: 22-01-1964; End: 20-02-1964
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 709 months left to run, estimated runtime remaining: 2:50:08.793867
# Start: 21-02-1964; End: 21-03-1964
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 708 months left to run, estimated runtime remaining: 2:49:40.606704
# Start: 22-03-1964; End: 20-04-1964
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 707 months left to run, estimated runtime remaining: 2:49:12.151653
# Start: 21-04-1964; End: 20-05-1964
# Chrome version=101.0.4951.67
# No search results for selected time period
# 706 months left to run, estimated runtime remaining: 2:48:44.277922
# Start: 21-05-1964; End: 19-06-1964
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 705 months left to run, estimated runtime remaining: 2:48:16.242255
# Start: 20-06-1964; End: 19-07-1964
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 704 months left to run, estimated runtime remaining: 2:49:38.028608
# Start: 20-07-1964; End: 18-08-1964
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 703 months left to run, estimated runtime remaining: 2:49:09.841591
# Start: 19-08-1964; End: 17-09-1964
# Chrome version=101.0.4951.67
# No search results for selected time period
# 702 months left to run, estimated runtime remaining: 2:48:42.088860
# Start: 18-09-1964; End: 17-10-1964
# Chrome version=101.0.4951.67
# No search results for selected time period
# 701 months left to run, estimated runtime remaining: 2:48:15.959024
# Start: 18-10-1964; End: 16-11-1964
# Chrome version=101.0.4951.67
# No search results for selected time period
# 700 months left to run, estimated runtime remaining: 2:47:48.242100
# Start: 17-11-1964; End: 16-12-1964
# Chrome version=101.0.4951.67
# 6 search results for selected time period
# 699 months left to run, estimated runtime remaining: 2:47:20.801577
# Start: 17-12-1964; End: 15-01-1965
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 698 months left to run, estimated runtime remaining: 2:46:53.023588
# Start: 16-01-1965; End: 14-02-1965
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 697 months left to run, estimated runtime remaining: 2:46:25.639503
# Start: 15-02-1965; End: 16-03-1965
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 696 months left to run, estimated runtime remaining: 2:45:58.697904
# Start: 17-03-1965; End: 15-04-1965
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 695 months left to run, estimated runtime remaining: 2:47:15.095965
# Start: 16-04-1965; End: 15-05-1965
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 694 months left to run, estimated runtime remaining: 2:46:48.854814
# Start: 16-05-1965; End: 14-06-1965
# Chrome version=101.0.4951.67
# No search results for selected time period
# 693 months left to run, estimated runtime remaining: 2:46:22.069713
# Start: 15-06-1965; End: 14-07-1965
# Chrome version=101.0.4951.67
# No search results for selected time period
# 692 months left to run, estimated runtime remaining: 2:45:54.631752
# Start: 15-07-1965; End: 13-08-1965
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 691 months left to run, estimated runtime remaining: 2:45:27.475384
# Start: 14-08-1965; End: 12-09-1965
# Chrome version=101.0.4951.67
# No search results for selected time period
# 690 months left to run, estimated runtime remaining: 2:45:03.357480
# Start: 13-09-1965; End: 12-10-1965
# Chrome version=101.0.4951.67
# No search results for selected time period
# 689 months left to run, estimated runtime remaining: 2:44:36.294805
# Start: 13-10-1965; End: 11-11-1965
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 688 months left to run, estimated runtime remaining: 2:44:10.777120
# Start: 12-11-1965; End: 11-12-1965
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 687 months left to run, estimated runtime remaining: 2:43:44.149464
# Start: 12-12-1965; End: 10-01-1966
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 686 months left to run, estimated runtime remaining: 2:44:56.713456
# Start: 11-01-1966; End: 09-02-1966
# Chrome version=101.0.4951.67
# No search results for selected time period
# 685 months left to run, estimated runtime remaining: 2:44:29.733450
# Start: 10-02-1966; End: 11-03-1966
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 684 months left to run, estimated runtime remaining: 2:44:03.343452
# Start: 12-03-1966; End: 10-04-1966
# Chrome version=101.0.4951.67
# No search results for selected time period
# 683 months left to run, estimated runtime remaining: 2:43:37.072497
# Start: 11-04-1966; End: 10-05-1966
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 682 months left to run, estimated runtime remaining: 2:43:10.693792
# Start: 11-05-1966; End: 09-06-1966
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 681 months left to run, estimated runtime remaining: 2:42:45.085773
# Start: 10-06-1966; End: 09-07-1966
# Chrome version=101.0.4951.67
# No search results for selected time period
# 680 months left to run, estimated runtime remaining: 2:42:18.671000
# Start: 10-07-1966; End: 08-08-1966
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 679 months left to run, estimated runtime remaining: 2:41:52.682847
# Start: 09-08-1966; End: 07-09-1966
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 678 months left to run, estimated runtime remaining: 2:41:27.113484
# Start: 08-09-1966; End: 07-10-1966
# Chrome version=101.0.4951.67
# No search results for selected time period
# 677 months left to run, estimated runtime remaining: 2:42:35.867203
# Start: 08-10-1966; End: 06-11-1966
# Chrome version=101.0.4951.67
# No search results for selected time period
# 676 months left to run, estimated runtime remaining: 2:42:13.508356
# Start: 07-11-1966; End: 06-12-1966
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 675 months left to run, estimated runtime remaining: 2:41:48.275250
# Start: 07-12-1966; End: 05-01-1967
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 674 months left to run, estimated runtime remaining: 2:41:23.104576
# Start: 06-01-1967; End: 04-02-1967
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 673 months left to run, estimated runtime remaining: 2:40:58.562192
# Start: 05-02-1967; End: 06-03-1967
# Chrome version=101.0.4951.67
# 7 search results for selected time period
# 672 months left to run, estimated runtime remaining: 2:40:33.551424
# Start: 07-03-1967; End: 05-04-1967
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 671 months left to run, estimated runtime remaining: 2:40:09.006517
# Start: 06-04-1967; End: 05-05-1967
# Chrome version=101.0.4951.67
# No search results for selected time period
# 670 months left to run, estimated runtime remaining: 2:39:44.251510
# Start: 06-05-1967; End: 04-06-1967
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 669 months left to run, estimated runtime remaining: 2:39:20.345169
# Start: 05-06-1967; End: 04-07-1967
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 668 months left to run, estimated runtime remaining: 2:40:26.295496
# Start: 05-07-1967; End: 03-08-1967
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 667 months left to run, estimated runtime remaining: 2:40:01.840521
# ...
# 91 months left to run, estimated runtime remaining: 0:21:53.344578
# Start: 25-11-2014; End: 24-12-2014
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 90 months left to run, estimated runtime remaining: 0:21:38.415060
# Start: 25-12-2014; End: 23-01-2015
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 89 months left to run, estimated runtime remaining: 0:21:23.509228
# Start: 24-01-2015; End: 22-02-2015
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 88 months left to run, estimated runtime remaining: 0:21:08.609584
# Start: 23-02-2015; End: 24-03-2015
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 87 months left to run, estimated runtime remaining: 0:20:57.459111
# Start: 25-03-2015; End: 23-04-2015
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 86 months left to run, estimated runtime remaining: 0:20:42.561368
# Start: 24-04-2015; End: 23-05-2015
# Chrome version=101.0.4951.67
# No search results for selected time period
# 85 months left to run, estimated runtime remaining: 0:20:27.635875
# Start: 24-05-2015; End: 22-06-2015
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 84 months left to run, estimated runtime remaining: 0:20:12.728412
# Start: 23-06-2015; End: 22-07-2015
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 83 months left to run, estimated runtime remaining: 0:19:57.843384
# Start: 23-07-2015; End: 21-08-2015
# Chrome version=101.0.4951.67
# No search results for selected time period
# 82 months left to run, estimated runtime remaining: 0:19:42.964390
# Start: 22-08-2015; End: 20-09-2015
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 81 months left to run, estimated runtime remaining: 0:19:28.085529
# Start: 21-09-2015; End: 20-10-2015
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 80 months left to run, estimated runtime remaining: 0:19:13.226000
# Start: 21-10-2015; End: 19-11-2015
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 79 months left to run, estimated runtime remaining: 0:18:58.384233
# Start: 20-11-2015; End: 19-12-2015
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 78 months left to run, estimated runtime remaining: 0:18:51.418392
# Start: 20-12-2015; End: 18-01-2016
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 77 months left to run, estimated runtime remaining: 0:18:36.487141
# Start: 19-01-2016; End: 17-02-2016
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 76 months left to run, estimated runtime remaining: 0:18:21.566800
# Start: 18-02-2016; End: 18-03-2016
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 75 months left to run, estimated runtime remaining: 0:18:06.654375
# Start: 19-03-2016; End: 17-04-2016
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 74 months left to run, estimated runtime remaining: 0:17:51.762646
# Start: 18-04-2016; End: 17-05-2016
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 73 months left to run, estimated runtime remaining: 0:17:36.888890
# Start: 18-05-2016; End: 16-06-2016
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 72 months left to run, estimated runtime remaining: 0:17:22.016472
# Start: 17-06-2016; End: 16-07-2016
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 71 months left to run, estimated runtime remaining: 0:17:07.157781
# Start: 17-07-2016; End: 15-08-2016
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 70 months left to run, estimated runtime remaining: 0:16:52.318510
# Start: 16-08-2016; End: 14-09-2016
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 69 months left to run, estimated runtime remaining: 0:16:40.406850
# Start: 15-09-2016; End: 14-10-2016
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 68 months left to run, estimated runtime remaining: 0:16:25.542904
# Start: 15-10-2016; End: 13-11-2016
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 67 months left to run, estimated runtime remaining: 0:16:10.690439
# Start: 14-11-2016; End: 13-12-2016
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 66 months left to run, estimated runtime remaining: 0:15:55.841898
# Start: 14-12-2016; End: 12-01-2017
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 65 months left to run, estimated runtime remaining: 0:15:41.005390
# Start: 13-01-2017; End: 11-02-2017
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 64 months left to run, estimated runtime remaining: 0:15:26.177344
# Start: 12-02-2017; End: 13-03-2017
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 63 months left to run, estimated runtime remaining: 0:15:11.362095
# Start: 14-03-2017; End: 12-04-2017
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 62 months left to run, estimated runtime remaining: 0:14:56.557572
# Start: 13-04-2017; End: 12-05-2017
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 61 months left to run, estimated runtime remaining: 0:14:43.987173
# Start: 13-05-2017; End: 11-06-2017
# Chrome version=101.0.4951.67
# No search results for selected time period
# 60 months left to run, estimated runtime remaining: 0:14:29.166600
# Start: 12-06-2017; End: 11-07-2017
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 59 months left to run, estimated runtime remaining: 0:14:14.371448
# Start: 12-07-2017; End: 10-08-2017
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 58 months left to run, estimated runtime remaining: 0:13:59.588860
# Start: 11-08-2017; End: 09-09-2017
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 57 months left to run, estimated runtime remaining: 0:13:44.822148
# Start: 10-09-2017; End: 09-10-2017
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 56 months left to run, estimated runtime remaining: 0:13:30.051704
# Start: 10-10-2017; End: 08-11-2017
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 55 months left to run, estimated runtime remaining: 0:13:15.305005
# Start: 09-11-2017; End: 08-12-2017
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 54 months left to run, estimated runtime remaining: 0:13:00.552828
# Start: 09-12-2017; End: 07-01-2018
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 53 months left to run, estimated runtime remaining: 0:12:47.748354
# Start: 08-01-2018; End: 06-02-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 52 months left to run, estimated runtime remaining: 0:12:33.007996
# Start: 07-02-2018; End: 08-03-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 51 months left to run, estimated runtime remaining: 0:12:18.258201
# Start: 09-03-2018; End: 07-04-2018
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 50 months left to run, estimated runtime remaining: 0:12:03.525650
# Start: 08-04-2018; End: 07-05-2018
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 49 months left to run, estimated runtime remaining: 0:11:48.804306
# Start: 08-05-2018; End: 06-06-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 48 months left to run, estimated runtime remaining: 0:11:34.081680
# Start: 07-06-2018; End: 06-07-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 47 months left to run, estimated runtime remaining: 0:11:19.377997
# Start: 07-07-2018; End: 05-08-2018
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 46 months left to run, estimated runtime remaining: 0:11:04.683348
# Start: 06-08-2018; End: 04-09-2018
# Chrome version=101.0.4951.67
# No search results for selected time period
# 45 months left to run, estimated runtime remaining: 0:10:50.004120
# Start: 05-09-2018; End: 04-10-2018
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 44 months left to run, estimated runtime remaining: 0:10:37.149392
# Start: 05-10-2018; End: 03-11-2018
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 43 months left to run, estimated runtime remaining: 0:10:22.446113
# Start: 04-11-2018; End: 03-12-2018
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 42 months left to run, estimated runtime remaining: 0:10:07.753440
# Start: 04-12-2018; End: 02-01-2019
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 41 months left to run, estimated runtime remaining: 0:09:53.071232
# Start: 03-01-2019; End: 01-02-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 40 months left to run, estimated runtime remaining: 0:09:38.401760
# Start: 02-02-2019; End: 03-03-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 39 months left to run, estimated runtime remaining: 0:09:23.761536
# Start: 04-03-2019; End: 02-04-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 38 months left to run, estimated runtime remaining: 0:09:09.116074
# Start: 03-04-2019; End: 02-05-2019
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 37 months left to run, estimated runtime remaining: 0:08:54.482353
# Start: 03-05-2019; End: 01-06-2019
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 36 months left to run, estimated runtime remaining: 0:08:39.864336
# Start: 02-06-2019; End: 01-07-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 35 months left to run, estimated runtime remaining: 0:08:26.677010
# Start: 02-07-2019; End: 31-07-2019
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 34 months left to run, estimated runtime remaining: 0:08:12.031646
# Start: 01-08-2019; End: 30-08-2019
# Chrome version=101.0.4951.67
# No search results for selected time period
# 33 months left to run, estimated runtime remaining: 0:07:57.396183
# Start: 31-08-2019; End: 29-09-2019
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 32 months left to run, estimated runtime remaining: 0:07:42.765504
# Start: 30-09-2019; End: 29-10-2019
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 31 months left to run, estimated runtime remaining: 0:07:28.150632
# Start: 30-10-2019; End: 28-11-2019
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 30 months left to run, estimated runtime remaining: 0:07:13.551540
# Start: 29-11-2019; End: 28-12-2019
# Chrome version=101.0.4951.67
# No search results for selected time period
# 29 months left to run, estimated runtime remaining: 0:06:58.956678
# Start: 29-12-2019; End: 27-01-2020
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 28 months left to run, estimated runtime remaining: 0:06:44.375328
# Start: 28-01-2020; End: 26-02-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 27 months left to run, estimated runtime remaining: 0:06:29.805480
# Start: 27-02-2020; End: 27-03-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 26 months left to run, estimated runtime remaining: 0:06:16.288666
# Start: 28-03-2020; End: 26-04-2020
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 25 months left to run, estimated runtime remaining: 0:06:01.692850
# Start: 27-04-2020; End: 26-05-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 24 months left to run, estimated runtime remaining: 0:05:47.100744
# Start: 27-05-2020; End: 25-06-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 23 months left to run, estimated runtime remaining: 0:05:32.518291
# Start: 26-06-2020; End: 25-07-2020
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 22 months left to run, estimated runtime remaining: 0:05:17.945826
# Start: 26-07-2020; End: 24-08-2020
# Chrome version=101.0.4951.67
# No search results for selected time period
# 21 months left to run, estimated runtime remaining: 0:05:03.386328
# Start: 25-08-2020; End: 23-09-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 20 months left to run, estimated runtime remaining: 0:04:48.836240
# Start: 24-09-2020; End: 23-10-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 19 months left to run, estimated runtime remaining: 0:04:34.297490
# Start: 24-10-2020; End: 22-11-2020
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 18 months left to run, estimated runtime remaining: 0:04:20.391186
# Start: 23-11-2020; End: 22-12-2020
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 17 months left to run, estimated runtime remaining: 0:04:05.836235
# Start: 23-12-2020; End: 21-01-2021
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 16 months left to run, estimated runtime remaining: 0:03:51.293744
# Start: 22-01-2021; End: 20-02-2021
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 15 months left to run, estimated runtime remaining: 0:03:36.759615
# Start: 21-02-2021; End: 22-03-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 14 months left to run, estimated runtime remaining: 0:03:22.244952
# Start: 23-03-2021; End: 21-04-2021
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 13 months left to run, estimated runtime remaining: 0:03:07.731843
# Start: 22-04-2021; End: 21-05-2021
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 12 months left to run, estimated runtime remaining: 0:02:53.228964
# Start: 22-05-2021; End: 20-06-2021
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 11 months left to run, estimated runtime remaining: 0:02:38.738569
# Start: 21-06-2021; End: 20-07-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 10 months left to run, estimated runtime remaining: 0:02:24.605400
# Start: 21-07-2021; End: 19-08-2021
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 9 months left to run, estimated runtime remaining: 0:02:10.097970
# Start: 20-08-2021; End: 18-09-2021
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 8 months left to run, estimated runtime remaining: 0:01:55.602272
# Start: 19-09-2021; End: 18-10-2021
# Chrome version=101.0.4951.67
# 1 search result for selected time period
# 7 months left to run, estimated runtime remaining: 0:01:41.116155
# Start: 19-10-2021; End: 17-11-2021
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 6 months left to run, estimated runtime remaining: 0:01:26.640468
# Start: 18-11-2021; End: 17-12-2021
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 5 months left to run, estimated runtime remaining: 0:01:12.174090
# Start: 18-12-2021; End: 16-01-2022
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 4 months left to run, estimated runtime remaining: 0:00:57.718920
# Start: 17-01-2022; End: 15-02-2022
# Chrome version=101.0.4951.67
# 4 search results for selected time period
# 3 months left to run, estimated runtime remaining: 0:00:43.274520
# Start: 16-02-2022; End: 17-03-2022
# Chrome version=101.0.4951.67
# 5 search results for selected time period
# 2 months left to run, estimated runtime remaining: 0:00:28.908744
# Start: 18-03-2022; End: 16-04-2022
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# 1 months left to run, estimated runtime remaining: 0:00:14.449320
# Start: 17-04-2022; End: 16-05-2022
# Chrome version=101.0.4951.67
# 3 search results for selected time period
# 0 months left to run, estimated runtime remaining: 0:00:00
# Start: 17-05-2022; End: 15-06-2022
# Chrome version=101.0.4951.67
# 2 search results for selected time period
# -1 months left to run, estimated runtime remaining: -1 day, 23:59:45.560204

# %%
pmqs_dates = pd.Series(pmqs_dates, name='date')
pmqs_dates = pmqs_dates.drop_duplicates()
pmqs_dates.to_csv('pmqs_dates.csv')
