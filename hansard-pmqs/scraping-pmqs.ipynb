# %%
import time
from datetime import datetime

def find_pmqs(start_date, end_date, term, print_url=True):
    
    # Load Selenium, module for browsing
    import undetected_chromedriver as uc
    from selenium import webdriver
    from selenium.common.exceptions import NoSuchElementException
    from selenium.webdriver.common.by import By
    
    # Prepare url with search term, start and end dates
    root_url = "https://hansard.parliament.uk/search/Debates?startDate=%s&endDate=%s&searchTerm=%s&house=Commons&partial=False"
    search_term = term.replace(" ","%20")
    url = root_url % (start_date, end_date, search_term)
    if print_url:
        print(url)
    
    # Make request to Hansard url with Selenium
    options = webdriver.ChromeOptions()
    browser = uc.Chrome(options=options)
    #browser = webdriver.Firefox()
    browser.get(url)
    
    # Wait for page to load
    time.sleep(5)
    
    # Save search results to a list
    try:
        dates_res = browser.find_element(By.CLASS_NAME, "card-list").text.split("\n")
        #search_res = browser.find_element_by_class_name("card-list").text.split("\n")
    except NoSuchElementException:
        dates_res = None
        temp_pmqs_dates = None
    
    try:
        urls_res = [x.get_property("href") for x in browser.find_element(By.CLASS_NAME, "card-list").find_elements(By.CLASS_NAME, "card-calendar")]
        #search_res = [x.get_property("href") for x in browser.find_element_by_class_name("card-list").find_elements_by_class_name("card-calendar")]
        if len(urls_res)==1:
            print(f"{len(urls_res)} search result for selected time period")
        else: print(f"{len(urls_res)} search results for selected time period")
    except NoSuchElementException:
        print("No search results for selected time period")
        urls_res = None
        
    browser.quit()
    
    if dates_res: 
        temp_pmqs_dates = []
        for i in range(0,len(dates_res),8):
            temp_pmqs_dates.append(dates_res[i+5])
        temp_pmqs_dates = [datetime.strftime(datetime.strptime(x,"%d %B %Y"),"%Y-%m-%d") for x in temp_pmqs_dates]
    
    return temp_pmqs_dates,urls_res

# %% [markdown]
# To do:
#  * Combine date and url grabbing functions to widen the browser launching bottleneck
#  * Return number of results for successful searches
#  * Implement estimated time left

# %%
import undetected_chromedriver as uc
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.by import By

def parse_hansard_url(target_url):

    # Make request to Hansard url with Selenium
    options = webdriver.ChromeOptions()
    browser = uc.Chrome(options=options)
    #browser = webdriver.Firefox()
    browser.get(target_url)

    # Wait for page to load
    time.sleep(5)

    d = browser.find_element(By.CLASS_NAME, "calendar-sheet").find_element(By.CLASS_NAME, "day").text
    m = browser.find_element(By.CLASS_NAME, "calendar-sheet").find_element(By.CLASS_NAME, "month").text
    y = browser.find_element(By.CLASS_NAME, "calendar-sheet").find_element(By.CLASS_NAME, "year").text

    debate_items = [x.find_element(By.CLASS_NAME, "contribution") for x in browser.find_element(By.CLASS_NAME, "article").find_elements(By.CLASS_NAME, "debate-item-contributiondebateitem")]

    debate = dict()

    debate['title'] = browser.find_element(By.CLASS_NAME, "hero-banner").find_element(By.TAG_NAME, "h1").text
    debate['date'] = d+"/"+m+"/"+y

    debate['contribs'] = dict()

    for contrib in debate_items:
        contrib_id = contrib.get_attribute("data-contribution-id")

        debate['contribs'][contrib_id] = dict()
        debate['contribs'][contrib_id]['speaker'] = contrib.find_element(By.CLASS_NAME, "attributed-to-details").find_element(By.CLASS_NAME, "primary-text").text
        debate['contribs'][contrib_id]['content'] = contrib.find_element(By.CLASS_NAME, "content").text

    browser.quit()
    
    return debate

# %%
from dateutil.relativedelta import *
from datetime import timedelta

date_ceiling = datetime.now()

startdate = datetime.strptime("1979-05-04","%Y-%m-%d")
enddate = startdate + relativedelta(days=+29)

pmqs_dates = list()
pmqs_urls = list()

tot_run_time = timedelta()
n = 0

while startdate <= date_ceiling: #datetime.today():
    
    go_time = datetime.now()
    
    print(f"Start: {datetime.strftime(startdate,'%d-%m-%Y')}; End: {datetime.strftime(enddate,'%d-%m-%Y')}")
    
    date_res,url_res = find_pmqs(startdate, enddate, "Prime Minister", print_url = False)
    if date_res:
        pmqs_dates.extend(date_res)
    if url_res:
        pmqs_urls.extend(url_res)
        
    startdate = startdate + relativedelta(days=+30)
    enddate = enddate + relativedelta(days=+30)
    
    run_time = datetime.now()-go_time
    tot_run_time += run_time
    n += 1
    avg_run_time = tot_run_time/n
    
    months_left_to_run = ((date_ceiling-startdate)/30).days
    estimated_runtime = avg_run_time*months_left_to_run
    print(f"{months_left_to_run} months left to run, estimated runtime remaining: {estimated_runtime}")
# Out:
# Start: 04-05-1979; End: 02-06-1979
# 3 search results for selected time period
# 519 months left to run, estimated runtime remaining: 1:25:07.924302
# Start: 03-06-1979; End: 02-07-1979
# 6 search results for selected time period
# 518 months left to run, estimated runtime remaining: 1:17:03.529176
# Start: 03-07-1979; End: 01-08-1979
# 8 search results for selected time period
# 517 months left to run, estimated runtime remaining: 1:13:39.927094
# Start: 02-08-1979; End: 31-08-1979
# No search results for selected time period
# 516 months left to run, estimated runtime remaining: 1:11:58.383876
# Start: 01-09-1979; End: 30-09-1979
# No search results for selected time period
# 515 months left to run, estimated runtime remaining: 1:09:55.212660
# Start: 01-10-1979; End: 30-10-1979
# 4 search results for selected time period
# 514 months left to run, estimated runtime remaining: 1:08:19.306770
# Start: 31-10-1979; End: 29-11-1979
# 15 search results for selected time period
# 513 months left to run, estimated runtime remaining: 1:07:18.343695
# Start: 30-11-1979; End: 29-12-1979
# 7 search results for selected time period
# 512 months left to run, estimated runtime remaining: 1:36:03.107328
# Start: 30-12-1979; End: 28-01-1980
# 3 search results for selected time period
# 511 months left to run, estimated runtime remaining: 1:32:12.585247
# Start: 29-01-1980; End: 27-02-1980
# 11 search results for selected time period
# 510 months left to run, estimated runtime remaining: 1:28:58.711110
# Start: 28-02-1980; End: 28-03-1980
# 10 search results for selected time period
# 509 months left to run, estimated runtime remaining: 1:26:14.983149
# Start: 29-03-1980; End: 27-04-1980
# 8 search results for selected time period
# 508 months left to run, estimated runtime remaining: 1:24:04.063064
# Start: 28-04-1980; End: 27-05-1980
# 9 search results for selected time period
# 507 months left to run, estimated runtime remaining: 1:22:04.556403
# Start: 28-05-1980; End: 26-06-1980
# 7 search results for selected time period
# 506 months left to run, estimated runtime remaining: 1:20:35.891082
# Start: 27-06-1980; End: 26-07-1980
# 12 search results for selected time period
# 505 months left to run, estimated runtime remaining: 1:19:06.383395
# Start: 27-07-1980; End: 25-08-1980
# 5 search results for selected time period
# 504 months left to run, estimated runtime remaining: 1:34:41.613672
# Start: 26-08-1980; End: 24-09-1980
# No search results for selected time period
# 503 months left to run, estimated runtime remaining: 1:32:27.832464
# Start: 25-09-1980; End: 24-10-1980
# No search results for selected time period
# 502 months left to run, estimated runtime remaining: 1:30:28.008532
# Start: 25-10-1980; End: 23-11-1980
# 8 search results for selected time period
# 501 months left to run, estimated runtime remaining: 1:28:40.041345
# Start: 24-11-1980; End: 23-12-1980
# 11 search results for selected time period
# 500 months left to run, estimated runtime remaining: 1:27:01.614500
# Start: 24-12-1980; End: 22-01-1981
# 5 search results for selected time period
# 499 months left to run, estimated runtime remaining: 1:25:34.285850
# Start: 23-01-1981; End: 21-02-1981
# No search results for selected time period
# 498 months left to run, estimated runtime remaining: 1:24:17.243286
# Start: 22-02-1981; End: 23-03-1981
# 9 search results for selected time period
# 497 months left to run, estimated runtime remaining: 1:23:02.557699
# Start: 24-03-1981; End: 22-04-1981
# 7 search results for selected time period
# 496 months left to run, estimated runtime remaining: 1:33:02.815296
# Start: 23-04-1981; End: 22-05-1981
# 8 search results for selected time period
# 495 months left to run, estimated runtime remaining: 1:31:29.517825
# Start: 23-05-1981; End: 21-06-1981
# 2 search results for selected time period
# 494 months left to run, estimated runtime remaining: 1:30:04.122386
# Start: 22-06-1981; End: 21-07-1981
# 9 search results for selected time period
# 493 months left to run, estimated runtime remaining: 1:28:42.288974
# Start: 22-07-1981; End: 20-08-1981
# 3 search results for selected time period
# 492 months left to run, estimated runtime remaining: 1:27:25.298592
# Start: 21-08-1981; End: 19-09-1981
# No search results for selected time period
# 491 months left to run, estimated runtime remaining: 1:26:17.379451
# Start: 20-09-1981; End: 19-10-1981
# No search results for selected time period
# 490 months left to run, estimated runtime remaining: 1:25:09.940990
# Start: 20-10-1981; End: 18-11-1981
# 3 search results for selected time period
# 489 months left to run, estimated runtime remaining: 1:24:07.156287
# Start: 19-11-1981; End: 18-12-1981
# 9 search results for selected time period
# 488 months left to run, estimated runtime remaining: 1:23:10.727200
# Start: 19-12-1981; End: 17-01-1982
# 1 search result for selected time period
# 487 months left to run, estimated runtime remaining: 1:31:21.582392
# Start: 18-01-1982; End: 16-02-1982
# 7 search results for selected time period
# 486 months left to run, estimated runtime remaining: 1:30:12.762306
# Start: 17-02-1982; End: 18-03-1982
# 8 search results for selected time period
# 485 months left to run, estimated runtime remaining: 1:29:07.243825
# Start: 19-03-1982; End: 17-04-1982
# 8 search results for selected time period
# 484 months left to run, estimated runtime remaining: 1:28:04.427676
# Start: 18-04-1982; End: 17-05-1982
# 8 search results for selected time period
# 483 months left to run, estimated runtime remaining: 1:27:03.341676
# Start: 18-05-1982; End: 16-06-1982
# 8 search results for selected time period
# 482 months left to run, estimated runtime remaining: 1:26:05.058016
# Start: 17-06-1982; End: 16-07-1982
# 9 search results for selected time period
# 481 months left to run, estimated runtime remaining: 1:25:10.460498
# Start: 17-07-1982; End: 15-08-1982
# 4 search results for selected time period
# 480 months left to run, estimated runtime remaining: 1:24:16.924800
# Start: 16-08-1982; End: 14-09-1982
# No search results for selected time period
# 479 months left to run, estimated runtime remaining: 1:23:25.184044
# Start: 15-09-1982; End: 14-10-1982
# No search results for selected time period
# 478 months left to run, estimated runtime remaining: 1:29:41.553440
# Start: 15-10-1982; End: 13-11-1982
# 5 search results for selected time period
# 477 months left to run, estimated runtime remaining: 1:28:43.714956
# Start: 14-11-1982; End: 13-12-1982
# 8 search results for selected time period
# 476 months left to run, estimated runtime remaining: 1:27:56.147744
# Start: 14-12-1982; End: 12-01-1983
# 4 search results for selected time period
# 475 months left to run, estimated runtime remaining: 1:27:02.401750
# Start: 13-01-1983; End: 11-02-1983
# 9 search results for selected time period
# 474 months left to run, estimated runtime remaining: 1:26:15.820248
# Start: 12-02-1983; End: 13-03-1983
# 8 search results for selected time period
# 473 months left to run, estimated runtime remaining: 1:25:29.921027
# Start: 14-03-1983; End: 12-04-1983
# 7 search results for selected time period
# 472 months left to run, estimated runtime remaining: 1:24:43.125648
# Start: 13-04-1983; End: 12-05-1983
# No search results for selected time period
# 471 months left to run, estimated runtime remaining: 1:23:59.425407
# Start: 13-05-1983; End: 11-06-1983
# No search results for selected time period
# 470 months left to run, estimated runtime remaining: 1:23:14.892570
# Start: 12-06-1983; End: 11-07-1983
# 4 search results for selected time period
# 469 months left to run, estimated runtime remaining: 1:28:12.613410
# Start: 12-07-1983; End: 10-08-1983
# 6 search results for selected time period
# 468 months left to run, estimated runtime remaining: 1:27:24.063084
# Start: 11-08-1983; End: 09-09-1983
# No search results for selected time period
# 467 months left to run, estimated runtime remaining: 1:26:37.886993
# Start: 10-09-1983; End: 09-10-1983
# No search results for selected time period
# 466 months left to run, estimated runtime remaining: 1:25:51.064276
# Start: 10-10-1983; End: 08-11-1983
# 5 search results for selected time period
# 465 months left to run, estimated runtime remaining: 1:25:06.609075
# Start: 09-11-1983; End: 08-12-1983
# 9 search results for selected time period
# 464 months left to run, estimated runtime remaining: 1:24:23.279360
# Start: 09-12-1983; End: 07-01-1984
# 4 search results for selected time period
# 463 months left to run, estimated runtime remaining: 1:23:44.410717
# Start: 08-01-1984; End: 06-02-1984
# 6 search results for selected time period
# 462 months left to run, estimated runtime remaining: 1:23:04.477806
# Start: 07-02-1984; End: 07-03-1984
# 5 search results for selected time period
# 461 months left to run, estimated runtime remaining: 1:22:25.173738
# Start: 08-03-1984; End: 06-04-1984
# No search results for selected time period
# 460 months left to run, estimated runtime remaining: 1:26:32.744960
# Start: 07-04-1984; End: 06-05-1984
# 5 search results for selected time period
# 459 months left to run, estimated runtime remaining: 1:25:50.329758
# Start: 07-05-1984; End: 05-06-1984
# 8 search results for selected time period
# 458 months left to run, estimated runtime remaining: 1:25:11.676628
# Start: 06-06-1984; End: 05-07-1984
# 11 search results for selected time period
# 457 months left to run, estimated runtime remaining: 1:24:31.546075
# Start: 06-07-1984; End: 04-08-1984
# 7 search results for selected time period
# 456 months left to run, estimated runtime remaining: 1:23:52.706472
# Start: 05-08-1984; End: 03-09-1984
# No search results for selected time period
# 455 months left to run, estimated runtime remaining: 1:23:13.417065
# Start: 04-09-1984; End: 03-10-1984
# No search results for selected time period
# 454 months left to run, estimated runtime remaining: 1:22:35.030002
# Start: 04-10-1984; End: 02-11-1984
# 3 search results for selected time period
# 453 months left to run, estimated runtime remaining: 1:21:58.476945
# Start: 03-11-1984; End: 02-12-1984
# 6 search results for selected time period
# 452 months left to run, estimated runtime remaining: 1:21:24.394264
# Start: 03-12-1984; End: 01-01-1985
# 5 search results for selected time period
# 451 months left to run, estimated runtime remaining: 1:24:52.034893
# Start: 02-01-1985; End: 31-01-1985
# 7 search results for selected time period
# 450 months left to run, estimated runtime remaining: 1:24:14.393700
# Start: 01-02-1985; End: 02-03-1985
# 9 search results for selected time period
# 449 months left to run, estimated runtime remaining: 1:23:36.933828
# Start: 03-03-1985; End: 01-04-1985
# 7 search results for selected time period
# 448 months left to run, estimated runtime remaining: 1:23:02.008640
# Start: 02-04-1985; End: 01-05-1985
# 7 search results for selected time period
# 447 months left to run, estimated runtime remaining: 1:22:26.937378
# Start: 02-05-1985; End: 31-05-1985
# 7 search results for selected time period
# 446 months left to run, estimated runtime remaining: 1:21:53.032082
# Start: 01-06-1985; End: 30-06-1985
# 7 search results for selected time period
# 445 months left to run, estimated runtime remaining: 1:21:18.472700
# Start: 01-07-1985; End: 30-07-1985
# 7 search results for selected time period
# 444 months left to run, estimated runtime remaining: 1:20:44.351244
# Start: 31-07-1985; End: 29-08-1985
# No search results for selected time period
# 443 months left to run, estimated runtime remaining: 1:20:11.658676
# Start: 30-08-1985; End: 28-09-1985
# No search results for selected time period
# 442 months left to run, estimated runtime remaining: 1:27:06.256178
# Start: 29-09-1985; End: 28-10-1985
# 2 search results for selected time period
# 441 months left to run, estimated runtime remaining: 1:26:28.217706
# Start: 29-10-1985; End: 27-11-1985
# 7 search results for selected time period
# 440 months left to run, estimated runtime remaining: 1:25:51.425400
# Start: 28-11-1985; End: 27-12-1985
# 7 search results for selected time period
# 439 months left to run, estimated runtime remaining: 1:25:14.910603
# Start: 28-12-1985; End: 26-01-1986
# 5 search results for selected time period
# 438 months left to run, estimated runtime remaining: 1:24:40.189428
# Start: 27-01-1986; End: 25-02-1986
# 8 search results for selected time period
# 437 months left to run, estimated runtime remaining: 1:24:04.766019
# Start: 26-02-1986; End: 27-03-1986
# 5 search results for selected time period
# 436 months left to run, estimated runtime remaining: 1:23:30.855568
# Start: 28-03-1986; End: 26-04-1986
# 6 search results for selected time period
# 435 months left to run, estimated runtime remaining: 1:22:57.471840
# Start: 27-04-1986; End: 26-05-1986
# 8 search results for selected time period
# 434 months left to run, estimated runtime remaining: 1:22:24.301166
# Start: 27-05-1986; End: 25-06-1986
# 7 search results for selected time period
# 433 months left to run, estimated runtime remaining: 1:24:56.783679
# Start: 26-06-1986; End: 25-07-1986
# 9 search results for selected time period
# 432 months left to run, estimated runtime remaining: 1:24:22.932864
# Start: 26-07-1986; End: 24-08-1986
# No search results for selected time period
# 431 months left to run, estimated runtime remaining: 1:23:49.134275
# Start: 25-08-1986; End: 23-09-1986
# No search results for selected time period
# 430 months left to run, estimated runtime remaining: 1:23:15.261840
# Start: 24-09-1986; End: 23-10-1986
# 2 search results for selected time period
# 429 months left to run, estimated runtime remaining: 1:22:43.767666
# Start: 24-10-1986; End: 22-11-1986
# 7 search results for selected time period
# 428 months left to run, estimated runtime remaining: 1:22:11.367208
# Start: 23-11-1986; End: 22-12-1986
# 7 search results for selected time period
# 427 months left to run, estimated runtime remaining: 1:21:40.057715
# Start: 23-12-1986; End: 21-01-1987
# 3 search results for selected time period
# 426 months left to run, estimated runtime remaining: 1:21:09.494388
# Start: 22-01-1987; End: 20-02-1987
# 8 search results for selected time period
# 425 months left to run, estimated runtime remaining: 1:20:38.738050
# Start: 21-02-1987; End: 22-03-1987
# 8 search results for selected time period
# 424 months left to run, estimated runtime remaining: 1:22:52.457032
# Start: 23-03-1987; End: 21-04-1987
# 5 search results for selected time period
# 423 months left to run, estimated runtime remaining: 1:22:22.757115
# Start: 22-04-1987; End: 21-05-1987
# 7 search results for selected time period
# 422 months left to run, estimated runtime remaining: 1:21:51.666862
# Start: 22-05-1987; End: 20-06-1987
# 1 search result for selected time period
# 421 months left to run, estimated runtime remaining: 1:21:20.326304
# Start: 21-06-1987; End: 20-07-1987
# 6 search results for selected time period
# 420 months left to run, estimated runtime remaining: 1:20:50.322120
# Start: 21-07-1987; End: 19-08-1987
# 2 search results for selected time period
# 419 months left to run, estimated runtime remaining: 1:20:20.187313
# Start: 20-08-1987; End: 18-09-1987
# No search results for selected time period
# 418 months left to run, estimated runtime remaining: 1:19:50.721408
# Start: 19-09-1987; End: 18-10-1987
# No search results for selected time period
# 417 months left to run, estimated runtime remaining: 1:19:21.563289
# Start: 19-10-1987; End: 17-11-1987
# 8 search results for selected time period
# 416 months left to run, estimated runtime remaining: 1:18:53.784640
# Start: 18-11-1987; End: 17-12-1987
# 9 search results for selected time period
# 415 months left to run, estimated runtime remaining: 1:20:52.250550
# Start: 18-12-1987; End: 16-01-1988
# 2 search results for selected time period
# 414 months left to run, estimated runtime remaining: 1:20:22.677720
# Start: 17-01-1988; End: 15-02-1988
# 8 search results for selected time period
# 413 months left to run, estimated runtime remaining: 1:19:53.651765
# Start: 16-02-1988; End: 16-03-1988
# 8 search results for selected time period
# 412 months left to run, estimated runtime remaining: 1:19:25.589580
# Start: 17-03-1988; End: 15-04-1988
# 7 search results for selected time period
# 411 months left to run, estimated runtime remaining: 1:18:57.737562
# Start: 16-04-1988; End: 15-05-1988
# 6 search results for selected time period
# 410 months left to run, estimated runtime remaining: 1:18:32.102530
# Start: 16-05-1988; End: 14-06-1988
# 5 search results for selected time period
# 409 months left to run, estimated runtime remaining: 1:18:04.999703
# Start: 15-06-1988; End: 14-07-1988
# 9 search results for selected time period
# 408 months left to run, estimated runtime remaining: 1:17:37.930368
# Start: 15-07-1988; End: 13-08-1988
# 4 search results for selected time period
# 407 months left to run, estimated runtime remaining: 1:17:11.182996
# Start: 14-08-1988; End: 12-09-1988
# No search results for selected time period
# 406 months left to run, estimated runtime remaining: 1:18:56.458524
# Start: 13-09-1988; End: 12-10-1988
# 1 search result for selected time period
# 405 months left to run, estimated runtime remaining: 1:18:28.734930
# Start: 13-10-1988; End: 11-11-1988
# 6 search results for selected time period
# 404 months left to run, estimated runtime remaining: 1:18:01.582704
# Start: 12-11-1988; End: 11-12-1988
# 5 search results for selected time period
# 403 months left to run, estimated runtime remaining: 1:17:34.583505
# Start: 12-12-1988; End: 10-01-1989
# 4 search results for selected time period
# 402 months left to run, estimated runtime remaining: 1:17:08.570112
# Start: 11-01-1989; End: 09-02-1989
# 9 search results for selected time period
# 401 months left to run, estimated runtime remaining: 1:16:42.416548
# Start: 10-02-1989; End: 11-03-1989
# 8 search results for selected time period
# 400 months left to run, estimated runtime remaining: 1:16:17.806800
# Start: 12-03-1989; End: 10-04-1989
# 4 search results for selected time period
# 399 months left to run, estimated runtime remaining: 1:15:52.730049
# Start: 11-04-1989; End: 10-05-1989
# 9 search results for selected time period
# 398 months left to run, estimated runtime remaining: 1:15:27.465716
# Start: 11-05-1989; End: 09-06-1989
# 7 search results for selected time period
# 397 months left to run, estimated runtime remaining: 1:17:01.934344
# Start: 10-06-1989; End: 09-07-1989
# 8 search results for selected time period
# 396 months left to run, estimated runtime remaining: 1:16:35.759388
# Start: 10-07-1989; End: 08-08-1989
# 6 search results for selected time period
# 395 months left to run, estimated runtime remaining: 1:16:09.952500
# Start: 09-08-1989; End: 07-09-1989
# No search results for selected time period
# 394 months left to run, estimated runtime remaining: 1:15:44.347932
# Start: 08-09-1989; End: 07-10-1989
# No search results for selected time period
# 393 months left to run, estimated runtime remaining: 1:15:19.459128
# Start: 08-10-1989; End: 06-11-1989
# 7 search results for selected time period
# 392 months left to run, estimated runtime remaining: 1:14:54.758240
# Start: 07-11-1989; End: 06-12-1989
# 6 search results for selected time period
# 391 months left to run, estimated runtime remaining: 1:14:30.193520
# Start: 07-12-1989; End: 05-01-1990
# 4 search results for selected time period
# 390 months left to run, estimated runtime remaining: 1:14:05.654070
# Start: 06-01-1990; End: 04-02-1990
# 6 search results for selected time period
# 389 months left to run, estimated runtime remaining: 1:13:41.651357
# Start: 05-02-1990; End: 06-03-1990
# 7 search results for selected time period
# 388 months left to run, estimated runtime remaining: 1:15:07.283480
# Start: 07-03-1990; End: 05-04-1990
# 8 search results for selected time period
# 387 months left to run, estimated runtime remaining: 1:14:42.914346
# Start: 06-04-1990; End: 05-05-1990
# 5 search results for selected time period
# 386 months left to run, estimated runtime remaining: 1:14:18.621152
# Start: 06-05-1990; End: 04-06-1990
# 5 search results for selected time period
# 385 months left to run, estimated runtime remaining: 1:13:54.337600
# Start: 05-06-1990; End: 04-07-1990
# 9 search results for selected time period
# 384 months left to run, estimated runtime remaining: 1:13:30.470400
# Start: 05-07-1990; End: 03-08-1990
# 6 search results for selected time period
# 383 months left to run, estimated runtime remaining: 1:13:07.667533
# Start: 04-08-1990; End: 02-09-1990
# No search results for selected time period
# 382 months left to run, estimated runtime remaining: 1:12:44.288880
# Start: 03-09-1990; End: 02-10-1990
# No search results for selected time period
# 381 months left to run, estimated runtime remaining: 1:12:22.034115
# Start: 03-10-1990; End: 01-11-1990
# 5 search results for selected time period
# 380 months left to run, estimated runtime remaining: 1:11:58.730400
# Start: 02-11-1990; End: 01-12-1990
# 6 search results for selected time period
# 379 months left to run, estimated runtime remaining: 1:13:15.347896
# Start: 02-12-1990; End: 31-12-1990
# 5 search results for selected time period
# 378 months left to run, estimated runtime remaining: 1:12:51.926454
# Start: 01-01-1991; End: 30-01-1991
# 5 search results for selected time period
# 377 months left to run, estimated runtime remaining: 1:12:28.786988
# Start: 31-01-1991; End: 01-03-1991
# 9 search results for selected time period
# 376 months left to run, estimated runtime remaining: 1:12:06.844064
# Start: 02-03-1991; End: 31-03-1991
# 7 search results for selected time period
# 375 months left to run, estimated runtime remaining: 1:11:44.026500
# Start: 01-04-1991; End: 30-04-1991
# 5 search results for selected time period
# 374 months left to run, estimated runtime remaining: 1:11:21.470094
# Start: 01-05-1991; End: 30-05-1991
# 6 search results for selected time period
# 373 months left to run, estimated runtime remaining: 1:10:59.109452
# Start: 31-05-1991; End: 29-06-1991
# 8 search results for selected time period
# 372 months left to run, estimated runtime remaining: 1:10:36.716184
# Start: 30-06-1991; End: 29-07-1991
# 7 search results for selected time period
# 371 months left to run, estimated runtime remaining: 1:10:14.721385
# Start: 30-07-1991; End: 28-08-1991
# No search results for selected time period
# 370 months left to run, estimated runtime remaining: 1:11:24.119740
# Start: 29-08-1991; End: 27-09-1991
# No search results for selected time period
# 369 months left to run, estimated runtime remaining: 1:11:01.426389
# Start: 28-09-1991; End: 27-10-1991
# 3 search results for selected time period
# 368 months left to run, estimated runtime remaining: 1:10:39.134784
# Start: 28-10-1991; End: 26-11-1991
# 8 search results for selected time period
# 367 months left to run, estimated runtime remaining: 1:10:17.776493
# Start: 27-11-1991; End: 26-12-1991
# 3 search results for selected time period
# 366 months left to run, estimated runtime remaining: 1:09:55.636608
# Start: 27-12-1991; End: 25-01-1992
# 4 search results for selected time period
# 365 months left to run, estimated runtime remaining: 1:09:33.680465
# Start: 26-01-1992; End: 24-02-1992
# 8 search results for selected time period
# 364 months left to run, estimated runtime remaining: 1:09:11.963816
# Start: 25-02-1992; End: 25-03-1992
# 6 search results for selected time period
# 363 months left to run, estimated runtime remaining: 1:08:50.567562
# Start: 26-03-1992; End: 24-04-1992
# No search results for selected time period
# 362 months left to run, estimated runtime remaining: 1:08:29.540202
# Start: 25-04-1992; End: 24-05-1992
# 4 search results for selected time period
# 361 months left to run, estimated runtime remaining: 1:09:32.670845
# Start: 25-05-1992; End: 23-06-1992
# 7 search results for selected time period
# 360 months left to run, estimated runtime remaining: 1:09:10.978920
# Start: 24-06-1992; End: 23-07-1992
# 6 search results for selected time period
# 359 months left to run, estimated runtime remaining: 1:08:49.500174
# Start: 24-07-1992; End: 22-08-1992
# No search results for selected time period
# 358 months left to run, estimated runtime remaining: 1:08:28.681512
# Start: 23-08-1992; End: 21-09-1992
# No search results for selected time period
# 357 months left to run, estimated runtime remaining: 1:08:07.414737
# Start: 22-09-1992; End: 21-10-1992
# 1 search result for selected time period
# 356 months left to run, estimated runtime remaining: 1:07:46.343072
# Start: 22-10-1992; End: 20-11-1992
# 3 search results for selected time period
# 355 months left to run, estimated runtime remaining: 1:07:25.475275
# Start: 21-11-1992; End: 20-12-1992
# 5 search results for selected time period
# 354 months left to run, estimated runtime remaining: 1:07:04.745652
# Start: 21-12-1992; End: 19-01-1993
# 3 search results for selected time period
# 353 months left to run, estimated runtime remaining: 1:06:44.478949
# Start: 20-01-1993; End: 18-02-1993
# 9 search results for selected time period
# 352 months left to run, estimated runtime remaining: 1:07:42.072256
# Start: 19-02-1993; End: 20-03-1993
# 8 search results for selected time period
# 351 months left to run, estimated runtime remaining: 1:07:21.640044
# Start: 21-03-1993; End: 19-04-1993
# 5 search results for selected time period
# 350 months left to run, estimated runtime remaining: 1:07:00.899750
# Start: 20-04-1993; End: 19-05-1993
# 9 search results for selected time period
# 349 months left to run, estimated runtime remaining: 1:06:40.588745
# Start: 20-05-1993; End: 18-06-1993
# 6 search results for selected time period
# 348 months left to run, estimated runtime remaining: 1:06:20.437572
# Start: 19-06-1993; End: 18-07-1993
# 8 search results for selected time period
# 347 months left to run, estimated runtime remaining: 1:06:00.206900
# Start: 19-07-1993; End: 17-08-1993
# 2 search results for selected time period
# 346 months left to run, estimated runtime remaining: 1:05:39.997842
# Start: 18-08-1993; End: 16-09-1993
# No search results for selected time period
# 345 months left to run, estimated runtime remaining: 1:05:20.166000
# Start: 17-09-1993; End: 16-10-1993
# No search results for selected time period
# 344 months left to run, estimated runtime remaining: 1:05:01.205616
# Start: 17-10-1993; End: 15-11-1993
# 6 search results for selected time period
# 343 months left to run, estimated runtime remaining: 1:05:53.414570
# Start: 16-11-1993; End: 15-12-1993
# 7 search results for selected time period
# 342 months left to run, estimated runtime remaining: 1:05:33.348156
# Start: 16-12-1993; End: 14-01-1994
# 3 search results for selected time period
# 341 months left to run, estimated runtime remaining: 1:05:13.324184
# Start: 15-01-1994; End: 13-02-1994
# No search results for selected time period
# 340 months left to run, estimated runtime remaining: 1:04:53.973080
# Start: 14-02-1994; End: 15-03-1994
# 9 search results for selected time period
# 339 months left to run, estimated runtime remaining: 1:04:34.489986
# Start: 16-03-1994; End: 14-04-1994
# 3 search results for selected time period
# 338 months left to run, estimated runtime remaining: 1:04:15.557888
# Start: 15-04-1994; End: 14-05-1994
# 7 search results for selected time period
# 337 months left to run, estimated runtime remaining: 1:03:56.200745
# Start: 15-05-1994; End: 13-06-1994
# 3 search results for selected time period
# 336 months left to run, estimated runtime remaining: 1:03:37.006368
# Start: 14-06-1994; End: 13-07-1994
# 9 search results for selected time period
# 335 months left to run, estimated runtime remaining: 1:03:17.888635
# Start: 14-07-1994; End: 12-08-1994
# 1 search result for selected time period
# 334 months left to run, estimated runtime remaining: 1:05:37.078774
# Start: 13-08-1994; End: 11-09-1994
# No search results for selected time period
# 333 months left to run, estimated runtime remaining: 1:05:16.888524
# Start: 12-09-1994; End: 11-10-1994
# No search results for selected time period
# 332 months left to run, estimated runtime remaining: 1:04:56.751728
# Start: 12-10-1994; End: 10-11-1994
# 5 search results for selected time period
# 331 months left to run, estimated runtime remaining: 1:04:37.469048
# Start: 11-11-1994; End: 10-12-1994
# 6 search results for selected time period
# 330 months left to run, estimated runtime remaining: 1:04:17.542590
# Start: 11-12-1994; End: 09-01-1995
# 2 search results for selected time period
# 329 months left to run, estimated runtime remaining: 1:03:58.460766
# Start: 10-01-1995; End: 08-02-1995
# 5 search results for selected time period
# 328 months left to run, estimated runtime remaining: 1:03:39.883080
# Start: 09-02-1995; End: 10-03-1995
# 8 search results for selected time period
# 327 months left to run, estimated runtime remaining: 1:03:20.398578
# Start: 11-03-1995; End: 09-04-1995
# 7 search results for selected time period
# 326 months left to run, estimated runtime remaining: 1:03:01.500570
# Start: 10-04-1995; End: 09-05-1995
# 8 search results for selected time period
# 325 months left to run, estimated runtime remaining: 1:03:45.005925
# Start: 10-05-1995; End: 08-06-1995
# 7 search results for selected time period
# 324 months left to run, estimated runtime remaining: 1:03:25.370928
# Start: 09-06-1995; End: 08-07-1995
# 8 search results for selected time period
# 323 months left to run, estimated runtime remaining: 1:03:05.941140
# Start: 09-07-1995; End: 07-08-1995
# 1 search result for selected time period
# 322 months left to run, estimated runtime remaining: 1:02:46.567630
# Start: 08-08-1995; End: 06-09-1995
# No search results for selected time period
# 321 months left to run, estimated runtime remaining: 1:02:27.483042
# Start: 07-09-1995; End: 06-10-1995
# No search results for selected time period
# 320 months left to run, estimated runtime remaining: 1:02:08.722240
# Start: 07-10-1995; End: 05-11-1995
# 4 search results for selected time period
# 319 months left to run, estimated runtime remaining: 1:01:49.942247
# Start: 06-11-1995; End: 05-12-1995
# 1 search result for selected time period
# 318 months left to run, estimated runtime remaining: 1:01:31.061298
# Start: 06-12-1995; End: 04-01-1996
# 4 search results for selected time period
# 317 months left to run, estimated runtime remaining: 1:01:12.775948
# Start: 05-01-1996; End: 03-02-1996
# 8 search results for selected time period
# 316 months left to run, estimated runtime remaining: 1:01:51.861452
# Start: 04-02-1996; End: 04-03-1996
# 9 search results for selected time period
# 315 months left to run, estimated runtime remaining: 1:01:33.442410
# Start: 05-03-1996; End: 03-04-1996
# 8 search results for selected time period
# 314 months left to run, estimated runtime remaining: 1:01:14.626134
# Start: 04-04-1996; End: 03-05-1996
# 6 search results for selected time period
# 313 months left to run, estimated runtime remaining: 1:00:56.087583
# Start: 04-05-1996; End: 02-06-1996
# 1 search result for selected time period
# 312 months left to run, estimated runtime remaining: 1:00:37.554336
# Start: 03-06-1996; End: 02-07-1996
# 8 search results for selected time period
# 311 months left to run, estimated runtime remaining: 1:00:19.013078
# Start: 03-07-1996; End: 01-08-1996
# 7 search results for selected time period
# 310 months left to run, estimated runtime remaining: 1:00:00.583350
# Start: 02-08-1996; End: 31-08-1996
# No search results for selected time period
# 309 months left to run, estimated runtime remaining: 0:59:42.269754
# Start: 01-09-1996; End: 30-09-1996
# No search results for selected time period
# 308 months left to run, estimated runtime remaining: 0:59:24.202488
# Start: 01-10-1996; End: 30-10-1996
# 2 search results for selected time period
# 307 months left to run, estimated runtime remaining: 0:59:59.362556
# Start: 31-10-1996; End: 29-11-1996
# 9 search results for selected time period
# 306 months left to run, estimated runtime remaining: 0:59:41.082504
# Start: 30-11-1996; End: 29-12-1996
# 5 search results for selected time period
# 305 months left to run, estimated runtime remaining: 0:59:22.883120
# Start: 30-12-1996; End: 28-01-1997
# 5 search results for selected time period
# 304 months left to run, estimated runtime remaining: 0:59:04.675264
# Start: 29-01-1997; End: 27-02-1997
# 9 search results for selected time period
# 303 months left to run, estimated runtime remaining: 0:58:46.817889
# Start: 28-02-1997; End: 29-03-1997
# 6 search results for selected time period
# 302 months left to run, estimated runtime remaining: 0:58:29.163594
# Start: 30-03-1997; End: 28-04-1997
# No search results for selected time period
# 301 months left to run, estimated runtime remaining: 0:58:11.373347
# Start: 29-04-1997; End: 28-05-1997
# 1 search result for selected time period
# 300 months left to run, estimated runtime remaining: 0:57:53.457900
# Start: 29-05-1997; End: 27-06-1997
# 4 search results for selected time period
# 299 months left to run, estimated runtime remaining: 0:57:35.731071
# Start: 28-06-1997; End: 27-07-1997
# 4 search results for selected time period
# 298 months left to run, estimated runtime remaining: 0:58:08.054538
# Start: 28-07-1997; End: 26-08-1997
# 1 search result for selected time period
# 297 months left to run, estimated runtime remaining: 0:57:50.549841
# Start: 27-08-1997; End: 25-09-1997
# No search results for selected time period
# 296 months left to run, estimated runtime remaining: 0:57:33.327808
# Start: 26-09-1997; End: 25-10-1997
# No search results for selected time period
# 295 months left to run, estimated runtime remaining: 0:57:15.534010
# Start: 26-10-1997; End: 24-11-1997
# 4 search results for selected time period
# 294 months left to run, estimated runtime remaining: 0:56:58.334472
# Start: 25-11-1997; End: 24-12-1997
# 4 search results for selected time period
# 293 months left to run, estimated runtime remaining: 0:56:40.820235
# Start: 25-12-1997; End: 23-01-1998
# 2 search results for selected time period
# 292 months left to run, estimated runtime remaining: 0:56:23.959676
# Start: 24-01-1998; End: 22-02-1998
# 4 search results for selected time period
# 291 months left to run, estimated runtime remaining: 0:56:06.686379
# Start: 23-02-1998; End: 24-03-1998
# 4 search results for selected time period
# 290 months left to run, estimated runtime remaining: 0:55:49.514500
# Start: 25-03-1998; End: 23-04-1998
# 4 search results for selected time period
# 289 months left to run, estimated runtime remaining: 0:56:18.678481
# Start: 24-04-1998; End: 23-05-1998
# 4 search results for selected time period
# 288 months left to run, estimated runtime remaining: 0:56:01.336992
# Start: 24-05-1998; End: 22-06-1998
# 4 search results for selected time period
# 287 months left to run, estimated runtime remaining: 0:55:44.130888
# Start: 23-06-1998; End: 22-07-1998
# 4 search results for selected time period
# 286 months left to run, estimated runtime remaining: 0:55:26.818638
# Start: 23-07-1998; End: 21-08-1998
# 1 search result for selected time period
# 285 months left to run, estimated runtime remaining: 0:55:09.482415
# Start: 22-08-1998; End: 20-09-1998
# No search results for selected time period
# 284 months left to run, estimated runtime remaining: 0:54:52.337592
# Start: 21-09-1998; End: 20-10-1998
# No search results for selected time period
# 283 months left to run, estimated runtime remaining: 0:54:35.216166
# Start: 21-10-1998; End: 19-11-1998
# 5 search results for selected time period
# 282 months left to run, estimated runtime remaining: 0:54:18.440346
# Start: 20-11-1998; End: 19-12-1998
# 3 search results for selected time period
# 281 months left to run, estimated runtime remaining: 0:54:01.679225
# Start: 20-12-1998; End: 18-01-1999
# 1 search result for selected time period
# 280 months left to run, estimated runtime remaining: 0:54:28.056120
# Start: 19-01-1999; End: 17-02-1999
# 4 search results for selected time period
# 279 months left to run, estimated runtime remaining: 0:54:11.136222
# Start: 18-02-1999; End: 19-03-1999
# No search results for selected time period
# 278 months left to run, estimated runtime remaining: 0:53:54.314550
# Start: 20-03-1999; End: 18-04-1999
# 3 search results for selected time period
# 277 months left to run, estimated runtime remaining: 0:53:37.469401
# Start: 19-04-1999; End: 18-05-1999
# 4 search results for selected time period
# 276 months left to run, estimated runtime remaining: 0:53:20.703552
# Start: 19-05-1999; End: 17-06-1999
# 4 search results for selected time period
# 275 months left to run, estimated runtime remaining: 0:53:04.043225
# Start: 18-06-1999; End: 17-07-1999
# 4 search results for selected time period
# 274 months left to run, estimated runtime remaining: 0:52:47.721672
# Start: 18-07-1999; End: 16-08-1999
# 1 search result for selected time period
# 273 months left to run, estimated runtime remaining: 0:52:31.145361
# Start: 17-08-1999; End: 15-09-1999
# No search results for selected time period
# 272 months left to run, estimated runtime remaining: 0:52:14.646048
# Start: 16-09-1999; End: 15-10-1999
# No search results for selected time period
# 271 months left to run, estimated runtime remaining: 0:52:38.669768
# Start: 16-10-1999; End: 14-11-1999
# 4 search results for selected time period
# 270 months left to run, estimated runtime remaining: 0:52:22.148760
# Start: 15-11-1999; End: 14-12-1999
# 3 search results for selected time period
# 269 months left to run, estimated runtime remaining: 0:52:05.762246
# Start: 15-12-1999; End: 13-01-2000
# 2 search results for selected time period
# 268 months left to run, estimated runtime remaining: 0:51:49.584972
# Start: 14-01-2000; End: 12-02-2000
# 3 search results for selected time period
# 267 months left to run, estimated runtime remaining: 0:51:33.338913
# Start: 13-02-2000; End: 13-03-2000
# 3 search results for selected time period
# 266 months left to run, estimated runtime remaining: 0:51:17.249994
# Start: 14-03-2000; End: 12-04-2000
# 5 search results for selected time period
# 265 months left to run, estimated runtime remaining: 0:51:01.327435
# Start: 13-04-2000; End: 12-05-2000
# 3 search results for selected time period
# 264 months left to run, estimated runtime remaining: 0:50:45.229440
# Start: 13-05-2000; End: 11-06-2000
# 3 search results for selected time period
# 263 months left to run, estimated runtime remaining: 0:50:29.339463
# Start: 12-06-2000; End: 11-07-2000
# 4 search results for selected time period
# 262 months left to run, estimated runtime remaining: 0:50:51.004410
# Start: 12-07-2000; End: 10-08-2000
# 3 search results for selected time period
# 261 months left to run, estimated runtime remaining: 0:50:34.978209
# Start: 11-08-2000; End: 09-09-2000
# No search results for selected time period
# 260 months left to run, estimated runtime remaining: 0:50:18.789540
# Start: 10-09-2000; End: 09-10-2000
# No search results for selected time period
# 259 months left to run, estimated runtime remaining: 0:50:02.749652
# Start: 10-10-2000; End: 08-11-2000
# 3 search results for selected time period
# 258 months left to run, estimated runtime remaining: 0:49:46.880448
# Start: 09-11-2000; End: 08-12-2000
# 3 search results for selected time period
# 257 months left to run, estimated runtime remaining: 0:49:31.078055
# Start: 09-12-2000; End: 07-01-2001
# 2 search results for selected time period
# 256 months left to run, estimated runtime remaining: 0:49:15.317504
# Start: 08-01-2001; End: 06-02-2001
# 3 search results for selected time period
# 255 months left to run, estimated runtime remaining: 0:48:59.883015
# Start: 07-02-2001; End: 08-03-2001
# 3 search results for selected time period
# 254 months left to run, estimated runtime remaining: 0:48:44.158490
# Start: 09-03-2001; End: 07-04-2001
# 4 search results for selected time period
# 253 months left to run, estimated runtime remaining: 0:49:03.478912
# Start: 08-04-2001; End: 07-05-2001
# 1 search result for selected time period
# 252 months left to run, estimated runtime remaining: 0:48:47.753892
# Start: 08-05-2001; End: 06-06-2001
# 1 search result for selected time period
# 251 months left to run, estimated runtime remaining: 0:48:31.940858
# Start: 07-06-2001; End: 06-07-2001
# 2 search results for selected time period
# 250 months left to run, estimated runtime remaining: 0:48:16.231000
# Start: 07-07-2001; End: 05-08-2001
# No search results for selected time period
# 249 months left to run, estimated runtime remaining: 0:48:00.796536
# Start: 06-08-2001; End: 04-09-2001
# No search results for selected time period
# 248 months left to run, estimated runtime remaining: 0:47:45.164584
# Start: 05-09-2001; End: 04-10-2001
# No search results for selected time period
# 247 months left to run, estimated runtime remaining: 0:47:29.550080
# Start: 05-10-2001; End: 03-11-2001
# 3 search results for selected time period
# 246 months left to run, estimated runtime remaining: 0:47:14.387400
# Start: 04-11-2001; End: 03-12-2001
# 7 search results for selected time period
# 245 months left to run, estimated runtime remaining: 0:46:59.089560
# Start: 04-12-2001; End: 02-01-2002
# 3 search results for selected time period
# 244 months left to run, estimated runtime remaining: 0:47:16.837696
# Start: 03-01-2002; End: 01-02-2002
# 5 search results for selected time period
# 243 months left to run, estimated runtime remaining: 0:47:01.511151
# Start: 02-02-2002; End: 03-03-2002
# 4 search results for selected time period
# 242 months left to run, estimated runtime remaining: 0:46:46.086800
# Start: 04-03-2002; End: 02-04-2002
# 4 search results for selected time period
# 241 months left to run, estimated runtime remaining: 0:46:30.738066
# Start: 03-04-2002; End: 02-05-2002
# 5 search results for selected time period
# 240 months left to run, estimated runtime remaining: 0:46:15.399840
# Start: 03-05-2002; End: 01-06-2002
# 4 search results for selected time period
# 239 months left to run, estimated runtime remaining: 0:45:59.975585
# Start: 02-06-2002; End: 01-07-2002
# 3 search results for selected time period
# 238 months left to run, estimated runtime remaining: 0:45:44.751184
# Start: 02-07-2002; End: 31-07-2002
# 8 search results for selected time period
# 237 months left to run, estimated runtime remaining: 0:45:29.757942
# Start: 01-08-2002; End: 30-08-2002
# No search results for selected time period
# 236 months left to run, estimated runtime remaining: 0:45:14.709180
# Start: 31-08-2002; End: 29-09-2002
# No search results for selected time period
# 235 months left to run, estimated runtime remaining: 0:45:30.460300
# Start: 30-09-2002; End: 29-10-2002
# 3 search results for selected time period
# 234 months left to run, estimated runtime remaining: 0:45:15.195366
# Start: 30-10-2002; End: 28-11-2002
# 3 search results for selected time period
# 233 months left to run, estimated runtime remaining: 0:44:59.905674
# Start: 29-11-2002; End: 28-12-2002
# 5 search results for selected time period
# 232 months left to run, estimated runtime remaining: 0:44:44.893080
# Start: 29-12-2002; End: 27-01-2003
# 3 search results for selected time period
# 231 months left to run, estimated runtime remaining: 0:44:30.078873
# Start: 28-01-2003; End: 26-02-2003
# 3 search results for selected time period
# 230 months left to run, estimated runtime remaining: 0:44:14.941290
# Start: 27-02-2003; End: 28-03-2003
# 3 search results for selected time period
# 229 months left to run, estimated runtime remaining: 0:43:59.771623
# Start: 29-03-2003; End: 27-04-2003
# 3 search results for selected time period
# 228 months left to run, estimated runtime remaining: 0:43:44.975628
# Start: 28-04-2003; End: 27-05-2003
# 5 search results for selected time period
# 227 months left to run, estimated runtime remaining: 0:43:29.997876
# Start: 28-05-2003; End: 26-06-2003
# 5 search results for selected time period
# 226 months left to run, estimated runtime remaining: 0:44:22.777200
# Start: 27-06-2003; End: 26-07-2003
# 4 search results for selected time period
# 225 months left to run, estimated runtime remaining: 0:44:07.484325
# Start: 27-07-2003; End: 25-08-2003
# No search results for selected time period
# 224 months left to run, estimated runtime remaining: 0:43:52.110208
# Start: 26-08-2003; End: 24-09-2003
# 2 search results for selected time period
# 223 months left to run, estimated runtime remaining: 0:43:36.795284
# Start: 25-09-2003; End: 24-10-2003
# No search results for selected time period
# 222 months left to run, estimated runtime remaining: 0:43:21.698142
# Start: 25-10-2003; End: 23-11-2003
# 6 search results for selected time period
# 221 months left to run, estimated runtime remaining: 0:43:06.625548
# Start: 24-11-2003; End: 23-12-2003
# 3 search results for selected time period
# 220 months left to run, estimated runtime remaining: 0:42:51.500800
# Start: 24-12-2003; End: 22-01-2004
# 3 search results for selected time period
# 219 months left to run, estimated runtime remaining: 0:42:36.459489
# Start: 23-01-2004; End: 21-02-2004
# 4 search results for selected time period
# 218 months left to run, estimated runtime remaining: 0:42:21.553654
# Start: 22-02-2004; End: 22-03-2004
# 4 search results for selected time period
# 217 months left to run, estimated runtime remaining: 0:42:33.166665
# Start: 23-03-2004; End: 21-04-2004
# 1 search result for selected time period
# 216 months left to run, estimated runtime remaining: 0:42:18.071496
# Start: 22-04-2004; End: 21-05-2004
# 4 search results for selected time period
# 215 months left to run, estimated runtime remaining: 0:42:02.962220
# Start: 22-05-2004; End: 20-06-2004
# 3 search results for selected time period
# 214 months left to run, estimated runtime remaining: 0:41:48.097334
# Start: 21-06-2004; End: 20-07-2004
# 5 search results for selected time period
# 213 months left to run, estimated runtime remaining: 0:41:33.114093
# Start: 21-07-2004; End: 19-08-2004
# 2 search results for selected time period
# 212 months left to run, estimated runtime remaining: 0:41:18.445148
# Start: 20-08-2004; End: 18-09-2004
# 2 search results for selected time period
# 211 months left to run, estimated runtime remaining: 0:41:03.659843
# Start: 19-09-2004; End: 18-10-2004
# No search results for selected time period
# 210 months left to run, estimated runtime remaining: 0:40:48.892110
# Start: 19-10-2004; End: 17-11-2004
# No search results for selected time period
# 209 months left to run, estimated runtime remaining: 0:40:34.046813
# Start: 18-11-2004; End: 17-12-2004
# No search results for selected time period
# 208 months left to run, estimated runtime remaining: 0:40:44.089856
# Start: 18-12-2004; End: 16-01-2005
# No search results for selected time period
# 207 months left to run, estimated runtime remaining: 0:40:29.205030
# Start: 17-01-2005; End: 15-02-2005
# No search results for selected time period
# 206 months left to run, estimated runtime remaining: 0:40:14.345750
# Start: 16-02-2005; End: 17-03-2005
# No search results for selected time period
# 205 months left to run, estimated runtime remaining: 0:39:59.542630
# Start: 18-03-2005; End: 16-04-2005
# No search results for selected time period
# 204 months left to run, estimated runtime remaining: 0:39:44.822220
# Start: 17-04-2005; End: 16-05-2005
# No search results for selected time period
# 203 months left to run, estimated runtime remaining: 0:39:30.093817
# Start: 17-05-2005; End: 15-06-2005
# No search results for selected time period
# 202 months left to run, estimated runtime remaining: 0:39:15.414132
# Start: 16-06-2005; End: 15-07-2005
# No search results for selected time period
# 201 months left to run, estimated runtime remaining: 0:39:00.803790
# Start: 16-07-2005; End: 14-08-2005
# No search results for selected time period
# 200 months left to run, estimated runtime remaining: 0:38:46.264000
# Start: 15-08-2005; End: 13-09-2005
# No search results for selected time period
# 199 months left to run, estimated runtime remaining: 0:38:54.948789
# Start: 14-09-2005; End: 13-10-2005
# No search results for selected time period
# 198 months left to run, estimated runtime remaining: 0:38:40.335270
# Start: 14-10-2005; End: 12-11-2005
# No search results for selected time period
# 197 months left to run, estimated runtime remaining: 0:38:25.729764
# Start: 13-11-2005; End: 12-12-2005
# No search results for selected time period
# 196 months left to run, estimated runtime remaining: 0:38:11.432276
# Start: 13-12-2005; End: 11-01-2006
# No search results for selected time period
# 195 months left to run, estimated runtime remaining: 0:37:56.985750
# Start: 12-01-2006; End: 10-02-2006
# No search results for selected time period
# 194 months left to run, estimated runtime remaining: 0:37:42.499586
# Start: 11-02-2006; End: 12-03-2006
# No search results for selected time period
# 193 months left to run, estimated runtime remaining: 0:37:28.047016
# Start: 13-03-2006; End: 11-04-2006
# No search results for selected time period
# 192 months left to run, estimated runtime remaining: 0:37:13.953216
# Start: 12-04-2006; End: 11-05-2006
# No search results for selected time period
# 191 months left to run, estimated runtime remaining: 0:36:59.658559
# Start: 12-05-2006; End: 10-06-2006
# 1 search result for selected time period
# 190 months left to run, estimated runtime remaining: 0:37:06.777960
# Start: 11-06-2006; End: 10-07-2006
# 5 search results for selected time period
# ...
# Start: 05-01-2013; End: 03-02-2013
# 5 search results for selected time period
# 109 months left to run, estimated runtime remaining: 0:21:19.872550
# Start: 04-02-2013; End: 05-03-2013
# 4 search results for selected time period
# 108 months left to run, estimated runtime remaining: 0:21:06.902316
# Start: 06-03-2013; End: 04-04-2013
# 4 search results for selected time period
# 107 months left to run, estimated runtime remaining: 0:20:53.956647
# Start: 05-04-2013; End: 04-05-2013
# 1 search result for selected time period
# 106 months left to run, estimated runtime remaining: 0:20:41.121034
# Start: 05-05-2013; End: 03-06-2013
# 1 search result for selected time period
# 105 months left to run, estimated runtime remaining: 0:20:28.301235
# Start: 04-06-2013; End: 03-07-2013
# 7 search results for selected time period
# 104 months left to run, estimated runtime remaining: 0:20:15.465264
# Start: 04-07-2013; End: 02-08-2013
# 3 search results for selected time period
# 103 months left to run, estimated runtime remaining: 0:20:02.668994
# Start: 03-08-2013; End: 01-09-2013
# No search results for selected time period
# 102 months left to run, estimated runtime remaining: 0:19:49.828062
# Start: 02-09-2013; End: 01-10-2013
# 2 search results for selected time period
# 101 months left to run, estimated runtime remaining: 0:19:46.023810
# Start: 02-10-2013; End: 31-10-2013
# 5 search results for selected time period
# 100 months left to run, estimated runtime remaining: 0:19:33.173800
# Start: 01-11-2013; End: 30-11-2013
# 5 search results for selected time period
# 99 months left to run, estimated runtime remaining: 0:19:20.437014
# Start: 01-12-2013; End: 30-12-2013
# 3 search results for selected time period
# 98 months left to run, estimated runtime remaining: 0:19:07.613320
# Start: 31-12-2013; End: 29-01-2014
# 5 search results for selected time period
# 97 months left to run, estimated runtime remaining: 0:18:54.835883
# Start: 30-01-2014; End: 28-02-2014
# 4 search results for selected time period
# 96 months left to run, estimated runtime remaining: 0:18:42.067584
# Start: 01-03-2014; End: 30-03-2014
# 5 search results for selected time period
# 95 months left to run, estimated runtime remaining: 0:18:29.332860
# Start: 31-03-2014; End: 29-04-2014
# 2 search results for selected time period
# 94 months left to run, estimated runtime remaining: 0:18:16.610956
# Start: 30-04-2014; End: 29-05-2014
# 4 search results for selected time period
# 93 months left to run, estimated runtime remaining: 0:18:03.934065
# Start: 30-05-2014; End: 28-06-2014
# 3 search results for selected time period
# 92 months left to run, estimated runtime remaining: 0:17:59.239304
# Start: 29-06-2014; End: 28-07-2014
# 4 search results for selected time period
# 91 months left to run, estimated runtime remaining: 0:17:46.516360
# Start: 29-07-2014; End: 27-08-2014
# No search results for selected time period
# 90 months left to run, estimated runtime remaining: 0:17:33.831060
# Start: 28-08-2014; End: 26-09-2014
# 2 search results for selected time period
# 89 months left to run, estimated runtime remaining: 0:17:21.142203
# Start: 27-09-2014; End: 26-10-2014
# 3 search results for selected time period
# 88 months left to run, estimated runtime remaining: 0:17:08.567936
# Start: 27-10-2014; End: 25-11-2014
# 4 search results for selected time period
# 87 months left to run, estimated runtime remaining: 0:16:55.929798
# Start: 26-11-2014; End: 25-12-2014
# 4 search results for selected time period
# 86 months left to run, estimated runtime remaining: 0:16:43.328116
# Start: 26-12-2014; End: 24-01-2015
# 4 search results for selected time period
# 85 months left to run, estimated runtime remaining: 0:16:30.761275
# Start: 25-01-2015; End: 23-02-2015
# 4 search results for selected time period
# 84 months left to run, estimated runtime remaining: 0:16:18.214524
# Start: 24-02-2015; End: 25-03-2015
# 6 search results for selected time period
# 83 months left to run, estimated runtime remaining: 0:16:12.704971
# Start: 26-03-2015; End: 24-04-2015
# No search results for selected time period
# 82 months left to run, estimated runtime remaining: 0:16:00.093556
# Start: 25-04-2015; End: 24-05-2015
# No search results for selected time period
# 81 months left to run, estimated runtime remaining: 0:15:47.534598
# Start: 25-05-2015; End: 23-06-2015
# 3 search results for selected time period
# 80 months left to run, estimated runtime remaining: 0:15:35.030000
# Start: 24-06-2015; End: 23-07-2015
# 3 search results for selected time period
# 79 months left to run, estimated runtime remaining: 0:15:22.504962
# Start: 24-07-2015; End: 22-08-2015
# No search results for selected time period
# 78 months left to run, estimated runtime remaining: 0:15:10.008762
# Start: 23-08-2015; End: 21-09-2015
# 2 search results for selected time period
# 77 months left to run, estimated runtime remaining: 0:14:57.520778
# Start: 22-09-2015; End: 21-10-2015
# 2 search results for selected time period
# 76 months left to run, estimated runtime remaining: 0:14:45.076544
# Start: 22-10-2015; End: 20-11-2015
# 3 search results for selected time period
# 75 months left to run, estimated runtime remaining: 0:14:32.641425
# Start: 21-11-2015; End: 20-12-2015
# 3 search results for selected time period
# 74 months left to run, estimated runtime remaining: 0:14:26.398068
# Start: 21-12-2015; End: 19-01-2016
# 2 search results for selected time period
# 73 months left to run, estimated runtime remaining: 0:14:13.948233
# Start: 20-01-2016; End: 18-02-2016
# 4 search results for selected time period
# 72 months left to run, estimated runtime remaining: 0:14:01.498992
# Start: 19-02-2016; End: 19-03-2016
# 4 search results for selected time period
# 71 months left to run, estimated runtime remaining: 0:13:49.151845
# Start: 20-03-2016; End: 18-04-2016
# 2 search results for selected time period
# 70 months left to run, estimated runtime remaining: 0:13:36.756500
# Start: 19-04-2016; End: 18-05-2016
# 4 search results for selected time period
# 69 months left to run, estimated runtime remaining: 0:13:24.442503
# Start: 19-05-2016; End: 17-06-2016
# 3 search results for selected time period
# 68 months left to run, estimated runtime remaining: 0:13:12.170760
# Start: 18-06-2016; End: 17-07-2016
# 3 search results for selected time period
# 67 months left to run, estimated runtime remaining: 0:12:59.854004
# Start: 18-07-2016; End: 16-08-2016
# 1 search result for selected time period
# 66 months left to run, estimated runtime remaining: 0:12:47.556438
# Start: 17-08-2016; End: 15-09-2016
# 2 search results for selected time period
# 65 months left to run, estimated runtime remaining: 0:12:40.622525
# Start: 16-09-2016; End: 15-10-2016
# 1 search result for selected time period
# 64 months left to run, estimated runtime remaining: 0:12:28.380800
# Start: 16-10-2016; End: 14-11-2016
# 3 search results for selected time period
# 63 months left to run, estimated runtime remaining: 0:12:16.109199
# Start: 15-11-2016; End: 14-12-2016
# 5 search results for selected time period
# 62 months left to run, estimated runtime remaining: 0:12:03.783784
# Start: 15-12-2016; End: 13-01-2017
# 1 search result for selected time period
# 61 months left to run, estimated runtime remaining: 0:11:51.548164
# Start: 14-01-2017; End: 12-02-2017
# 4 search results for selected time period
# 60 months left to run, estimated runtime remaining: 0:11:39.277380
# Start: 13-02-2017; End: 14-03-2017
# 3 search results for selected time period
# 59 months left to run, estimated runtime remaining: 0:11:27.031990
# Start: 15-03-2017; End: 13-04-2017
# 3 search results for selected time period
# 58 months left to run, estimated runtime remaining: 0:11:14.820140
# Start: 14-04-2017; End: 13-05-2017
# 2 search results for selected time period
# 57 months left to run, estimated runtime remaining: 0:11:02.637426
# Start: 14-05-2017; End: 12-06-2017
# No search results for selected time period
# 56 months left to run, estimated runtime remaining: 0:10:54.926216
# Start: 13-06-2017; End: 12-07-2017
# 3 search results for selected time period
# 55 months left to run, estimated runtime remaining: 0:10:42.688475
# Start: 13-07-2017; End: 11-08-2017
# 1 search result for selected time period
# 54 months left to run, estimated runtime remaining: 0:10:30.476946
# Start: 12-08-2017; End: 10-09-2017
# 1 search result for selected time period
# 53 months left to run, estimated runtime remaining: 0:10:18.425041
# Start: 11-09-2017; End: 10-10-2017
# 1 search result for selected time period
# 52 months left to run, estimated runtime remaining: 0:10:06.262072
# Start: 11-10-2017; End: 09-11-2017
# 4 search results for selected time period
# 51 months left to run, estimated runtime remaining: 0:09:54.114810
# Start: 10-11-2017; End: 09-12-2017
# 4 search results for selected time period
# 50 months left to run, estimated runtime remaining: 0:09:42.024550
# Start: 10-12-2017; End: 08-01-2018
# No search results for selected time period
# 49 months left to run, estimated runtime remaining: 0:09:29.953741
# Start: 09-01-2018; End: 07-02-2018
# 5 search results for selected time period
# 48 months left to run, estimated runtime remaining: 0:09:17.845488
# Start: 08-02-2018; End: 09-03-2018
# 3 search results for selected time period
# 47 months left to run, estimated runtime remaining: 0:09:09.456132
# Start: 10-03-2018; End: 08-04-2018
# 3 search results for selected time period
# 46 months left to run, estimated runtime remaining: 0:08:57.329496
# Start: 09-04-2018; End: 08-05-2018
# 3 search results for selected time period
# 45 months left to run, estimated runtime remaining: 0:08:45.231000
# Start: 09-05-2018; End: 07-06-2018
# No search results for selected time period
# 44 months left to run, estimated runtime remaining: 0:08:33.152992
# Start: 08-06-2018; End: 07-07-2018
# 4 search results for selected time period
# 43 months left to run, estimated runtime remaining: 0:08:21.069927
# Start: 08-07-2018; End: 06-08-2018
# 2 search results for selected time period
# 42 months left to run, estimated runtime remaining: 0:08:09.015408
# Start: 07-08-2018; End: 05-09-2018
# 1 search result for selected time period
# 41 months left to run, estimated runtime remaining: 0:07:56.981249
# Start: 06-09-2018; End: 05-10-2018
# 1 search result for selected time period
# 40 months left to run, estimated runtime remaining: 0:07:44.965640
# Start: 06-10-2018; End: 04-11-2018
# 4 search results for selected time period
# 39 months left to run, estimated runtime remaining: 0:07:32.972598
# Start: 05-11-2018; End: 04-12-2018
# 3 search results for selected time period
# 38 months left to run, estimated runtime remaining: 0:07:23.939256
# Start: 05-12-2018; End: 03-01-2019
# 3 search results for selected time period
# 37 months left to run, estimated runtime remaining: 0:07:11.911101
# Start: 04-01-2019; End: 02-02-2019
# 4 search results for selected time period
# 36 months left to run, estimated runtime remaining: 0:06:59.899500
# Start: 03-02-2019; End: 04-03-2019
# 4 search results for selected time period
# 35 months left to run, estimated runtime remaining: 0:06:47.936375
# Start: 05-03-2019; End: 03-04-2019
# 5 search results for selected time period
# 34 months left to run, estimated runtime remaining: 0:06:35.953426
# Start: 04-04-2019; End: 03-05-2019
# 4 search results for selected time period
# 33 months left to run, estimated runtime remaining: 0:06:23.996646
# Start: 04-05-2019; End: 02-06-2019
# 3 search results for selected time period
# 32 months left to run, estimated runtime remaining: 0:06:12.063616
# Start: 03-06-2019; End: 02-07-2019
# 4 search results for selected time period
# 31 months left to run, estimated runtime remaining: 0:06:00.149134
# Start: 03-07-2019; End: 01-08-2019
# 4 search results for selected time period
# 30 months left to run, estimated runtime remaining: 0:05:48.253050
# Start: 02-08-2019; End: 31-08-2019
# No search results for selected time period
# 29 months left to run, estimated runtime remaining: 0:05:38.564502
# Start: 01-09-2019; End: 30-09-2019
# 1 search result for selected time period
# 28 months left to run, estimated runtime remaining: 0:05:26.639768
# Start: 01-10-2019; End: 30-10-2019
# 3 search results for selected time period
# 27 months left to run, estimated runtime remaining: 0:05:14.736570
# Start: 31-10-2019; End: 29-11-2019
# No search results for selected time period
# 26 months left to run, estimated runtime remaining: 0:05:02.839264
# Start: 30-11-2019; End: 29-12-2019
# No search results for selected time period
# 25 months left to run, estimated runtime remaining: 0:04:50.955925
# Start: 30-12-2019; End: 28-01-2020
# 3 search results for selected time period
# 24 months left to run, estimated runtime remaining: 0:04:39.115440
# Start: 29-01-2020; End: 27-02-2020
# 4 search results for selected time period
# 23 months left to run, estimated runtime remaining: 0:04:27.280516
# Start: 28-02-2020; End: 28-03-2020
# 4 search results for selected time period
# 22 months left to run, estimated runtime remaining: 0:04:15.472184
# Start: 29-03-2020; End: 27-04-2020
# 1 search result for selected time period
# 21 months left to run, estimated runtime remaining: 0:04:03.674256
# Start: 28-04-2020; End: 27-05-2020
# 4 search results for selected time period
# 20 months left to run, estimated runtime remaining: 0:03:53.372560
# Start: 28-05-2020; End: 26-06-2020
# 4 search results for selected time period
# 19 months left to run, estimated runtime remaining: 0:03:41.545396
# Start: 27-06-2020; End: 26-07-2020
# 5 search results for selected time period
# 18 months left to run, estimated runtime remaining: 0:03:29.720988
# Start: 27-07-2020; End: 25-08-2020
# No search results for selected time period
# 17 months left to run, estimated runtime remaining: 0:03:17.915666
# Start: 26-08-2020; End: 24-09-2020
# 4 search results for selected time period
# 16 months left to run, estimated runtime remaining: 0:03:06.130656
# Start: 25-09-2020; End: 24-10-2020
# No search results for selected time period
# 15 months left to run, estimated runtime remaining: 0:02:54.362010
# Start: 25-10-2020; End: 23-11-2020
# No search results for selected time period
# 14 months left to run, estimated runtime remaining: 0:02:42.621130
# Start: 24-11-2020; End: 23-12-2020
# 4 search results for selected time period
# 13 months left to run, estimated runtime remaining: 0:02:30.892261
# Start: 24-12-2020; End: 22-01-2021
# 2 search results for selected time period
# 12 months left to run, estimated runtime remaining: 0:02:19.185024
# Start: 23-01-2021; End: 21-02-2021
# 3 search results for selected time period
# 11 months left to run, estimated runtime remaining: 0:02:09.386488
# Start: 22-02-2021; End: 23-03-2021
# 4 search results for selected time period
# 10 months left to run, estimated runtime remaining: 0:01:57.533520
# Start: 24-03-2021; End: 22-04-2021
# 3 search results for selected time period
# 9 months left to run, estimated runtime remaining: 0:01:45.700644
# Start: 23-04-2021; End: 22-05-2021
# No search results for selected time period
# 8 months left to run, estimated runtime remaining: 0:01:33.884392
# Start: 23-05-2021; End: 21-06-2021
# 3 search results for selected time period
# 7 months left to run, estimated runtime remaining: 0:01:22.091772
# Start: 22-06-2021; End: 21-07-2021
# No search results for selected time period
# 6 months left to run, estimated runtime remaining: 0:01:10.313454
# Start: 22-07-2021; End: 20-08-2021
# No search results for selected time period
# 5 months left to run, estimated runtime remaining: 0:00:58.552085
# Start: 21-08-2021; End: 19-09-2021
# No search results for selected time period
# 4 months left to run, estimated runtime remaining: 0:00:46.807160
# Start: 20-09-2021; End: 19-10-2021
# 1 search result for selected time period
# 3 months left to run, estimated runtime remaining: 0:00:35.081175
# Start: 20-10-2021; End: 18-11-2021
# 5 search results for selected time period
# 2 months left to run, estimated runtime remaining: 0:00:23.515560
# Start: 19-11-2021; End: 18-12-2021
# 4 search results for selected time period
# 1 months left to run, estimated runtime remaining: 0:00:11.750023
# Start: 19-12-2021; End: 17-01-2022
# 3 search results for selected time period
# 0 months left to run, estimated runtime remaining: 0:00:00
# Start: 18-01-2022; End: 16-02-2022
# No search results for selected time period
# -1 months left to run, estimated runtime remaining: -1 day, 23:59:48.267351

# %%
from tqdm import tqdm

debates = dict()

for i,url in tqdm(enumerate(pmqs_urls)):
    debates[pmqs_dates[i]] = parse_hansard_url(url)
# Out:
# 602it [2:55:39, 17.51s/it]
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-4-6a8f82d00bd4> in <module>
#       4
#       5 for i,url in tqdm(enumerate(pmqs_urls)):
# ----> 6     debates[pmqs_dates[i]] = parse_hansard_url(url)
#
# <ipython-input-2-fc78276c9a5c> in parse_hansard_url(target_url)
#      15     time.sleep(5)
#      16
# ---> 17     d = browser.find_element(By.CLASS_NAME, "calendar-sheet").find_element(By.CLASS_NAME, "day").text
#      18     m = browser.find_element(By.CLASS_NAME, "calendar-sheet").find_element(By.CLASS_NAME, "month").text
#      19     y = browser.find_element(By.CLASS_NAME, "calendar-sheet").find_element(By.CLASS_NAME, "year").text
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#    1242             value = '[name="%s"]' % value
#    1243
# -> 1244         return self.execute(Command.FIND_ELEMENT, {
#    1245             'using': by,
#    1246             'value': value})['value']
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     422         response = self.command_executor.execute(driver_command, params)
#     423         if response:
# --> 424             self.error_handler.check_response(response)
#     425             response['value'] = self._unwrap_value(
#     426                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     245                 alert_text = value['alert'].get('text')
#     246             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247         raise exception_class(message, screen, stacktrace)
#     248
#     249     def _value_or_default(self, obj: Mapping[_KT, _VT], key: _KT, default: _VT) -> _VT:
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".calendar-sheet"}
#   (Session info: chrome=98.0.4758.82)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x01007AC3+2587331]
# 	Ordinal0 [0x00F9ADD1+2141649]
# 	Ordinal0 [0x00E93BB8+1063864]
# 	Ordinal0 [0x00EC01CE+1245646]
# 	Ordinal0 [0x00EC03CB+1246155]
# 	Ordinal0 [0x00EEA612+1418770]
# 	Ordinal0 [0x00ED86D4+1345236]
# 	Ordinal0 [0x00EE8A0A+1411594]
# 	Ordinal0 [0x00ED84A6+1344678]
# 	Ordinal0 [0x00EB53F6+1201142]
# 	Ordinal0 [0x00EB62E6+1204966]
# 	GetHandleVerifier [0x011ADF22+1680738]
# 	GetHandleVerifier [0x01260DBC+2413564]
# 	GetHandleVerifier [0x0109D151+563089]
# 	GetHandleVerifier [0x0109BF13+558419]
# 	Ordinal0 [0x00FA081E+2164766]
# 	Ordinal0 [0x00FA5508+2184456]
# 	Ordinal0 [0x00FA5650+2184784]
# 	Ordinal0 [0x00FAF5BC+2225596]
# 	BaseThreadInitThunk [0x771C6739+25]
# 	RtlGetFullPathName_UEx [0x77BC8AFF+1215]
# 	RtlGetFullPathName_UEx [0x77BC8ACD+1165]

# %%
import pickle

debates_pkl = open('debates.pkl','wb')
pickle.dump(debates, debates_pkl)
debates_pkl.close()
